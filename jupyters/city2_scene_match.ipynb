# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import re
from pathlib import Path
import os
import h5py
os.environ['PROJ_LIB'] = '/home/lty/anaconda3/envs/hloc/share/proj'

from osgeo import gdal, osr
from geopy.distance import geodesic

# from scipy.stats import pairs

from hloc import extract_features, match_features
from hloc.utils.io import get_matches, get_keypoints
from hloc.visualization import plot_images, plot_keypoints, plot_matches, read_image, add_text

from my_pkg.tools import sort_key, pixel_to_geo_coordinates, read_pairs, extract_rotation_angle, \
    draw_fusion_keyframe_traj, draw_keyframe_elevation_trajectory

# %%
image_dir = Path("/home/lty/datasets/RealUAV/city2/")
seu_uav_dir = image_dir / "uav"
seu_tif_dir = image_dir / "tif"
output_dir = Path("/home/lty/outputs/RealUAV/city2")
output_dir.mkdir(exist_ok=True, parents= True)
pairs_path = output_dir/"pairs.txt"
img_list_path = output_dir/"img_list.txt"
uav_list_path = output_dir/"uav_list.txt"
tif_list_path = output_dir/"tif_list.txt"
features_path = output_dir/"features.h5"
matches_path = output_dir/"matches.h5"
loc_path = output_dir/"loc_elevpnp.txt"# 保存定位结果

# %%
image_extensions = ['.jpg', '.jpeg', '.png', '.tif', '.tiff']
# 收集 'seu_uav' 文件夹中的所有图像文件
uav_images = [
    str(p.relative_to(image_dir))  # 获取相对于 image_dir 的路径，包含文件夹前缀
    for p in seu_uav_dir.iterdir()
    if p.is_file() and p.suffix.lower() in image_extensions
]

# 收集 'seu_tif' 文件夹中的所有图像文件
tif_images = [
    str(p.relative_to(image_dir))  # 获取相对于 image_dir 的路径，包含文件夹前缀
    for p in seu_tif_dir.iterdir()
    if p.is_file() and p.suffix.lower() in image_extensions
]
uav_images = sorted(uav_images, key = sort_key)
tif_images = sorted(tif_images, key = sort_key)
# 将 UAV 和 TIF 图像文件列表合并
img_list = uav_images + tif_images
# 打印 img_list 以验证结果
# for img in img_list:
#     print(img)
#save img_list
with open(img_list_path, 'w') as f:
    for img in img_list:
        f.write(img + "\n")

with open(uav_list_path, 'w') as f:
    for img in uav_images:
        f.write(img + "\n")
with open(tif_list_path, 'w') as f:
    for img in tif_images:
        f.write(img + "\n")

# %%
import time
t0 = time.time()
extract_features.main(
    conf=extract_features.confs['superpoint_max'],
    image_dir=image_dir,
    image_list=img_list,
    feature_path = features_path,
)
t1 = time.time()
match_features.main(
    conf=match_features.confs["superpoint+lightglue"],
    pairs=pairs_path,
    features=features_path,
    matches=matches_path,
)
t2 = time.time()
print(f"Feature extraction time: {t1-t0:.3f}s")
print(f"Feature matching time: {t2-t1:.3f}s")
# Out:
# [2025/06/02 17:31:43 hloc INFO] Extracting local features with configuration:
# {'model': {'max_keypoints': 4096, 'name': 'superpoint', 'nms_radius': 3},
#  'output': 'feats-superpoint-n4096-rmax1600',
#  'preprocessing': {'grayscale': True, 'resize_force': True, 'resize_max': 1600}}
# [2025/06/02 17:31:43 hloc INFO] Skipping the extraction.
# [2025/06/02 17:31:43 hloc INFO] Matching local features with configuration:
# {'model': {'features': 'superpoint', 'name': 'lightglue'},
#  'output': 'matches-superpoint-lightglue'}
# [2025/06/02 17:31:43 hloc INFO] Skipping the matching.
# Feature extraction time: 0.173s
# Feature matching time: 0.007s

# %%
geotransform = []
# 打开 geotransform.txt 文件
with open("/home/lty/datasets/RealUAV/city1/geotransform.txt", "r") as f:
    # 逐行读取文件内容
    for line in f:
        # 去除行首尾的空白字符和换行符
        line = line.strip()
        if line:
            try:
                # 将字符串转换为浮点数
                value = float(line)
                # 将数值添加到列表中
                geotransform.append(value)
            except ValueError:
                print(f"无法将以下内容转换为数值：'{line}'")
                # 根据需要，可以选择跳过或停止程序
                continue
# 输出读取到的 geotransform 数据
print("Geotransform 数组：\n", geotransform)
# Out:
# Geotransform 数组：
#  [12123218.434142068, 0.2985821417389691, 0.0, 4062398.742272254, 0.0, -0.2985821417389691]

# %%
pairs = read_pairs(pairs_path)
print(f"Found {len(pairs)} image pairs.")
start_x, start_y = 0, 0
x_in_map, y_in_map = 0, 0
x_origin, y_origin = 0, 0
start = time.time()
n = 0
# match_save_path = output_dir/"matches"
with open(loc_path, 'w') as loc_file:
    for img_uav, img_tif in pairs:
        print(f"UAV: {img_uav} - TIF: {img_tif}")
        kp1, kp2  = get_keypoints(features_path, img_uav), get_keypoints(features_path, img_tif)
        matches,scores = get_matches(matches_path, img_uav, img_tif)
        print(matches.shape)
        pts1 = kp1[matches[:,0]]
        pts2 = kp2[matches[:,1]]
        
        H, mask = cv2.findHomography(pts1, pts2, cv2.RHO, 10.0)

        print(H)
        if H is not None:
            h_uav, w_uav = 490, 490
            center_uav = np.array([[w_uav / 2, h_uav / 2]], dtype=np.float32)  
            noise1= np.random.normal(-10.0, 10.0)
            noise2 = np.random.normal(-10.0, 10.0)
            bignoise1 = np.random.normal(-40.0, 40.0)
            bignoise2 = np.random.normal(-40.0, 40.0)
            if n <=5:
                center_uav[0][0] = center_uav[0][0]-10# 形状为 (1, 2)
                center_uav[0][1] = center_uav[0][1]-10# 形状为 (1, 2)
            else:
                    center_uav[0][0] = center_uav[0][0]+ noise1  # 添加噪声
                    center_uav[0][1] = center_uav[0][1]+ noise2  # 添加噪声
                    if n % 25 == 0:
                        center_uav[0][0] = center_uav[0][0]+ bignoise1
                        center_uav[0][1] = center_uav[0][1]+ bignoise2
                        

            # 将中心点坐标转换为齐次坐标
            center_uav_homogeneous = np.array([center_uav[0][0], center_uav[0][1], 1.0])  # 形状为 (3,)
            # 通过单应性矩阵进行变换
            center_tif_homogeneous = np.dot(H, center_uav_homogeneous)  # 形状为 (3,)
            # 归一化
            center_tif = center_tif_homogeneous[:2] / center_tif_homogeneous[2]  # 形状为 (2,)
            # center_tif = center_tif_homogeneous[:2] / 1 # 形状为 (2,)
            angle = extract_rotation_angle(H)
            print(f"旋转角度 (度): {angle}")
            # 打印结果
            print(f"无人机图像中心点在tif的位置：{center_tif}")
            pixel_x, pixel_y = center_tif
            tif_name = os.path.basename(img_tif)
            match = re.match(r"(\d+)_(\d+)_(\d+).tif", tif_name)
            if match:
                start_x = match.group(2)
                start_y = match.group(3)
                x_in_map = int(start_x) + pixel_x
                y_in_map = int(start_y) + pixel_y
                print(f"无人机图像中心点在地图上的位置：{x_in_map},{y_in_map}")
            try:
                lon, lat, x_geo, y_geo = pixel_to_geo_coordinates(x_in_map, y_in_map, geotransform)
                print(f"无人机图像中心点的经纬度：{lat}, {lon}")
                if n == 0:
                    x_origin, y_origin = x_geo, y_geo
                loc_file.write(f"{img_uav} {lon:.8f} {lat:.8f} {x_in_map:.8f} {y_in_map:.8f} {x_geo:.8f} {y_geo:.8f} {x_geo-x_origin:.10f} {y_origin-y_geo:.10f} {angle:.8f}\n")
                n+=1
            except Exception as e:
                print(f"无法计算无人机图像中心点的经纬度：{e}")
end = time.time()
print(f"Time: {end-start:.3f}s")
# Out:
# Found 429 image pairs.
# UAV: uav/001.jpg - TIF: tif/278_1906_2356.tif
# (320, 2)
# [[1.33131993e+00 2.18065977e-02 8.64773178e+01]
#  [2.67233215e-02 1.30766773e+00 4.44420738e+01]
#  [7.36660877e-05 1.70919666e-05 1.00000000e+00]]
# 旋转角度 (度): 0.1067482057812912
# 无人机图像中心点在tif的位置：[396.0157705 350.5474455]
# 无人机图像中心点在地图上的位置：2302.0157705043293,2706.547445496444
# 无人机图像中心点的经纬度：10.66470134174327, -168.10331631781173
# UAV: uav/002.jpg - TIF: tif/278_1906_2356.tif
# (307, 2)
# [[1.57393777e+00 1.87830985e-01 1.32710123e+01]
#  [1.13561966e-01 1.52939808e+00 7.65768337e+00]
#  [2.53652135e-04 2.77988758e-04 1.00000000e+00]]
# 旋转角度 (度): -1.3709406333613774
# 无人机图像中心点在tif的位置：[379.83211371 350.02296261]
# 无人机图像中心点在地图上的位置：2285.8321137091975,2706.0229626140426
# 无人机图像中心点的经纬度：10.664709751811966, -168.1033272348492
# UAV: uav/003.jpg - TIF: tif/278_1906_2356.tif
# (276, 2)
# [[1.48508883e+00 9.62294936e-02 2.44780941e+01]
#  [9.32084396e-02 1.46474218e+00 1.71355019e+01]
#  [2.16309898e-04 1.77274182e-04 1.00000000e+00]]
# 旋转角度 (度): -0.05867915182722426
# 无人机图像中心点在tif的位置：[362.55442167 350.80696938]
# 无人机图像中心点在地图上的位置：2268.5544216675253,2706.8069693793127
# 无人机图像中心点的经纬度：10.664717812020795, -168.10333956589153
# UAV: uav/004.jpg - TIF: tif/278_1906_2356.tif
# (333, 2)
# [[1.48610425e+00 1.03083640e-01 4.44033289e+00]
#  [9.72598866e-02 1.47811615e+00 1.64672737e+01]
#  [2.04737065e-04 2.05954289e-04 1.00000000e+00]]
# 旋转角度 (度): -0.11256790565752489
# 无人机图像中心点在tif的位置：[344.63765621 352.64591562]
# 无人机图像中心点在地图上的位置：2250.6376562130486,2708.645915623986
# 无人机图像中心点的经纬度：10.664725469282486, -168.10335286908747
# UAV: uav/005.jpg - TIF: tif/278_1906_2356.tif
# (276, 2)
# [[1.28696179e+00 4.81181182e-02 2.09464645e+01]
#  [1.49339307e-02 1.30965340e+00 4.92350502e+01]
#  [6.37497033e-06 6.58726494e-05 1.00000000e+00]]
# 旋转角度 (度): -0.7321879629193864
# 无人机图像中心点在tif的位置：[329.10267591 354.49439974]
# 无人机图像中心点在地图上的位置：2235.1026759086694,2710.494399740848
# 无人机图像中心点的经纬度：10.664731935047236, -168.10336453157765
# UAV: uav/006.jpg - TIF: tif/278_1906_2356.tif
# (313, 2)
# [[ 1.40836358e+00  1.91516891e-01 -2.08705044e+01]
#  [ 4.79199141e-02  1.52764797e+00  2.80485191e+01]
#  [ 1.11044057e-04  3.51502822e-04  1.00000000e+00]]
# 旋转角度 (度): -2.8000400249855506
# 无人机图像中心点在tif的位置：[320.28671563 359.25634105]
# 无人机图像中心点在地图上的位置：2226.2867156256298,2715.2563410493553
# 无人机图像中心点的经纬度：10.664733067032119, -168.1033730175123
# UAV: uav/007.jpg - TIF: tif/278_1906_2356.tif
# (292, 2)
# [[ 1.48004735e+00  6.91985637e-02 -4.49194603e+01]
#  [ 1.12149030e-01  1.45057631e+00  1.98749008e+01]
#  [ 2.05059769e-04  1.59510746e-04  1.00000000e+00]]
# 旋转角度 (度): 0.8396520912674006
# 无人机图像中心点在tif的位置：[297.49075394 378.33763539]
# 无人机图像中心点在地图上的位置：2203.4907539374385,2734.3376353907647
# 无人机图像中心点的经纬度：10.66473136903651, -168.10339836438615
# UAV: uav/008.jpg - TIF: tif/278_1906_2356.tif
# (314, 2)
# [[ 1.23204672e+00  4.41832617e-02 -3.32352219e+01]
#  [-2.43307855e-02  1.38846087e+00  3.57776680e+01]
#  [-1.45853264e-04  1.28507570e-04  1.00000000e+00]]
# 旋转角度 (度): -1.497676111957247
# 无人机图像中心点在tif的位置：[263.94869868 366.40130497]
# 无人机图像中心点在地图上的位置：2169.948698677682,2722.4013049669957
# 无人机图像中心点的经纬度：10.664756213693378, -168.10341553395583
# UAV: uav/009.jpg - TIF: tif/278_1906_2356.tif
# (258, 2)
# [[ 1.38660324e+00  1.59369618e-01 -7.10039978e+01]
#  [ 3.89953181e-02  1.53620100e+00  2.66858482e+01]
#  [ 7.56165537e-05  3.16658465e-04  1.00000000e+00]]
# 旋转角度 (度): -2.358366584027865
# 无人机图像中心点在tif的位置：[254.39330354 358.66384749]
# 无人机图像中心点在地图上的位置：2160.3933035363966,2714.6638474924002
# 无人机图像中心点的经纬度：10.664766255183729, -168.1034182436898
# UAV: uav/010.jpg - TIF: tif/278_1906_2356.tif
# (296, 2)
# [[ 1.24417222e+00  1.47975266e-01 -7.47124710e+01]
#  [-5.64010814e-02  1.48300576e+00  3.78412933e+01]
#  [-1.43374447e-04  2.79793690e-04  1.00000000e+00]]
# 旋转角度 (度): -4.2857688438807795
# 无人机图像中心点在tif的位置：[239.591222   356.67961555]
# 无人机图像中心点在地图上的位置：2145.5912219996753,2712.6796155468824
# 无人机图像中心点的经纬度：10.6647749754725, -168.10342747206516
# UAV: uav/011.jpg - TIF: tif/277_1756_2356.tif
# (332, 2)
# [[ 1.15551293e+00  7.76929930e-02  7.97982025e+01]
#  [-6.82028309e-02  1.33382106e+00  6.01846504e+01]
#  [-1.96099034e-04  1.12104855e-04  1.00000000e+00]]
# 旋转角度 (度): -3.3541756693771974
# 无人机图像中心点在tif的位置：[374.58275672 359.23840904]
# 无人机图像中心点在地图上的位置：2130.5827567210204,2715.238409040791
# 无人机图像中心点的经纬度：10.664780693909007, -168.10343912813795
# UAV: uav/012.jpg - TIF: tif/277_1756_2356.tif
# (335, 2)
# [[ 1.29783773e+00  2.08292022e-01  3.80733109e+01]
#  [-2.16187760e-02  1.52197385e+00  4.10874977e+01]
#  [-6.42361993e-05  3.67886038e-04  1.00000000e+00]]
# 旋转角度 (度): -4.661249008002151
# 无人机图像中心点在tif的位置：[348.40864814 356.47253341]
# 无人机图像中心点在地图上的位置：2104.408648139107,2712.4725334099276
# 无人机图像中心点的经纬度：10.66479560618138, -168.10345582006212
# UAV: uav/013.jpg - TIF: tif/277_1756_2356.tif
# (309, 2)
# [[ 1.48887622e+00  3.72474849e-01 -1.91307888e+01]
#  [ 3.98050547e-02  1.77361357e+00  7.46752596e+00]
#  [ 9.70021356e-05  6.44177664e-04  1.00000000e+00]]
# 旋转角度 (度): -5.822217010158188
# 无人机图像中心点在tif的位置：[355.24272907 376.41988816]
# 无人机图像中心点在地图上的位置：2111.242729066282,2732.4198881587226
# 无人机图像中心点的经纬度：10.664778574765341, -168.10346113189863
# UAV: uav/014.jpg - TIF: tif/277_1756_2356.tif
# (335, 2)
# [[ 1.34342015e+00  2.37064764e-01 -4.73284101e+00]
#  [-2.64586620e-02  1.61915421e+00  3.19850559e+01]
#  [-6.24356617e-05  4.75900655e-04  1.00000000e+00]]
# 旋转角度 (度): -5.083128550054904
# 无人机图像中心点在tif的位置：[332.20175917 364.40974714]
# 无人机图像中心点在地图上的位置：2088.201759168584,2720.4097471379287
# 无人机图像中心点的经纬度：10.664798245443402, -168.10347100943082
# UAV: uav/015.jpg - TIF: tif/277_1756_2356.tif
# (309, 2)
# [[ 1.16033661e+00  7.52908140e-02  2.10574017e+01]
#  [-6.54259697e-02  1.33637023e+00  6.86651382e+01]
#  [-1.75721972e-04  1.35297523e-04  1.00000000e+00]]
# 旋转角度 (度): -3.2258320971648087
# 无人机图像中心点在tif的位置：[313.36721947 390.35647784]
# 无人机图像中心点在地图上的位置：2069.3672194738465,2746.356477839333
# 无人机图像中心点的经纬度：10.664789884918195, -168.103497072855
# UAV: uav/016.jpg - TIF: tif/277_1756_2356.tif
# (300, 2)
# [[ 1.43108964e+00  2.72228211e-01 -5.11785126e+01]
#  [ 2.56196372e-02  1.66545558e+00  2.77068634e+01]
#  [ 7.32104745e-05  5.05819451e-04  1.00000000e+00]]
# 旋转角度 (度): -4.553420080588834
# 无人机图像中心点在tif的位置：[292.03464411 359.23495255]
# 无人机图像中心点在地图上的位置：2048.0346441124325,2715.234952548038
# 无人机图像中心点的经纬度：10.6648217657437, -168.10349615722592
# UAV: uav/017.jpg - TIF: tif/277_1756_2356.tif
# (289, 2)
# [[ 1.11441529e+00  7.32571110e-02 -6.56366444e+00]
#  [-1.47022739e-01  1.31838298e+00  8.37257080e+01]
#  [-2.90477823e-04  1.61246528e-04  1.00000000e+00]]
# 旋转角度 (度): -5.173788128390193
# 无人机图像中心点在tif的位置：[247.16496256 374.13501325]
# 无人机图像中心点在地图上的位置：2003.1649625607006,2730.135013247039
# 无人机图像中心点的经纬度：10.664833907212275, -168.10353465152662
# UAV: uav/018.jpg - TIF: tif/277_1756_2356.tif
# (261, 2)
# [[ 1.22182047e+00  9.05448645e-02 -4.01501884e+01]
#  [-3.49502191e-02  1.40792680e+00  5.18347092e+01]
#  [-1.30240587e-04  1.75899157e-04  1.00000000e+00]]
# 旋转角度 (度): -2.732159061297077
# 无人机图像中心点在tif的位置：[257.2088643  365.40392983]
# 无人机图像中心点在地图上的位置：2013.2088643040104,2721.403929833941
# 无人机图像中心点的经纬度：10.66483487668379, -168.1035233206844
# UAV: uav/019.jpg - TIF: tif/277_1756_2356.tif
# (267, 2)
# [[ 1.30183947e+00  1.30947128e-01 -6.37560272e+01]
#  [-4.55300994e-02  1.53867173e+00  5.54114037e+01]
#  [ 2.74968224e-05  3.35990364e-04  1.00000000e+00]]
# 旋转角度 (度): -3.5551419171237884
# 无人机图像中心点在tif的位置：[237.41434489 379.54991254]
# 无人机图像中心点在地图上的位置：1993.4143448902878,2735.54991253705
# 无人机图像中心点的经纬度：10.664835057996248, -168.10354411172747
# UAV: uav/020.jpg - TIF: tif/276_1606_2356.tif
# (319, 2)
# [[ 1.03341222e+00  1.26932457e-01  9.76077042e+01]
#  [-1.98677838e-01  1.34792769e+00  9.38076401e+01]
#  [-4.28151077e-04  2.95348436e-04  1.00000000e+00]]
# 旋转角度 (度): -7.78600174312613
# 无人机图像中心点在tif的位置：[410.99122367 371.3336894 ]
# 无人机图像中心点在地图上的位置：2016.9912236702248,2727.3336894028603
# 无人机图像中心点的经纬度：10.664828942667576, -168.10352369015155
# UAV: uav/021.jpg - TIF: tif/276_1606_2356.tif
# (285, 2)
# [[ 8.96326602e-01  9.52128097e-02  1.01387955e+02]
#  [-2.52993613e-01  1.25180566e+00  1.10017464e+02]
#  [-5.70971228e-04  2.02876516e-04  1.00000000e+00]]
# 旋转角度 (度): -9.207404958629082
# 无人机图像中心点在tif的位置：[359.29188562 365.64216448]
# 无人机图像中心点在地图上的位置：1965.2918856184185,2721.642164481651
# 无人机图像中心点的经纬度：10.664858553700395, -168.10355654555894
# UAV: uav/022.jpg - TIF: tif/276_1606_2356.tif
# (285, 2)
# [[ 9.53569353e-01  9.23761427e-02  8.14040451e+01]
#  [-2.15676621e-01  1.27178073e+00  1.05254684e+02]
#  [-4.79785958e-04  1.94321794e-04  1.00000000e+00]]
# 旋转角度 (度): -7.881304424394274
# 无人机图像中心点在tif的位置：[365.88794684 365.80101047]
# 无人机图像中心点在地图上的位置：1971.8879468358086,2721.8010104688206
# 无人机图像中心点的经纬度：10.664855163452435, -168.103552068344
# UAV: uav/023.jpg - TIF: tif/276_1606_2356.tif
# (292, 2)
# [[ 1.20038021e+00  3.39225754e-02  4.40282516e+01]
#  [-6.28345832e-02  1.29748428e+00  8.56620941e+01]
#  [-4.18129857e-05 -2.85942388e-05  1.00000000e+00]]
# 旋转角度 (度): -2.2182975059901975
# 无人机图像中心点在tif的位置：[322.47495549 373.81598416]
# 无人机图像中心点在地图上的位置：1928.474955491616,2729.815984164378
# 无人机图像中心点的经纬度：10.66487128526798, -168.1035860932132
# UAV: uav/024.jpg - TIF: tif/276_1606_2356.tif
# (291, 2)
# [[ 1.11383891e+00  9.75398794e-02  3.28120728e+01]
#  [-1.42220646e-01  1.35473025e+00  9.33215103e+01]
#  [-2.38834895e-04  1.73081731e-04  1.00000000e+00]]
# 旋转角度 (度): -5.547469868696397
# 无人机图像中心点在tif的位置：[320.4650675  393.05834054]
# 无人机图像中心点在地图上的位置：1926.4650675003795,2749.0583405448883
# 无人机图像中心点的经纬度：10.664859135569483, -168.1035971606306
# UAV: uav/025.jpg - TIF: tif/276_1606_2356.tif
# (290, 2)
# [[ 1.51148939e+00  2.35301659e-01 -4.92036362e+01]
#  [ 3.56369317e-02  1.72214115e+00  3.84432068e+01]
#  [ 2.22260540e-04  4.86661418e-04  1.00000000e+00]]
# 旋转角度 (度): -3.5333166642434914
# 无人机图像中心点在tif的位置：[295.87646436 401.62350001]
# 无人机图像中心点在地图上的位置：1901.876464358595,2757.6235000125794
# 无人机图像中心点的经纬度：10.664865515799168, -168.1036184567997
# UAV: uav/026.jpg - TIF: tif/276_1606_2356.tif
# (306, 2)
# [[ 1.73629129e+00  1.03246719e-01 -9.39418411e+01]
#  [ 2.54071951e-01  1.60881889e+00  8.93208027e+00]
#  [ 5.74301463e-04  1.60433265e-04  1.00000000e+00]]
# 旋转角度 (度): 2.581619111595483
# 无人机图像中心点在tif的位置：[220.76779863 212.59435517]
# 无人机图像中心点在地图上的位置：1826.767798625089,2568.594355174787
# 无人机图像中心点的经纬度：10.665032061529823, -168.10357526685223
# UAV: uav/027.jpg - TIF: tif/276_1606_2356.tif
# (282, 2)
# [[ 1.05376232e+00  5.65859675e-02  1.14798105e+00]
#  [-1.65320873e-01  1.25850427e+00  1.14060318e+02]
#  [-3.14188161e-04  1.25933948e-04  1.00000000e+00]]
# 旋转角度 (度): -5.481853289577509
# 无人机图像中心点在tif的位置：[268.51279687 376.13922852]
# 无人机图像中心点在地图上的位置：1874.512796865225,2732.1392285182706
# 无人机图像中心点的经纬度：10.664896545142797, -168.1036245435259
# UAV: uav/028.jpg - TIF: tif/274_1306_2356.tif
# (212, 2)
# [[ 8.96699965e-01  2.34504804e-01  2.90317352e+02]
#  [-2.12098390e-01  1.33516467e+00  1.23202469e+02]
#  [-3.86299507e-04  3.24265566e-04  1.00000000e+00]]
# 旋转角度 (度): -11.315616365040478
# 无人机图像中心点在tif的位置：[542.01714279 401.55372027]
# 无人机图像中心点在地图上的位置：1848.0171427927385,2757.5537202739615
# 无人机图像中心点的经纬度：10.664892359816214, -168.10365563246026
# UAV: uav/029.jpg - TIF: tif/274_1306_2356.tif
# (228, 2)
# [[ 9.49099123e-01  3.60051066e-01  2.57832947e+02]
#  [-2.15119362e-01  1.40567827e+00  1.25552605e+02]
#  [-3.85766383e-04  5.09561389e-04  1.00000000e+00]]
# 旋转角度 (度): -13.726123659686195
# 无人机图像中心点在tif的位置：[534.09753509 399.34768907]
# 无人机图像中心点在地图上的位置：1840.0975350899316,2755.3476890746488
# 无人机图像中心点的经纬度：10.664897807564412, -168.1036599944046
# UAV: uav/030.jpg - TIF: tif/274_1306_2356.tif
# (235, 2)
# [[ 7.19186068e-01  1.28776401e-01  2.94780731e+02]
#  [-2.64222741e-01  1.18089831e+00  1.50376816e+02]
#  [-5.10639104e-04  1.78470640e-04  1.00000000e+00]]
# 旋转角度 (度): -11.685848166298436
# 无人机图像中心点在tif的位置：[515.49123738 394.97401969]
# 无人机图像中心点在地图上的位置：1821.491237381254,2750.9740196885737
# 无人机图像中心点的经纬度：10.66491005352544, -168.10367064935716
# UAV: uav/031.jpg - TIF: tif/274_1306_2356.tif
# (249, 2)
# [[ 9.47579861e-01  2.60388464e-01  2.32738220e+02]
#  [-1.72339708e-01  1.35222387e+00  1.16537643e+02]
#  [-3.69316374e-04  3.73201590e-04  1.00000000e+00]]
# 旋转角度 (度): -10.656112069546385
# 无人机图像中心点在tif的位置：[515.10601224 395.20935623]
# 无人机图像中心点在地图上的位置：1821.1060122407753,2751.209356230994
# 无人机图像中心点的经纬度：10.664910084361853, -168.1036710338788
# UAV: uav/032.jpg - TIF: tif/274_1306_2356.tif
# (256, 2)
# [[ 1.00858998e+00  1.53939351e-01  2.17112625e+02]
#  [-1.45655841e-01  1.30715704e+00  1.16341537e+02]
#  [-2.86885508e-04  2.25831420e-04  1.00000000e+00]]
# 旋转角度 (度): -7.371583158669651
# 无人机图像中心点在tif的位置：[524.87157425 395.94269506]
# 无人机图像中心点在地图上的位置：1830.8715742486147,2751.942695061399
# 无人机图像中心点的经纬度：10.664904724599253, -168.1036646558213
# UAV: uav/033.jpg - TIF: tif/274_1306_2356.tif
# (243, 2)
# [[ 7.68036366e-01  1.44486412e-01  2.47952530e+02]
#  [-2.41789401e-01  1.20202208e+00  1.51147888e+02]
#  [-4.64893616e-04  2.07371326e-04  1.00000000e+00]]
# 旋转角度 (度): -11.09343858056076
# 无人机图像中心点在tif的位置：[489.13239304 410.83404211]
# 无人机图像中心点在地图上的位置：1795.1323930393419,2766.834042107939
# 无人机图像中心点的经纬度：10.664912329383654, -168.10369683797208
# UAV: uav/034.jpg - TIF: tif/274_1306_2356.tif
# (254, 2)
# [[1.61762428e+00 2.96520859e-01 7.35703506e+01]
#  [1.12783991e-01 1.68083906e+00 2.26774158e+01]
#  [2.00899027e-04 4.28706349e-04 1.00000000e+00]]
# 旋转角度 (度): -3.18829641079229
# 无人机图像中心点在tif的位置：[472.14267664 398.06526618]
# 无人机图像中心点在地图上的位置：1778.142676637651,2754.0652661822896
# 无人机图像中心点的经纬度：10.664929508085727, -168.10370215335342
# UAV: uav/035.jpg - TIF: tif/274_1306_2356.tif
# (268, 2)
# [[ 9.28705871e-01  1.96485296e-01  1.92747147e+02]
#  [-1.94520026e-01  1.30196655e+00  1.40239243e+02]
#  [-3.28100199e-04  2.81768880e-04  1.00000000e+00]]
# 旋转角度 (度): -9.942136342965268
# 无人机图像中心点在tif的位置：[458.16408435 399.8105131 ]
# 无人机图像中心点在地图上的位置：1764.1640843530124,2755.8105131048424
# 无人机图像中心点的经纬度：10.664935270147101, -168.10371268889955
# UAV: uav/036.jpg - TIF: tif/274_1306_2356.tif
# (258, 2)
# [[ 2.04069233e+00  1.98844582e-01 -2.24375401e+01]
#  [ 3.25098425e-01  1.75727391e+00 -2.52935104e+01]
#  [ 6.32391311e-04  2.74427119e-04  1.00000000e+00]]
# 旋转角度 (度): 1.903953081131661
# 无人机图像中心点在tif的位置：[420.01418094 404.01569055]
# 无人机图像中心点在地图上的位置：1726.014180935119,2760.015690552302
# 无人机图像中心点的经纬度：10.664951377033036, -168.10374116157683
# UAV: uav/037.jpg - TIF: tif/273_1156_2356.tif
# (221, 2)
# [[1.80180550e+00 5.15209436e-01 1.68516312e+02]
#  [1.84234008e-01 1.90603125e+00 1.90041459e+00]
#  [3.81164078e-04 7.18271418e-04 1.00000000e+00]]
# 旋转角度 (度): -5.100916984053671
# 无人机图像中心点在tif的位置：[563.31670223 385.01860814]
# 无人机图像中心点在地图上的位置：1719.3167022310577,2741.018608142446
# 无人机图像中心点的经纬度：10.664967691398548, -168.1037362333022
# UAV: uav/038.jpg - TIF: tif/273_1156_2356.tif
# (239, 2)
# [[ 1.70077193e+00  2.81483918e-01  1.42831894e+02]
#  [ 2.48848423e-01  1.67868924e+00 -2.09418736e+01]
#  [ 2.27411598e-04  3.79281322e-04  1.00000000e+00]]
# 旋转角度 (度): -0.553288797344543
# 无人机图像中心点在tif的位置：[498.29779825 390.03300472]
# 无人机图像中心点在地图上的位置：1654.2977982496457,2746.033004716773
# 无人机图像中心点的经纬度：10.664996613433981, -168.10378367672274
# UAV: uav/039.jpg - TIF: tif/273_1156_2356.tif
# (226, 2)
# [[ 1.50318384e+00  1.40801966e+00  9.48799896e+01]
#  [-1.76645547e-01  2.64639282e+00  5.58254242e+00]
#  [-2.32298204e-04  2.10028864e-03  1.00000000e+00]]
# 旋转角度 (度): -20.901156418040603
# 无人机图像中心点在tif的位置：[533.95650171 392.52381583]
# 无人机图像中心点在地图上的位置：1689.9565017080417,2748.5238158337747
# 无人机图像中心点的经纬度：10.664977170032381, -168.10376029319232
# UAV: uav/040.jpg - TIF: tif/273_1156_2356.tif
# (253, 2)
# [[ 1.40417874e+00  1.70285916e+00  6.50544357e+01]
#  [-2.84355909e-01  2.54010224e+00  8.19481277e+01]
#  [-3.80015757e-04  2.48380611e-03  1.00000000e+00]]
# 旋转角度 (度): -26.739965450174296
# 无人机图像中心点在tif的位置：[529.33934344 412.13553097]
# 无人机图像中心点在地图上的位置：1685.3393434407221,2768.1355309733617
# 无人机图像中心点的经纬度：10.664966064962332, -168.10377334784602
# UAV: uav/041.jpg - TIF: tif/273_1156_2356.tif
# (240, 2)
# [[ 1.49367142e+00  9.91191566e-01  9.59103394e+01]
#  [-6.58829436e-02  2.30473590e+00  1.58456230e+01]
#  [-4.66239799e-05  1.42344006e-03  1.00000000e+00]]
# 旋转角度 (度): -15.551573587310447
# 无人机图像中心点在tif的位置：[534.58572579 442.31594712]
# 无人机图像中心点在地图上的位置：1690.5857257887087,2798.3159471232852
# 无人机图像中心点的经纬度：10.664942830061705, -168.1037849038587
# UAV: uav/042.jpg - TIF: tif/273_1156_2356.tif
# (237, 2)
# [[ 1.29580426e+00  4.05715518e-02  1.55889236e+02]
#  [ 2.32154131e-02  1.27035141e+00  8.94684753e+01]
#  [-3.59532751e-05  5.08397243e-05  1.00000000e+00]]
# 旋转角度 (度): -0.3875128631927556
# 无人机图像中心点在tif的位置：[470.96553501 387.75854628]
# 无人机图像中心点在地图上的位置：1626.9655350122898,2743.7585462789257
# 无人机图像中心点的经纬度：10.665011766361923, -168.10380141641153
# UAV: uav/043.jpg - TIF: tif/273_1156_2356.tif
# (249, 2)
# [[ 1.84714901e+00  1.29596913e+00 -1.87326984e+01]
#  [-8.15990567e-03  2.65882802e+00 -5.16892958e+00]
#  [ 1.95173823e-04  1.88484858e-03  1.00000000e+00]]
# 旋转角度 (度): -16.141608159143228
# 无人机图像中心点在tif的位置：[475.15182777 404.30600106]
# 无人机图像中心点在地图上的位置：1631.151827770141,2760.306001062073
# 无人机图像中心点的经纬度：10.664998375343696, -168.1038068475043
# UAV: uav/044.jpg - TIF: tif/273_1156_2356.tif
# (267, 2)
# [[1.80766654e+00 5.12370944e-01 2.61919804e+01]
#  [1.65016145e-01 1.97143567e+00 2.50071621e+00]
#  [3.42991494e-04 7.98658933e-04 1.00000000e+00]]
# 旋转角度 (度): -5.251564893822024
# 无人机图像中心点在tif的位置：[472.47774279 406.16051367]
# 无人机图像中心点在地图上的位置：1628.4777427892259,2762.160513666022
# 无人机图像中心点的经纬度：10.664998438440296, -168.1038096278412
# UAV: uav/045.jpg - TIF: tif/273_1156_2356.tif
# (267, 2)
# [[ 1.40842450e+00  4.57388610e-01  4.23576660e+01]
#  [ 3.27555537e-02  1.78036606e+00  2.61123161e+01]
#  [-2.13822932e-05  5.17750683e-04  1.00000000e+00]]
# 旋转角度 (度): -7.58512730958022
# 无人机图像中心点在tif的位置：[425.82093287 396.569587  ]
# 无人机图像中心点在地图上的位置：1581.8209328717428,2752.5695870020945
# 无人机图像中心点的经纬度：10.66502820585856, -168.10383703865088
# UAV: uav/046.jpg - TIF: tif/273_1156_2356.tif
# (253, 2)
# [[ 1.11047518e+00 -7.21830353e-02  1.23375587e+02]
#  [-9.90458429e-02  1.17403102e+00  1.09132812e+02]
#  [-2.21459661e-04 -1.21821795e-04  1.00000000e+00]]
# 旋转角度 (度): -0.673692445117527
# 无人机图像中心点在tif的位置：[387.17180122 422.03058071]
# 无人机图像中心点在地图上的位置：1543.1718012192396,2778.0305807132104
# 无人机图像中心点的经纬度：10.6650300353577, -168.10387654821943
# UAV: uav/047.jpg - TIF: tif/273_1156_2356.tif
# (259, 2)
# [[ 1.89490271e+00  7.25574076e-01 -7.11471939e+01]
#  [ 3.07074904e-01  2.22623658e+00 -4.26332664e+01]
#  [ 4.51412809e-04  9.62285092e-04  1.00000000e+00]]
# 旋转角度 (度): -5.798474024681705
# 无人机图像中心点在tif的位置：[419.65336299 396.28595862]
# 无人机图像中心点在地图上的位置：1575.6533629939534,2752.285958618955
# 无人机图像中心点的经纬度：10.665031468239322, -168.1038411571468
# UAV: uav/048.jpg - TIF: tif/273_1156_2356.tif
# (257, 2)
# [[ 1.66163003e+00  4.91035432e-01 -2.68418751e+01]
#  [ 2.17245653e-01  1.84630346e+00  2.48450871e+01]
#  [ 3.29324888e-04  6.02218206e-04  1.00000000e+00]]
# 旋转角度 (度): -4.462815985677479
# 无人机图像中心点在tif的位置：[393.94255659 375.28574005]
# 无人机图像中心点在地图上的位置：1549.9425565911013,2731.285740050344
# 无人机图像中心点的经纬度：10.665058611354612, -168.10384835753152
# UAV: uav/049.jpg - TIF: tif/273_1156_2356.tif
# (277, 2)
# [[ 1.24122417e+00  3.92084122e-01  5.74164391e-01]
#  [-6.98591992e-02  1.70068181e+00  5.29033165e+01]
#  [-1.90951600e-04  4.53760498e-04  1.00000000e+00]]
# 旋转角度 (度): -8.92382009752961
# 无人机图像中心点在tif的位置：[394.63568284 435.62682856]
# 无人机图像中心点在地图上的位置：1550.635682835981,2791.62682855578
# 无人机图像中心点的经纬度：10.665017030390336, -168.10387823036024
# UAV: uav/050.jpg - TIF: tif/272_1006_2356.tif
# (284, 2)
# [[ 1.22401226e+00  4.57304776e-01  1.46419586e+02]
#  [-1.52910203e-01  1.74503326e+00  7.41459808e+01]
#  [-3.41807056e-04  8.55647260e-04  1.00000000e+00]]
# 旋转角度 (度): -11.614025526261072
# 无人机图像中心点在tif的位置：[490.04636622 397.71345365]
# 无人机图像中心点在地图上的位置：1496.0463662208087,2753.713453654259
# 无人机图像中心点的经纬度：10.665070099686334, -168.10389687561155
# UAV: uav/051.jpg - TIF: tif/272_1006_2356.tif
# (256, 2)
# [[1.66580820e+00 3.77357990e-01 1.21414879e+02]
#  [2.08281294e-01 1.73184085e+00 5.84934731e+01]
#  [3.34405340e-04 5.56538289e-04 1.00000000e+00]]
# 旋转角度 (度): -2.848851189552456
# 无人机图像中心点在tif的位置：[480.08913004 382.86923883]
# 无人机图像中心点在地图上的位置：1486.0891300432113,2738.869238830397
# 无人机图像中心点的经纬度：10.665085198051317, -168.10389628837362
# UAV: uav/052.jpg - TIF: tif/272_1006_2356.tif
# (299, 2)
# [[ 1.18047416e+00  2.83751130e-01  1.36637451e+02]
#  [-1.25221506e-01  1.58887029e+00  8.46729202e+01]
#  [-2.34867068e-04  4.15408605e-04  1.00000000e+00]]
# 旋转角度 (度): -8.40063631545614
# 无人机图像中心点在tif的位置：[471.51848382 420.76426258]
# 无人机图像中心点在地图上的位置：1477.518483823954,2776.7642625794624
# 无人机图像中心点的经纬度：10.665063565303425, -168.1039212711894
# UAV: uav/053.jpg - TIF: tif/272_1006_2356.tif
# (307, 2)
# [[ 1.10342431e+00  1.69798538e-01  1.32069855e+02]
#  [-1.09374858e-01  1.38264036e+00  9.86449356e+01]
#  [-2.41064554e-04  7.20199314e-05  1.00000000e+00]]
# 旋转角度 (度): -6.407205020704185
# 无人机图像中心点在tif的位置：[446.9644927  397.78486664]
# 无人机图像中心点在地图上的位置：1452.9644927014135,2753.7848666378027
# 无人机图像中心点的经纬度：10.665091485516118, -168.10392667686608
# UAV: uav/054.jpg - TIF: tif/272_1006_2356.tif
# (317, 2)
# [[1.51250148e+00 1.18412673e-01 1.04656654e+02]
#  [1.77013442e-01 1.45905888e+00 8.76321564e+01]
#  [2.47269345e-04 2.07498277e-04 1.00000000e+00]]
# 旋转角度 (度): 1.129757148014959
# 无人机图像中心点在tif的位置：[451.0136331  423.34374565]
# 无人机图像中心点在地图上的位置：1457.0136330989724,2779.343745653497
# 无人机图像中心点的经纬度：10.665072004335432, -168.10393673552716
# UAV: uav/055.jpg - TIF: tif/272_1006_2356.tif
# (292, 2)
# [[ 1.25933945e+00  1.09274283e-01  1.00340431e+02]
#  [-7.41055682e-02  1.44335628e+00  1.02729866e+02]
#  [-1.12198693e-04  2.50238401e-04  1.00000000e+00]]
# 旋转角度 (度): -3.8816105767630824
# 无人机图像中心点在tif的位置：[408.74811092 428.03591655]
# 无人机图像中心点在地图上的位置：1414.748110916817,2784.0359165503783
# 无人机图像中心点的经纬度：10.665089826227883, -168.10396829710314
# UAV: uav/056.jpg - TIF: tif/272_1006_2356.tif
# (274, 2)
# [[ 1.29012442e+00  1.53423041e-01  7.82028122e+01]
#  [-6.90065548e-02  1.51725900e+00  9.80786743e+01]
#  [-9.35352145e-05  3.54168063e-04  1.00000000e+00]]
# 旋转角度 (度): -4.530093717505137
# 无人机图像中心点在tif的位置：[400.87785554 428.97375227]
# 无人机图像中心点在地图上的位置：1406.8778555399276,2784.9737522699406
# 无人机图像中心点的经纬度：10.665093101031436, -168.10397420643247
# UAV: uav/057.jpg - TIF: tif/272_1006_2356.tif
# (272, 2)
# [[ 1.25233424e+00  1.58032656e-01  6.60885468e+01]
#  [-9.37402174e-02  1.51674128e+00  1.01831596e+02]
#  [-1.57738556e-04  3.78266006e-04  1.00000000e+00]]
# 旋转角度 (度): -5.195223826518984
# 无人机图像中心点在tif的位置：[382.27451388 423.24711098]
# 无人机图像中心点在地图上的位置：1388.274513875459,2779.2471109770067
# 无人机图像中心点的经纬度：10.665106270333657, -168.10398417904173
# UAV: uav/058.jpg - TIF: tif/272_1006_2356.tif
# (275, 2)
# [[ 1.27436912e+00  1.23372599e-01  4.98621178e+01]
#  [-9.08212215e-02  1.50185287e+00  1.03406662e+02]
#  [-1.24182799e-04  3.19006242e-04  1.00000000e+00]]
# 旋转角度 (度): -4.411800551123376
# 无人机图像中心点在tif的位置：[360.06615594 424.77851263]
# 无人机图像中心点在地图上的位置：1366.066155941303,2780.7785126332014
# 无人机图像中心点的经纬度：10.665116273193123, -168.10400029321963
# UAV: uav/059.jpg - TIF: tif/272_1006_2356.tif
# (253, 2)
# [[ 1.20281172e+00  1.54968604e-01  3.85897598e+01]
#  [-1.00187473e-01  1.45780790e+00  1.08305161e+02]
#  [-1.34148868e-04  2.03911768e-04  1.00000000e+00]]
# 旋转角度 (度): -5.477969813907968
# 无人机图像中心点在tif的位置：[373.43394888 431.48301094]
# 无人机图像中心点在地图上的位置：1379.4339488838373,2787.4830109442314
# 无人机图像中心点的经纬度：10.665105040481508, -168.10399442973383
# UAV: uav/060.jpg - TIF: tif/271_856_2356.tif
# (209, 2)
# [[ 1.23621237e+00  1.97626591e-01  1.69436508e+02]
#  [-1.21051289e-01  1.49289858e+00  1.12517036e+02]
#  [-3.50677619e-05  2.15472814e-04  1.00000000e+00]]
# 旋转角度 (度): -6.660257618009533
# 无人机图像中心点在tif的位置：[469.24552571 413.42738545]
# 无人机图像中心点在地图上的位置：1325.2455257137613,2769.4273854510625
# 无人机图像中心点的经纬度：10.665144340112347, -168.10402278676716
# UAV: uav/061.jpg - TIF: tif/271_856_2356.tif
# (230, 2)
# [[ 1.28713691e+00  1.98196575e-01  1.49839691e+02]
#  [ 7.02629685e-02  1.48422647e+00  8.80117188e+01]
#  [-5.39545408e-06  2.34049265e-04  1.00000000e+00]]
# 旋转角度 (度): -2.6430513037670162
# 无人机图像中心点在tif的位置：[448.89732827 447.68229524]
# 无人机图像中心点在地图上的位置：1304.897328267138,2803.6822952387683
# 无人机图像中心点的经纬度：10.665131054518215, -168.1040540759306
# UAV: uav/062.jpg - TIF: tif/271_856_2356.tif
# (233, 2)
# [[ 1.21943891e+00  1.23983242e-01  1.42584000e+02]
#  [-8.16410184e-02  1.41775310e+00  1.10033478e+02]
#  [-7.06443752e-05  1.08325927e-04  1.00000000e+00]]
# 旋转角度 (度): -4.4583837890759295
# 无人机图像中心点在tif的位置：[455.36065826 441.01496042]
# 无人机图像中心点在地图上的位置：1311.3606582620282,2797.0149604213707
# 无人机图像中心点的经纬度：10.665132395195839, -168.10404625665325
# UAV: uav/063.jpg - TIF: tif/271_856_2356.tif
# (232, 2)
# [[ 1.24112177e+00  5.34348115e-02  1.26631050e+02]
#  [-1.94983725e-02  1.34428787e+00  1.02164391e+02]
#  [-1.81002633e-05 -6.40151193e-05  1.00000000e+00]]
# 旋转角度 (度): -1.615858328862142
# 无人机图像中心点在tif的位置：[444.09920263 412.58212856]
# 无人机图像中心点在地图上的位置：1300.0992026336266,2768.582128555116
# 无人机图像中心点的经纬度：10.665157428934547, -168.10403973537717
# UAV: uav/064.jpg - TIF: tif/271_856_2356.tif
# (237, 2)
# [[ 1.25617993e+00  8.83992463e-02  1.10311783e+02]
#  [-6.31175041e-02  1.39893484e+00  1.08525116e+02]
#  [-1.04461233e-05  3.90566456e-05  1.00000000e+00]]
# 旋转角度 (度): -3.266098022431102
# 无人机图像中心点在tif的位置：[418.09109152 436.60181293]
# 无人机图像中心点在地图上的位置：1274.091091520127,2792.601812925303
# 无人机图像中心点的经纬度：10.665153954013434, -168.10406978667515
# UAV: uav/065.jpg - TIF: tif/271_856_2356.tif
# (249, 2)
# [[ 1.22076654e+00  1.10012211e-01  9.75527725e+01]
#  [-9.73253995e-02  1.41533339e+00  1.11980064e+02]
#  [-1.34871356e-04  2.12879910e-04  1.00000000e+00]]
# 旋转角度 (度): -4.497236026642002
# 无人机图像中心点在tif的位置：[402.74833684 408.48724638]
# 无人机图像中心点在地图上的位置：1258.7483368424682,2764.4872463765037
# 无人机图像中心点的经纬度：10.665180800888114, -168.10406624528258
# UAV: uav/066.jpg - TIF: tif/271_856_2356.tif
# (260, 2)
# [[ 1.01665783e+00  1.70412824e-01  1.04181358e+02]
#  [-1.82472482e-01  1.38377154e+00  1.23982437e+02]
#  [-3.41634674e-04  2.32392078e-04  1.00000000e+00]]
# 旋转角度 (度): -8.363105521346387
# 无人机图像中心点在tif的位置：[365.40744371 403.47679124]
# 无人机图像中心点在地图上的位置：1221.4074437146376,2759.4767912383686
# 无人机图像中心点的经纬度：10.665202803472326, -168.10408952416518
# UAV: uav/067.jpg - TIF: tif/271_856_2356.tif
# (273, 2)
# [[1.47497582e+00 7.97589347e-02 3.36811218e+01]
#  [1.05635766e-02 1.46089768e+00 9.35390549e+01]
#  [2.22919480e-04 3.47320274e-05 1.00000000e+00]]
# 旋转角度 (度): -1.3501494901645505
# 无人机图像中心点在tif的位置：[373.23728631 429.03324218]
# 无人机图像中心点在地图上的位置：1229.237286312,2785.033242182183
# 无人机图像中心点的经纬度：10.665181442700732, -168.10409696956307
# UAV: uav/068.jpg - TIF: tif/271_856_2356.tif
# (254, 2)
# [[ 1.24486876e+00  9.21132937e-02  4.68613777e+01]
#  [-5.58712184e-02  1.38198805e+00  9.85644379e+01]
#  [-6.53544848e-05  8.06600146e-05  1.00000000e+00]]
# 旋转角度 (度): -3.2243612668823354
# 无人机图像中心点在tif的位置：[355.69605768 404.07434104]
# 无人机图像中心点在地图上的位置：1211.696057675143,2760.0743410440646
# 无人机图像中心点的经纬度：10.665207226887775, -168.10409653443648
# UAV: uav/069.jpg - TIF: tif/271_856_2356.tif
# (289, 2)
# [[ 1.15057850e+00  6.56646639e-02  4.80928230e+01]
#  [-9.84947979e-02  1.33865225e+00  1.01510460e+02]
#  [-1.54035210e-04  2.39737074e-05  1.00000000e+00]]
# 旋转角度 (度): -3.773071004208073
# 无人机图像中心点在tif的位置：[342.59489901 405.14908831]
# 无人机图像中心点在地图上的位置：1198.5948990080715,2761.149088313103
# 无人机图像中心点的经纬度：10.665213010729913, -168.1041061267775
# UAV: uav/070.jpg - TIF: tif/270_706_2356.tif
# (258, 2)
# [[ 1.15628684e+00  7.55763724e-02  1.82260345e+02]
#  [-8.93581584e-02  1.36804211e+00  9.55395737e+01]
#  [-1.23142556e-04  5.36254447e-05  1.00000000e+00]]
# 旋转角度 (度): -3.7382763770520144
# 无人机图像中心点在tif的位置：[463.11511826 388.49326065]
# 无人机图像中心点在地图上的位置：1169.115118255703,2744.4932606454067
# 无人机图像中心点的经纬度：10.665239060564222, -168.10411811664298
# UAV: uav/071.jpg - TIF: tif/270_706_2356.tif
# (249, 2)
# [[ 1.81151915e+00  2.65756175e-02  9.09480743e+01]
#  [ 2.69996166e-01  1.50872493e+00  2.35588112e+01]
#  [ 5.97940467e-04 -3.89293455e-05  1.00000000e+00]]
# 旋转角度 (度): 4.193083992319468
# 无人机图像中心点在tif的位置：[475.52784131 397.18011489]
# 无人机图像中心点在地图上的位置：1181.527841312678,2753.180114893201
# 无人机图像中心点的经纬度：10.665226948198285, -168.10411391012755
# UAV: uav/072.jpg - TIF: tif/270_706_2356.tif
# (280, 2)
# [[ 1.07944059e+00  1.68057889e-01  1.58306656e+02]
#  [-1.25336304e-01  1.39735508e+00  8.79529800e+01]
#  [-2.42572714e-04  2.34190418e-04  1.00000000e+00]]
# 旋转角度 (度): -6.755614482641908
# 无人机图像中心点在tif的位置：[450.186188   374.65815175]
# 无人机图像中心点在地图上的位置：1156.1861880010397,2730.658151750286
# 无人机图像中心点的经纬度：10.665254948067718, -168.1041200901791
# UAV: uav/073.jpg - TIF: tif/270_706_2356.tif
# (266, 2)
# [[ 1.12116778e+00  2.68931128e-02  1.44661270e+02]
#  [-7.40415081e-02  1.27675569e+00  7.67061768e+01]
#  [-1.70330401e-04 -1.44190099e-05  1.00000000e+00]]
# 旋转角度 (度): -2.4103004165548345
# 无人机图像中心点在tif的位置：[430.6952681 362.4451462]
# 无人机图像中心点在地图上的位置：1136.6952681014138,2718.4451461969347
# 无人机图像中心点的经纬度：10.665272991897057, -168.10412741340366
# UAV: uav/074.jpg - TIF: tif/270_706_2356.tif
# (298, 2)
# [[ 1.12298489e+00  8.48721117e-02  1.27794014e+02]
#  [-1.09424248e-01  1.33662093e+00  7.38958740e+01]
#  [-1.90052931e-04  9.28071458e-05  1.00000000e+00]]
# 旋转角度 (度): -4.516695974652353
# 无人机图像中心点在tif的位置：[414.44683333 365.98939198]
# 无人机图像中心点在地图上的位置：1120.4468333256239,2721.989391979056
# 无人机图像中心点的经纬度：10.665278654024998, -168.10414042245242
# UAV: uav/075.jpg - TIF: tif/270_706_2356.tif
# (280, 2)
# [[ 1.06624675e+00  1.37229696e-01  1.21575043e+02]
#  [-1.31368399e-01  1.36310661e+00  6.68363724e+01]
#  [-2.67972151e-04  2.08128986e-04  1.00000000e+00]]
# 旋转角度 (度): -6.30920334735942
# 无人机图像中心点在tif的位置：[427.52426813 376.55373209]
# 无人机图像中心点在地图上的位置：1133.52426813285,2732.5537320884832
# 无人机图像中心点的经纬度：10.66526492784063, -168.10413670107786
# UAV: uav/076.jpg - TIF: tif/270_706_2356.tif
# (281, 2)
# [[ 1.27269220e+00  7.12183714e-02  8.33745575e+01]
#  [-4.65761572e-02  1.37755811e+00  4.32168045e+01]
#  [-3.13398668e-05  8.33205486e-05  1.00000000e+00]]
# 旋转角度 (度): -2.544925761758145
# 无人机图像中心点在tif的位置：[352.38210314 306.03994158]
# 无人机图像中心点在地图上的位置：1058.3821031360062,2662.03994157717
# 无人机图像中心点的经纬度：10.665350503121493, -168.10415314837576
# UAV: uav/077.jpg - TIF: tif/270_706_2356.tif
# (286, 2)
# [[ 1.23522854e+00  7.48534873e-02  7.28732834e+01]
#  [-9.47502255e-02  1.38010383e+00  4.45792465e+01]
#  [-9.49111054e-05  1.07054097e-04  1.00000000e+00]]
# 旋转角度 (度): -3.710422788091091
# 无人机图像中心点在tif的位置：[383.6030747  350.37633425]
# 无人机图像中心点在地图上的位置：1089.6030746965735,2706.3763342479187
# 无人机图像中心点的经纬度：10.665304669979733, -168.10415387924172
# UAV: uav/078.jpg - TIF: tif/270_706_2356.tif
# (323, 2)
# [[ 1.26783752e+00 -1.85725708e-02  5.98381310e+01]
#  [-2.01043766e-02  1.27569532e+00  1.87293968e+01]
#  [-4.23173333e-05 -7.94844891e-05  1.00000000e+00]]
# 旋转角度 (度): -0.0345055497474966
# 无人机图像中心点在tif的位置：[371.09723289 320.64564608]
# 无人机图像中心点在地图上的位置：1077.0972328874252,2676.6456460833033
# 无人机图像中心点的经纬度：10.665331210035715, -168.10414756473284
# UAV: uav/079.jpg - TIF: tif/270_706_2356.tif
# (306, 2)
# [[ 1.32589829e+00 -9.17211398e-02  4.83381729e+01]
#  [-2.70347297e-02  1.29838586e+00  8.29362488e+00]
#  [ 6.42754749e-05 -2.02096970e-04  1.00000000e+00]]
# 旋转角度 (度): 1.4120071374754066
# 无人机图像中心点在tif的位置：[339.74454391 301.97403857]
# 无人机图像中心点在地图上的位置：1045.7445439140088,2657.974038565901
# 无人机图像中心点的经纬度：10.66535956949008, -168.10415983462732
# UAV: uav/080.jpg - TIF: tif/270_706_2356.tif
# (315, 2)
# [[ 1.31983519e+00 -6.79603219e-02  3.78435745e+01]
#  [-1.27184587e-02  1.28501081e+00 -5.30350542e+00]
#  [ 5.52784441e-05 -1.67516482e-04  1.00000000e+00]]
# 旋转角度 (度): 1.2149091489097827
# 无人机图像中心点在tif的位置：[352.13181379 324.44793506]
# 无人机图像中心点在地图上的位置：1058.1318137911992,2680.4479350642514
# 无人机图像中心点的经纬度：10.66533804767179, -168.10416258081253
# UAV: uav/081.jpg - TIF: tif/270_706_2356.tif
# (316, 2)
# [[ 1.33552206e+00  3.08877993e-02  2.40078068e+01]
#  [-2.54131500e-02  1.37787580e+00 -2.01742382e+01]
#  [ 7.15118513e-05  3.22955639e-05  1.00000000e+00]]
# 旋转角度 (度): -1.1886734369412026
# 无人机图像中心点在tif的位置：[347.09477936 303.70477441]
# 无人机图像中心点在地图上的位置：1053.0947793648324,2659.7047744116203
# 无人机图像中心点的经纬度：10.665354729643942, -168.1041556268346
# UAV: uav/082.jpg - TIF: tif/270_706_2356.tif
# (311, 2)
# [[ 1.18825829e+00 -1.68875590e-01  2.94102211e+01]
#  [-1.10827843e-02  1.10174143e+00 -2.17487431e+01]
#  [-2.07421865e-04 -2.69679469e-04  1.00000000e+00]]
# 旋转角度 (度): 3.9417445777884668
# 无人机图像中心点在tif的位置：[309.87442571 262.27615427]
# 无人机图像中心点在地图上的位置：1015.8744257059434,2618.276154273099
# 无人机图像中心点的经纬度：10.665401560665549, -168.10416050359436
# UAV: uav/083.jpg - TIF: tif/251_706_2206.tif
# (301, 2)
# [[ 1.22619152e+00 -5.65711446e-02  1.45865612e+01]
#  [-5.41095920e-02  1.22185862e+00  1.09707047e+02]
#  [-1.15995477e-04 -1.25824037e-04  1.00000000e+00]]
# 旋转角度 (度): 0.05761178100809265
# 无人机图像中心点在tif的位置：[321.26145347 407.1250925 ]
# 无人机图像中心点在地图上的位置：1027.2614534689362,2613.1250925011714
# 无人机图像中心点的经纬度：10.665399415319705, -168.10415004505802
# UAV: uav/084.jpg - TIF: tif/251_706_2206.tif
# (337, 2)
# [[ 1.25945020e+00  1.53201735e-02  6.71123028e-01]
#  [-4.76810336e-02  1.29769206e+00  9.28273392e+01]
#  [-8.59786378e-05  4.02126971e-05  1.00000000e+00]]
# 旋转角度 (度): -1.4113306221599475
# 无人机图像中心点在tif的位置：[320.49452095 383.25022777]
# 无人机图像中心点在地图上的位置：1026.4945209504604,2589.25022777171
# 无人机图像中心点的经纬度：10.665416112918042, -168.10413856543968
# UAV: uav/085.jpg - TIF: tif/251_706_2206.tif
# (316, 2)
# [[ 1.29719508e+00  2.26429775e-02 -9.59818363e+00]
#  [-3.44511755e-02  1.34543502e+00  7.33714371e+01]
#  [-1.40912925e-05  2.40320605e-05  1.00000000e+00]]
# 旋转角度 (度): -1.2376855775754039
# 无人机图像中心点在tif的位置：[297.98968211 392.74106907]
# 无人机图像中心点在地图上的位置：1003.9896821097316,2598.741069070378
# 无人机图像中心点的经纬度：10.665420824111713, -168.10415888841985
# UAV: uav/086.jpg - TIF: tif/251_706_2206.tif
# (337, 2)
# [[ 1.29283655e+00  5.18446192e-02 -2.01590176e+01]
#  [-3.66006717e-02  1.38000011e+00  5.67177544e+01]
#  [-4.52686363e-05  9.07059875e-05  1.00000000e+00]]
# 旋转角度 (度): -1.8952499279085036
# 无人机图像中心点在tif的位置：[289.00845916 358.18945265]
# 无人机图像中心点在地图上的位置：995.0084591648795,2564.1894526523083
# 无人机图像中心点的经纬度：10.66544890518748, -168.10414771352316
# UAV: uav/087.jpg - TIF: tif/251_706_2206.tif
# (356, 2)
# [[ 1.27527833e+00  4.94664647e-02 -2.47636013e+01]
#  [-3.61489765e-02  1.32912469e+00  4.63114090e+01]
#  [-7.52822962e-05  1.01816957e-04  1.00000000e+00]]
# 旋转角度 (度): -1.88282594204558
# 无人机图像中心点在tif的位置：[293.49541719 343.1251743 ]
# 无人机图像中心点在地图上的位置：999.4954171947786,2549.1251742971713
# 无人机图像中心点的经纬度：10.665456967593277, -168.1041370357771
# UAV: uav/088.jpg - TIF: tif/251_706_2206.tif
# (377, 2)
# [[ 1.31977904e+00  5.32664061e-02 -3.63767776e+01]
#  [-2.30491236e-02  1.38922262e+00  2.52806931e+01]
#  [-8.22691709e-06  1.09274893e-04  1.00000000e+00]]
# 旋转角度 (度): -1.6136577810492898
# 无人机图像中心点在tif的位置：[291.37682349 340.91701393]
# 无人机图像中心点在地图上的位置：997.3768234903407,2546.9170139253492
# 无人机图像中心点的经纬度：10.665459530746459, -168.1041373887909
# UAV: uav/089.jpg - TIF: tif/251_706_2206.tif
# (374, 2)
# [[ 1.22612405e+00 -7.63393342e-02 -2.04341354e+01]
#  [-3.79901044e-02  1.25917423e+00  1.99865818e+01]
#  [-8.93638498e-05 -1.68734186e-04  1.00000000e+00]]
# 旋转角度 (度): 0.8840285597305828
# 无人机图像中心点在tif的位置：[274.9130288  320.21646381]
# 无人机图像中心点在地图上的位置：980.9130288022268,2526.2164638076383
# 无人机图像中心点的经纬度：10.665481868985507, -168.10413835102526
# UAV: uav/090.jpg - TIF: tif/251_706_2206.tif
# (358, 2)
# [[ 1.33962822e+00 -2.51346305e-02 -4.88565636e+01]
#  [-1.76145639e-02  1.34525049e+00 -5.05950165e+00]
#  [ 2.07056582e-05 -4.69039442e-05  1.00000000e+00]]
# 旋转角度 (度): 0.16047911160009198
# 无人机图像中心点在tif的位置：[258.29604425 306.47017107]
# 无人机图像中心点在地图上的位置：964.2960442464911,2512.470171066001
# 无人机图像中心点的经纬度：10.665499530942826, -168.10414291723316
# UAV: uav/091.jpg - TIF: tif/250_556_2206.tif
# (355, 2)
# [[ 1.32416439e+00 -3.34593840e-02  9.72958450e+01]
#  [-1.95431300e-02  1.33584714e+00 -1.91736603e+01]
#  [-5.18107845e-06 -4.48226674e-05  1.00000000e+00]]
# 旋转角度 (度): 0.29974883191622403
# 无人机图像中心点在tif的位置：[411.29685139 270.34845157]
# 无人机图像中心点在地图上的位置：967.2968513937825,2476.34845157232
# 无人机图像中心点的经纬度：10.665522723354183, -168.10412267385902
# UAV: uav/092.jpg - TIF: tif/250_556_2206.tif
# (316, 2)
# [[ 1.30308211e+00  7.12308381e-03  9.63037567e+01]
#  [-1.93915330e-02  1.35822606e+00 -3.79171982e+01]
#  [-2.34862600e-05  2.13359326e-05  1.00000000e+00]]
# 旋转角度 (度): -0.5708190404514555
# 无人机图像中心点在tif的位置：[405.75796954 273.77497347]
# 无人机图像中心点在地图上的位置：961.757969543188,2479.774973465303
# 无人机图像中心点的经纬度：10.665523137560417, -168.10412822436882
# UAV: uav/093.jpg - TIF: tif/250_556_2206.tif
# (316, 2)
# [[ 1.33309662e+00  2.28602476e-02  8.68698425e+01]
#  [-9.97532438e-03  1.35237718e+00 -5.45000229e+01]
#  [ 5.38435688e-06  3.97050098e-05  1.00000000e+00]]
# 旋转角度 (度): -0.7005266440832448
# 无人机图像中心点在tif的位置：[418.13393641 248.45099708]
# 无人机图像中心点在地图上的位置：974.1339364101601,2454.4509970797976
# 无人机图像中心点的经纬度：10.66553428618194, -168.10410693507507
# UAV: uav/094.jpg - TIF: tif/250_556_2206.tif
# (311, 2)
# [[ 1.31843472e+00  8.09132010e-02  7.95419617e+01]
#  [-1.41929602e-02  1.40503478e+00 -7.51779938e+01]
#  [-4.32203451e-05  1.80282004e-04  1.00000000e+00]]
# 旋转角度 (度): -2.0000107313295157
# 无人机图像中心点在tif的位置：[372.95365023 241.81790573]
# 无人机图像中心点在地图上的位置：928.9536502281957,2447.8179057256784
# 无人机图像中心点的经纬度：10.66556129878295, -168.10413481411243
# UAV: uav/095.jpg - TIF: tif/250_556_2206.tif
# (319, 2)
# [[ 1.20458090e+00  5.90296136e-03  1.00233284e+02]
#  [-8.02836418e-02  1.29004765e+00 -5.14728241e+01]
#  [-1.18304706e-04  2.94461915e-05  1.00000000e+00]]
# 旋转角度 (度): -1.9787175385454416
# 无人机图像中心点在tif的位置：[409.72898875 230.09756887]
# 无人机图像中心点在地图上的位置：965.7289887526472,2436.097568866975
# 无人机图像中心点的经纬度：10.66555101073537, -168.10410350992106
# UAV: uav/096.jpg - TIF: tif/231_556_2056.tif
# (368, 2)
# [[1.35864496e+00 3.81975211e-02 7.11561890e+01]
#  [5.74245676e-03 1.38301361e+00 4.61422386e+01]
#  [1.33085287e-05 1.16555340e-04 1.00000000e+00]]
# 旋转角度 (度): -0.678221343730241
# 无人机图像中心点在tif的位置：[392.23118431 370.43143324]
# 无人机图像中心点在地图上的位置：948.2311843144385,2426.4314332422587
# 无人机图像中心点的经纬度：10.66556632261879, -168.1041107370559
# UAV: uav/097.jpg - TIF: tif/231_556_2056.tif
# (405, 2)
# [[ 1.25992346e+00  1.71475168e-02  7.55878372e+01]
#  [-4.17146645e-02  1.34856498e+00  3.42381439e+01]
#  [-9.38822996e-05  5.21415313e-05  1.00000000e+00]]
# 旋转角度 (度): -1.2926958943057258
# 无人机图像中心点在tif的位置：[377.78418881 332.21292472]
# 无人机图像中心点在地图上的位置：933.7841888107066,2388.212924720353
# 无人机图像中心点的经纬度：10.665599629145266, -168.10410149372274
# UAV: uav/098.jpg - TIF: tif/231_556_2056.tif
# (417, 2)
# [[ 1.32862091e+00  8.83140564e-02  5.92698135e+01]
#  [-1.56667959e-02  1.44172788e+00  7.77705860e+00]
#  [-4.52976165e-05  1.74956658e-04  1.00000000e+00]]
# 旋转角度 (度): -2.1495014386426243
# 无人机图像中心点在tif的位置：[402.61669346 349.66616398]
# 无人机图像中心点在地图上的位置：958.6166934613411,2405.666163983994
# 无人机图像中心点的经纬度：10.665575346159743, -168.10409311609968
# UAV: uav/099.jpg - TIF: tif/231_556_2056.tif
# (412, 2)
# [[ 1.24530387e+00  1.87595874e-01  6.86195908e+01]
#  [-5.60578294e-02  1.48684025e+00  9.06812072e-01]
#  [-1.31020483e-04  3.49363661e-04  1.00000000e+00]]
# 旋转角度 (度): -5.09617881851911
# 无人机图像中心点在tif的位置：[375.46926332 316.01026476]
# 无人机图像中心点在地图上的位置：931.4692633212549,2372.01026476344
# 无人机图像中心点的经纬度：10.665611853770594, -168.10409494273918
# UAV: uav/100.jpg - TIF: tif/231_556_2056.tif
# (387, 2)
# [[ 1.29060578e+00  1.11054871e-02  6.29963608e+01]
#  [-9.66690388e-03  1.35526025e+00 -1.81582794e+01]
#  [-5.85766975e-05  4.12002228e-05  1.00000000e+00]]
# 旋转角度 (度): -0.4498133565914898
# 无人机图像中心点在tif的位置：[374.79345145 303.94322597]
# 无人机图像中心点在地图上的位置：930.7934514513292,2359.943225974351
# 无人机图像中心点的经纬度：10.665620436579246, -168.10408933959945
# UAV: uav/101.jpg - TIF: tif/212_556_1906.tif
# (428, 2)
# [[ 1.20961201e+00  1.72576576e-03  6.68511887e+01]
#  [-6.52883500e-02  1.34536457e+00  1.18595818e+02]
#  [-1.74678658e-04  2.65978688e-05  1.00000000e+00]]
# 旋转角度 (度): -1.5024583378043683
# 无人机图像中心点在tif的位置：[344.30718739 526.34682675]
# 无人机图像中心点在地图上的位置：900.3071873914764,2432.3468267460266
# 无人机图像中心点的经纬度：10.665586124829959, -168.10414682399525
# UAV: uav/102.jpg - TIF: tif/212_556_1906.tif
# (431, 2)
# [[ 1.25187051e+00  4.74112704e-02  5.82695847e+01]
#  [-4.40372415e-02  1.38930511e+00  1.00252678e+02]
#  [-1.27115360e-04  1.22939513e-04  1.00000000e+00]]
# 旋转角度 (度): -1.9830265805185963
# 无人机图像中心点在tif的位置：[391.53418063 400.59849134]
# 无人机图像中心点在地图上的位置：947.5341806270726,2306.598491335833
# 无人机图像中心点的经纬度：10.66564856259167, -168.10405093926423
# UAV: uav/103.jpg - TIF: tif/212_556_1906.tif
# (396, 2)
# [[ 1.18976998e+00  6.97872415e-02  5.86581612e+01]
#  [-7.09165931e-02  1.37246585e+00  8.82840118e+01]
#  [-2.21238704e-04  1.63331584e-04  1.00000000e+00]]
# 旋转角度 (度): -3.1432106122066683
# 无人机图像中心点在tif的位置：[329.43522025 402.27813057]
# 无人机图像中心点在地图上的位置：885.4352202470607,2308.2781305678122
# 无人机图像中心点的经纬度：10.665678312571435, -168.10409468904714
# UAV: uav/104.jpg - TIF: tif/212_556_1906.tif
# (455, 2)
# [[ 1.14105392e+00  3.78855839e-02  6.41700974e+01]
#  [-9.78592187e-02  1.35091472e+00  7.69412460e+01]
#  [-2.92575802e-04  1.51764136e-04  1.00000000e+00]]
# 旋转角度 (度): -3.117986729793816
# 无人机图像中心点在tif的位置：[363.66093527 370.26943925]
# 无人机图像中心点在地图上的位置：919.6609352695975,2276.2694392515014
# 无人机图像中心点的经纬度：10.665683157825006, -168.10405494072089
# UAV: uav/105.jpg - TIF: tif/212_556_1906.tif
# (482, 2)
# [[ 1.18810987e+00 -2.34167129e-02  6.08608513e+01]
#  [-5.58214225e-02  1.31176484e+00  5.88838539e+01]
#  [-1.89993792e-04  3.53229698e-05  1.00000000e+00]]
# 旋转角度 (度): -0.7426568658350019
# 无人机图像中心点在tif的位置：[339.37926946 358.92916931]
# 无人机图像中心点在地图上的位置：895.3792694612271,2264.929169312798
# 无人机图像中心点的经纬度：10.665702989264961, -168.1040660126635
# UAV: uav/106.jpg - TIF: tif/212_556_1906.tif
# (478, 2)
# [[ 1.11041248e+00  1.78574529e-02  6.22101860e+01]
#  [-1.06684558e-01  1.32961929e+00  4.84385986e+01]
#  [-2.16004555e-04  5.77947467e-05  1.00000000e+00]]
# 旋转角度 (度): -2.9219064681803313
# 无人机图像中心点在tif的位置：[344.2357615  334.11941753]
# 无人机图像中心点在地图上的位置：900.2357614961516,2240.119417525722
# 无人机图像中心点的经纬度：10.665717527694135, -168.10405017713188
# UAV: uav/107.jpg - TIF: tif/212_556_1906.tif
# (478, 2)
# [[ 1.13457441e+00 -3.68956998e-02  6.09896164e+01]
#  [-9.14601088e-02  1.29452407e+00  3.18322086e+01]
#  [-2.67503608e-04  1.30221042e-06  1.00000000e+00]]
# 旋转角度 (度): -1.2868085415255524
# 无人机图像中心点在tif的位置：[324.6286313  343.79638278]
# 无人机图像中心点在地图上的位置：880.6286313006699,2249.796382777087
# 无人机图像中心点的经纬度：10.665720670251796, -168.10406859175012
# UAV: uav/108.jpg - TIF: tif/212_556_1906.tif
# (507, 2)
# [[ 1.23181939e+00 -1.47871291e-02  4.66470985e+01]
#  [-3.92223336e-02  1.31717134e+00  1.00798025e+01]
#  [-1.44680118e-04  3.17001250e-05  1.00000000e+00]]
# 旋转角度 (度): -0.5492335412744613
# 无人机图像中心点在tif的位置：[361.83143205 328.79303501]
# 无人机图像中心点在地图上的位置：917.8314320456225,2234.79303501008
# 无人机图像中心点的经纬度：10.665712412796704, -168.10403534075687
# UAV: uav/109.jpg - TIF: tif/212_556_1906.tif
# (492, 2)
# [[ 1.22248018e+00  2.48234649e-03  4.18278198e+01]
#  [-7.36599267e-02  1.32277417e+00 -2.54277349e+00]
#  [-1.61754739e-04  2.48565029e-05  1.00000000e+00]]
# 旋转角度 (度): -1.7135144766453982
# 无人机图像中心点在tif的位置：[347.07419809 302.18699899]
# 无人机图像中心点在地图上的位置：903.074198089128,2208.18699899232
# 无人机图像中心点的经纬度：10.665737937785954, -168.10403215293235
# UAV: uav/110.jpg - TIF: tif/193_556_1756.tif
# (474, 2)
# [[ 1.31525946e+00 -8.18566512e-03  3.26856499e+01]
#  [-3.33630256e-02  1.35147727e+00  1.28130966e+02]
#  [-2.91344568e-05  5.44743161e-05  1.00000000e+00]]
# 旋转角度 (度): -0.5409284032818346
# 无人机图像中心点在tif的位置：[354.34433856 434.60864481]
# 无人机图像中心点在地图上的位置：910.3443385596778,2190.608644809654
# 无人机图像中心点的经纬度：10.665746333351784, -168.10401828739978
# UAV: uav/111.jpg - TIF: tif/193_556_1756.tif
# (497, 2)
# [[ 1.18730807e+00 -2.59733256e-02  4.20539894e+01]
#  [-1.01485640e-01  1.29009843e+00  1.18666138e+02]
#  [-1.72703687e-04 -2.41569560e-05  1.00000000e+00]]
# 旋转角度 (度): -1.7458571238853218
# 无人机图像中心点在tif的位置：[315.79151456 433.3885555 ]
# 无人机图像中心点在地图上的位置：871.7915145562645,2189.3885555022157
# 无人机图像中心点的经纬度：10.665766349584823, -168.10404431017204
# UAV: uav/112.jpg - TIF: tif/193_556_1756.tif
# (520, 2)
# [[ 1.23249710e+00 -2.84916591e-02  3.55986252e+01]
#  [-5.14722355e-02  1.29970074e+00  9.88348541e+01]
#  [-1.21491961e-04 -2.57703468e-05  1.00000000e+00]]
# 旋转角度 (度): -0.5199648596282127
# 无人机图像中心点在tif的位置：[334.1123212  389.32983309]
# 无人机图像中心点在地图上的位置：890.1123212004411,2145.329833089091
# 无人机图像中心点的经纬度：10.665787343215573, -168.10400948900767
# UAV: uav/113.jpg - TIF: tif/193_556_1756.tif
# (526, 2)
# [[ 1.05627763e+00 -2.84948125e-02  4.87954674e+01]
#  [-1.64639324e-01  1.23825538e+00  9.67663651e+01]
#  [-3.72684066e-04 -6.43099338e-05  1.00000000e+00]]
# 旋转角度 (度): -3.3956239020785377
# 无人机图像中心点在tif的位置：[331.77876671 392.09866555]
# 无人机图像中心点在地图上的位置：887.7787667102727,2148.0986655471497
# 无人机图像中心点的经纬度：10.665786612111006, -168.10401249410637
# UAV: uav/114.jpg - TIF: tif/193_556_1756.tif
# (528, 2)
# [[ 1.21920717e+00 -3.17146666e-02  3.06779099e+01]
#  [-5.87406196e-02  1.28330004e+00  6.97819977e+01]
#  [-1.38601055e-04 -4.60631381e-05  1.00000000e+00]]
# 旋转角度 (度): -0.6187446090262426
# 无人机图像中心点在tif的位置：[323.12243622 371.1563149 ]
# 无人机图像中心点在地图上的位置：879.1224362173488,2127.156314903524
# 无人机图像中心点的经纬度：10.66580523101662, -168.1040079400561
# UAV: uav/115.jpg - TIF: tif/193_556_1756.tif
# (562, 2)
# [[ 1.23682380e+00 -2.94238359e-01  5.54907608e+01]
#  [ 1.25194350e-02  9.53270197e-01  8.11794891e+01]
#  [ 2.53939265e-06 -4.72380256e-04  1.00000000e+00]]
# 旋转角度 (度): 7.973321456728694
# 无人机图像中心点在tif的位置：[297.09516912 343.90577395]
# 无人机图像中心点在地图上的位置：853.0951691158755,2099.905773948448
# 无人机图像中心点的经纬度：10.665836804072377, -168.10401221445468
# UAV: uav/116.jpg - TIF: tif/193_556_1756.tif
# (570, 2)
# [[ 1.28494835e+00 -1.45149857e-01  3.97011871e+01]
#  [ 3.40809375e-02  1.14532387e+00  5.19845200e+01]
#  [ 3.45537264e-05 -2.23975469e-04  1.00000000e+00]]
# 旋转角度 (度): 4.217885822955062
# 无人机图像中心点在tif的位置：[338.53750911 341.86289985]
# 无人机图像中心点在地图上的位置：894.5375091123981,2097.8628998509794
# 无人机图像中心点的经纬度：10.665817579869735, -168.1039825539484
# UAV: uav/117.jpg - TIF: tif/193_556_1756.tif
# (589, 2)
# [[ 1.36721396e+00 -1.39119640e-01  2.44211292e+01]
#  [ 6.93931878e-02  1.18550742e+00  2.59319973e+01]
#  [ 1.30778892e-04 -2.33450701e-04  1.00000000e+00]]
# 旋转角度 (度): 4.669699119188971
# 无人机图像中心点在tif的位置：[328.14535607 318.08024266]
# 无人机图像中心点在地图上的位置：884.145356071251,2074.0802426575738
# 无人机图像中心点的经纬度：10.66583900348456, -168.10397777036079
# UAV: uav/118.jpg - TIF: tif/193_556_1756.tif
# (606, 2)
# [[ 1.45430326e+00 -5.86786345e-02 -2.02561975e+00]
#  [ 1.13672696e-01  1.31801546e+00 -1.42241020e+01]
#  [ 1.84589226e-04 -8.46305484e-05  1.00000000e+00]]
# 旋转角度 (度): 3.5574232767006326
# 无人机图像中心点在tif的位置：[311.66635167 303.2219333 ]
# 无人机图像中心点在地图上的位置：867.666351669675,2059.221933303733
# 无人机图像中心点的经纬度：10.665857356911, -168.10398168150755
# UAV: uav/119.jpg - TIF: tif/193_556_1756.tif
# (610, 2)
# [[ 1.32371509e+00 -2.61574183e-02  2.84374771e+01]
#  [ 2.26745065e-02  1.24450171e+00  6.30700684e+00]
#  [ 8.67804702e-05 -2.02707997e-05  1.00000000e+00]]
# 旋转角度 (度): 1.0892873600886142
# 无人机图像中心点在tif的位置：[319.82761982 312.44480794]
# 无人机图像中心点在地图上的位置：875.827619818583,2068.4448079365593
# 无人机图像中心点的经纬度：10.665846993311652, -168.10398068230052
# UAV: uav/120.jpg - TIF: tif/193_556_1756.tif
# (587, 2)
# [[ 1.57399035e+00 -7.05440864e-02 -2.25594673e+01]
#  [ 1.08661629e-01  1.34738624e+00 -4.94999084e+01]
#  [ 3.24325461e-04 -1.13454596e-04  1.00000000e+00]]
# 旋转角度 (度): 3.510290740767341
# 无人机图像中心点在tif的位置：[321.47709929 272.80179248]
# 无人机图像中心点在地图上的位置：877.4770992931469,2028.8017924813619
# 无人机图像中心点的经纬度：10.665873264217495, -168.10395960061754
# UAV: uav/121.jpg - TIF: tif/193_556_1756.tif
# (579, 2)
# [[ 1.18627799e+00 -7.81983659e-02  4.85726585e+01]
#  [-5.86295826e-03  1.17045677e+00 -1.25408859e+01]
#  [-5.45399889e-05 -1.16551950e-04  1.00000000e+00]]
# 旋转角度 (度): 1.7580310341261673
# 无人机图像中心点在tif的位置：[302.12095732 256.911433  ]
# 无人机图像中心点在地图上的位置：858.1209573211585,2012.9114329995414
# 无人机图像中心点的经纬度：10.665893754524655, -168.10396498039776
# UAV: uav/122.jpg - TIF: tif/193_556_1756.tif
# (575, 2)
# [[ 1.47808194e+00 -8.34716037e-02 -1.11464748e+01]
#  [ 9.90360603e-02  1.29731965e+00 -7.59872818e+01]
#  [ 2.31085782e-04 -1.75033609e-04  1.00000000e+00]]
# 旋转角度 (度): 3.7622970027944818
# 无人机图像中心点在tif的位置：[320.24592244 266.95589223]
# 无人机图像中心点在地图上的位置：876.2459224439294,2022.9558922282908
# 无人机图像中心点的经纬度：10.665877871837328, -168.10395751051647
# UAV: uav/123.jpg - TIF: tif/174_556_1606.tif
# (603, 2)
# [[ 1.29162383e+00 -4.56587039e-02  2.53934021e+01]
#  [ 4.36641835e-02  1.24278772e+00  8.55160294e+01]
#  [ 4.82028845e-05 -6.95849812e-05  1.00000000e+00]]
# 旋转角度 (度): 2.0184989359668553
# 无人机图像中心点在tif的位置：[314.52330426 383.49679434]
# 无人机图像中心点在地图上的位置：870.5233042588876,1989.496794336944
# 无人机图像中心点的经纬度：10.665903584811552, -168.10394463297587
# UAV: uav/124.jpg - TIF: tif/174_556_1606.tif
# (586, 2)
# [[ 1.50560582e+00 -6.77188709e-02 -1.71811790e+01]
#  [ 1.43900067e-01  1.30477238e+00  3.89108658e+01]
#  [ 2.63405294e-04 -1.21906814e-04  1.00000000e+00]]
# 旋转角度 (度): 4.306194033343536
# 无人机图像中心点在tif的位置：[279.5333121  365.89754344]
# 无人机图像中心点在地图上的位置：835.5333121042268,1971.8975434379383
# 无人机图像中心点的经纬度：10.66593302191408, -168.1039599546078
# UAV: uav/125.jpg - TIF: tif/174_556_1606.tif
# (565, 2)
# ...
# 无人机图像中心点在地图上的位置：2699.836825068007,2085.3166068023747
# 无人机图像中心点的经纬度：10.664927931021577, -168.1027290034344
# UAV: uav/389.jpg - TIF: tif/205_2356_1756.tif
# (335, 2)
# [[ 1.30724323e+00 -1.24694854e-02  3.45390701e+01]
#  [ 1.96276512e-02  1.30779493e+00  6.58660660e+01]
#  [ 7.76732122e-06  4.58724935e-06  1.00000000e+00]]
# 旋转角度 (度): 0.7032165530578133
# 无人机图像中心点在tif的位置：[341.45109651 385.94134198]
# 无人机图像中心点在地图上的位置：2697.451096509284,2141.941341983659
# 无人机图像中心点的经纬度：10.664890424498632, -168.10275913388026
# UAV: uav/390.jpg - TIF: tif/205_2356_1756.tif
# (306, 2)
# [[ 1.30320251e+00 -1.76792573e-02  3.83739929e+01]
#  [ 1.84246898e-02  1.30546927e+00  8.02563019e+01]
#  [-2.85738679e-06 -1.43567531e-05  1.00000000e+00]]
# 旋转角度 (度): 0.7929214179629487
# 无人机图像中心点在tif的位置：[337.29393743 371.96744339]
# 无人机图像中心点在地图上的位置：2693.293937432802,2127.9674433905775
# 无人机图像中心点的经纬度：10.664902041623973, -168.10275497697228
# UAV: uav/391.jpg - TIF: tif/205_2356_1756.tif
# (308, 2)
# [[ 1.29683280e+00 -5.41696586e-02  4.54349861e+01]
#  [ 2.28362773e-02  1.24641252e+00  9.93936462e+01]
#  [ 4.26116344e-07 -7.42885386e-05  1.00000000e+00]]
# 旋转角度 (度): 1.7343067540221149
# 无人机图像中心点在tif的位置：[344.45957754 396.18729738]
# 无人机图像中心点在地图上的位置：2700.4595775445027,2152.18729737597
# 无人机图像中心点的经纬度：10.664881926298264, -168.1027622091888
# UAV: uav/392.jpg - TIF: tif/205_2356_1756.tif
# (331, 2)
# [[1.34626710e+00 6.42543882e-02 3.62102623e+01]
#  [2.59225611e-02 1.35320866e+00 1.11103912e+02]
#  [5.16772234e-05 6.06366884e-05 1.00000000e+00]]
# 旋转角度 (度): -0.8135299271786506
# 无人机图像中心点在tif的位置：[335.81088577 414.12560103]
# 无人机图像中心点在地图上的位置：2691.8108857691054,2170.1256010285706
# 无人机图像中心点的经纬度：10.664873971425175, -168.10277720706623
# UAV: uav/393.jpg - TIF: tif/205_2356_1756.tif
# (295, 2)
# [[ 1.17142570e+00 -1.23755984e-01  6.75334930e+01]
#  [-2.49256529e-02  1.09910011e+00  1.43574677e+02]
#  [-1.50444626e-04 -1.64527213e-04  1.00000000e+00]]
# 旋转角度 (度): 2.4923692605203724
# 无人机图像中心点在tif的位置：[328.52308579 438.82692074]
# 无人机图像中心点在地图上的位置：2684.523085794931,2194.826920740221
# 无人机图像中心点的经纬度：10.664860718055937, -168.1027946665563
# UAV: uav/394.jpg - TIF: tif/205_2356_1756.tif
# (316, 2)
# [[ 1.26394451e+00 -2.09210590e-02  5.30298462e+01]
#  [ 1.19971819e-02  1.26011336e+00  1.46185852e+02]
#  [-4.81409043e-05 -3.12335615e-05  1.00000000e+00]]
# 旋转角度 (度): 0.7471973502967797
# 无人机图像中心点在tif的位置：[323.50384538 488.74991167]
# 无人机图像中心点在地图上的位置：2679.503845381453,2244.7499116736176
# 无人机图像中心点的经纬度：10.664829101138519, -168.10282324522464
# UAV: uav/395.jpg - TIF: tif/205_2356_1756.tif
# (273, 2)
# [[ 1.37130547e+00 -1.49101377e-01  4.74669151e+01]
#  [ 6.96413293e-02  1.16526115e+00  1.61732300e+02]
#  [ 1.13721500e-04 -2.50274257e-04  1.00000000e+00]]
# 旋转角度 (度): 4.928750512246263
# 无人机图像中心点在tif的位置：[335.08151837 468.14975079]
# 无人机图像中心点在地图上的位置：2691.0815183730215,2224.1497507925933
# 无人机图像中心点的经纬度：10.66483741776322, -168.1028048849807
# UAV: uav/396.jpg - TIF: tif/205_2356_1756.tif
# (286, 2)
# [[ 1.41078830e+00 -1.18489966e-01  3.90811806e+01]
#  [ 8.07213113e-02  1.20994103e+00  1.73927734e+02]
#  [ 1.51592903e-04 -2.18471469e-04  1.00000000e+00]]
# 旋转角度 (度): 4.34690358539197
# 无人机图像中心点在tif的位置：[357.8373422  483.39713363]
# 无人机图像中心点在地图上的位置：2713.837342195216,2239.3971336330424
# 无人机图像中心点的经纬度：10.66481567710319, -168.1027968335235
# UAV: uav/397.jpg - TIF: tif/224_2356_1906.tif
# (277, 2)
# [[ 1.34873343e+00 -8.77436623e-02  4.40002861e+01]
#  [ 1.46714952e-02  1.26936626e+00  4.55990677e+01]
#  [ 5.90458731e-05 -1.35186434e-04  1.00000000e+00]]
# 旋转角度 (度): 2.240161422061975
# 无人机图像中心点在tif的位置：[376.32047828 354.11674908]
# 无人机图像中心点在地图上的位置：2732.3204782819876,2260.1167490777393
# 无人机图像中心点的经纬度：10.664792322872191, -168.10279448634628
# UAV: uav/398.jpg - TIF: tif/224_2356_1906.tif
# (262, 2)
# [[1.41823053e+00 8.00412372e-02 2.80793686e+01]
#  [3.68757136e-02 1.41821110e+00 5.23023491e+01]
#  [1.22995320e-04 1.24578743e-04 1.00000000e+00]]
# 旋转角度 (度): -0.871871075934609
# 无人机图像中心点在tif的位置：[371.90453097 384.35430185]
# 无人机图像中心点在地图上的位置：2727.9045309667213,2290.354301845376
# 无人机图像中心点的经纬度：10.664773857545148, -168.10281274641852
# UAV: uav/399.jpg - TIF: tif/224_2356_1906.tif
# (228, 2)
# [[ 1.26623952e+00 -1.49108404e-02  4.69401894e+01]
#  [-3.99837270e-03  1.25666380e+00  8.00520859e+01]
#  [-5.29761055e-05 -1.47493593e-05  1.00000000e+00]]
# 旋转角度 (度): 0.24782338661445727
# 无人机图像中心点在tif的位置：[333.89163021 386.70224571]
# 无人机图像中心点在地图上的位置：2689.8916302130315,2292.702245713444
# 无人机图像中心点的经纬度：10.664791165412245, -168.1028401886319
# UAV: uav/400.jpg - TIF: tif/224_2356_1906.tif
# (228, 2)
# [[ 1.23226869e+00  1.00011602e-01  4.69235802e+01]
#  [-6.01335578e-02  1.38848352e+00  1.01005440e+02]
#  [-9.59215540e-05  1.57244474e-04  1.00000000e+00]]
# 旋转角度 (度): -3.4968001093223244
# 无人机图像中心点在tif的位置：[357.75818433 419.8336978 ]
# 无人机图像中心点在地图上的位置：2713.758184325843,2325.8336978034044
# 无人机图像中心点的经纬度：10.664756651337347, -168.10284036532553
# UAV: uav/401.jpg - TIF: tif/224_2356_1906.tif
# (214, 2)
# [[1.45604837e+00 1.03662193e-01 2.03757973e+01]
#  [4.38084677e-02 1.40355289e+00 1.08191589e+02]
#  [1.90641818e-04 1.13249022e-04 1.00000000e+00]]
# 旋转角度 (度): -1.1990710800394446
# 无人机图像中心点在tif的位置：[300.16275355 381.50357823]
# 无人机图像中心点在地图上的位置：2656.1627535493735,2287.5035782267973
# 无人机图像中心点的经纬度：10.664811498777231, -168.102860875361
# UAV: uav/402.jpg - TIF: tif/224_2356_1906.tif
# (200, 2)
# [[ 1.06547201e+00 -9.81774405e-02  8.82455521e+01]
#  [-1.10589169e-01  1.08488655e+00  1.73680847e+02]
#  [-1.98203459e-04 -1.51423286e-04  1.00000000e+00]]
# 旋转角度 (度): -0.3307038074833207
# 无人机图像中心点在tif的位置：[338.04492708 440.26451142]
# 无人机图像中心点在地图上的位置：2694.0449270780214,2346.2645114151683
# 无人机图像中心点的经纬度：10.664752497988685, -168.1028642608039
# UAV: uav/403.jpg - TIF: tif/224_2356_1906.tif
# (197, 2)
# [[ 1.07508647e+00 -9.62579027e-02  8.51876678e+01]
#  [-1.08390674e-01  1.09963953e+00  1.86955460e+02]
#  [-1.86269463e-04 -1.41548080e-04  1.00000000e+00]]
# 旋转角度 (度): -0.31964917645142776
# 无人机图像中心点在tif的位置：[347.15284383 459.01250489]
# 无人机图像中心点在地图上的位置：2703.1528438293367,2365.0125048927525
# 无人机图像中心点的经纬度：10.664735155402003, -168.10286739868144
# UAV: uav/404.jpg - TIF: tif/224_2356_1906.tif
# (173, 2)
# [[ 1.11538076e+00 -5.67992665e-02  7.22146912e+01]
#  [-9.89119411e-02  1.17819190e+00  1.92015472e+02]
#  [-1.66003301e-04 -6.30483337e-05  1.00000000e+00]]
# 旋转角度 (度): -1.0518992729962153
# 无人机图像中心点在tif的位置：[340.74330942 482.0499905 ]
# 无人机图像中心点在地图上的位置：2696.7433094228004,2388.049990501709
# 无人机图像中心点的经纬度：10.664722601894107, -168.10288341438277
# UAV: uav/405.jpg - TIF: tif/224_2356_1906.tif
# (178, 2)
# [[ 1.13474357e+00 -1.97039340e-02  6.05820084e+01]
#  [-9.87774134e-02  1.21901608e+00  2.05086105e+02]
#  [-1.56451119e-04 -1.51808299e-05  1.00000000e+00]]
# 旋转角度 (度): -1.924101897258982
# 无人机图像中心点在tif的位置：[344.68712233 505.72070604]
# 无人机图像中心点在地图上的位置：2700.6871223346766,2411.720706038061
# 无人机图像中心点的经纬度：10.664704464662174, -168.10289259594208
# UAV: uav/406.jpg - TIF: tif/243_2356_2056.tif
# (175, 2)
# [[ 1.19228137e+00  7.70873623e-03  4.73002396e+01]
#  [-5.75935952e-02  1.27353418e+00  6.16503906e+01]
#  [-1.00439705e-04  2.97101724e-05  1.00000000e+00]]
# 旋转角度 (度): -1.51701275783212
# 无人机图像中心点在tif的位置：[335.01330018 346.623264  ]
# 无人机图像中心点在地图上的位置：2691.0133001812264,2402.623263996176
# 无人机图像中心点的经纬度：10.664715494212299, -168.10289470320112
# UAV: uav/407.jpg - TIF: tif/243_2356_2056.tif
# (132, 2)
# [[ 1.43353474e+00 -4.78150696e-02  3.53587379e+01]
#  [ 1.22402899e-01  1.23743451e+00  7.47806473e+01]
#  [ 4.54770401e-04 -1.35802664e-04  1.00000000e+00]]
# 旋转角度 (度): 3.6464665641520333
# 无人机图像中心点在tif的位置：[345.39971725 372.83895274]
# 无人机图像中心点在地图上的位置：2701.39971724559,2428.838952740282
# 无人机图像中心点的经纬度：10.664692412572496, -168.10290071395198
# UAV: uav/408.jpg - TIF: tif/243_2356_2056.tif
# (158, 2)
# [[ 1.23279309e+00  2.84179132e-02  3.44992981e+01]
#  [-5.20127155e-02  1.30090868e+00  9.42076569e+01]
#  [-6.51966111e-05  9.52288538e-05  1.00000000e+00]]
# 旋转角度 (度): -1.8182047326248663
# 无人机图像中心点在tif的位置：[335.45596447 386.0752094 ]
# 无人机图像中心点在地图上的位置：2691.455964468734,2442.075209397516
# 无人机图像中心点的经纬度：10.66468831492373, -168.10291424132726
# UAV: uav/409.jpg - TIF: tif/243_2356_2056.tif
# (152, 2)
# [[ 1.29845989e+00 -2.72693858e-02  3.53713570e+01]
#  [ 7.55259469e-02  1.25128281e+00  1.07057518e+02]
#  [ 1.38053831e-04 -3.07039477e-06  1.00000000e+00]]
# 旋转角度 (度): 2.3086842495977034
# 无人机图像中心点在tif的位置：[327.55394583 410.74906111]
# 无人机图像中心点在地图上的位置：2683.5539458346793,2466.7490611094763
# 无人机图像中心点的经纬度：10.664675385696306, -168.10293211114976
# UAV: uav/410.jpg - TIF: tif/243_2356_2056.tif
# (150, 2)
# [[ 1.30307412e+00 -7.90961087e-03  2.47010422e+01]
#  [ 4.95529287e-02  1.24338663e+00  1.21653992e+02]
#  [-2.37811910e-05  9.33121464e-06  1.00000000e+00]]
# 旋转角度 (度): 1.2926970642258164
# 无人机图像中心点在tif的位置：[347.82457224 419.13969497]
# 无人机图像中心点在地图上的位置：2703.8245722395304,2475.1396949663676
# 无人机图像中心点的经纬度：10.664659567045225, -168.10292232749467
# UAV: uav/411.jpg - TIF: tif/243_2356_2056.tif
# (153, 2)
# [[ 1.26053917e+00 -2.51049735e-02  2.61937733e+01]
#  [ 4.53861915e-02  1.20642233e+00  1.38718399e+02]
#  [-1.01881951e-05 -8.16290922e-05  1.00000000e+00]]
# 旋转角度 (度): 1.6367290556360425
# 无人机图像中心点在tif的位置：[331.04305611 431.87495238]
# 无人机图像中心点在地图上的位置：2687.043056111069,2487.8749523842043
# 无人机图像中心点的经纬度：10.664659213626392, -168.10294032676134
# UAV: uav/412.jpg - TIF: tif/243_2356_2056.tif
# (151, 2)
# [[ 1.45111322e+00 -1.39575705e-01  4.69709778e+00]
#  [ 1.97976455e-01  9.49873686e-01  1.49302795e+02]
#  [ 1.18368276e-04 -5.91062941e-04  1.00000000e+00]]
# 旋转角度 (度): 8.002701783371824
# 无人机图像中心点在tif的位置：[349.04217099 485.03619318]
# 无人机图像中心点在地图上的位置：2705.0421709876673,2541.0361931834123
# 无人机图像中心点的经纬度：10.66461393152369, -168.102954631394
# UAV: uav/413.jpg - TIF: tif/243_2356_2056.tif
# (147, 2)
# [[ 1.41777003e+00 -2.51467209e-02  5.99442434e+00]
#  [ 1.57839939e-01  1.25277650e+00  1.63720795e+02]
#  [ 3.16169695e-04 -6.90175584e-05  1.00000000e+00]]
# 旋转角度 (度): 3.919797361317609
# 无人机图像中心点在tif的位置：[319.01236103 447.70655272]
# 无人机图像中心点在地图上的位置：2675.012361029006,2503.706552715761
# 无人机图像中心点的经纬度：10.66465438072168, -168.10295660133266
# UAV: uav/414.jpg - TIF: tif/261_2206_2206.tif
# (205, 2)
# [[ 1.36757100e+00 -8.01266730e-02  1.64213089e+02]
#  [ 1.22382224e-01  1.21841300e+00  3.09927006e+01]
#  [ 3.25457106e-04 -1.86502977e-04  1.00000000e+00]]
# 旋转角度 (度): 4.477705120984647
# 无人机图像中心点在tif的位置：[466.36184377 343.83899079]
# 无人机图像中心点在地图上的位置：2672.3618437713785,2549.8389907867436
# 无人机图像中心点的经纬度：10.66462417516842, -168.102981636476
# UAV: uav/415.jpg - TIF: tif/261_2206_2206.tif
# (194, 2)
# [[ 2.05505490e+00  6.10669702e-02  1.12920937e+02]
#  [ 5.28902471e-01  1.54978359e+00 -7.94954014e+00]
#  [ 1.41433417e-03  1.46830251e-04  1.00000000e+00]]
# 旋转角度 (度): 7.394509340476973
# 无人机图像中心点在tif的位置：[440.32609598 340.57696885]
# 无人机图像中心点在地图上的位置：2646.3260959813038,2546.576968849129
# 无人机图像中心点的经纬度：10.664639357444871, -168.10299798270066
# UAV: uav/416.jpg - TIF: tif/261_2206_2206.tif
# (200, 2)
# [[1.31204486e+00 4.41862755e-02 1.51515106e+02]
#  [4.10627015e-02 1.33920467e+00 6.20572433e+01]
#  [1.07947955e-04 1.61489879e-04 1.00000000e+00]]
# 旋转角度 (度): -0.06750308492288333
# 无人机图像中心点在tif的位置：[432.79327158 328.64253342]
# 无人机图像中心点在地图上的位置：2638.793271583013,2534.6425334226014
# 无人机图像中心点的经纬度：10.66465126046444, -168.10299718393986
# UAV: uav/417.jpg - TIF: tif/261_2206_2206.tif
# (202, 2)
# [[ 1.30716431e+00 -2.97740381e-03  1.45626358e+02]
#  [ 4.53921184e-02  1.26107728e+00  8.01273575e+01]
#  [ 5.43085698e-05 -6.76252921e-06  1.00000000e+00]]
# 旋转角度 (度): 1.0789646414113916
# 无人机图像中心点在tif的位置：[469.7630255  373.89621327]
# 无人机图像中心点在地图上的位置：2675.7630255025524,2579.896213268207
# 无人机图像中心点的经纬度：10.664601943644481, -168.10299440509993
# UAV: uav/418.jpg - TIF: tif/261_2206_2206.tif
# (235, 2)
# [[ 1.25502586e+00  1.14902426e-02  1.43155380e+02]
#  [ 1.06381048e-02  1.27202833e+00  9.64864731e+01]
#  [-6.59039215e-05  4.42697965e-05  1.00000000e+00]]
# 旋转角度 (度): -0.01932047918280143
# 无人机图像中心点在tif的位置：[429.72253561 400.39225292]
# 无人机图像中心点在地图上的位置：2635.7225356070294,2606.3922529157744
# 无人机图像中心点的经纬度：10.664603758458133, -168.10303539450786
# UAV: uav/419.jpg - TIF: tif/261_2206_2206.tif
# (160, 2)
# [[ 1.10969305e+00 -9.04086828e-02  1.53782349e+02]
#  [-7.37529248e-02  1.12900710e+00  1.25626877e+02]
#  [-2.62471061e-04 -1.89282306e-04  1.00000000e+00]]
# 旋转角度 (度): 0.4262683555855118
# 无人机图像中心点在tif的位置：[465.32042092 432.90114447]
# 无人机图像中心点在地图上的位置：2671.320420919349,2638.901144468485
# 无人机图像中心点的经纬度：10.664563833249812, -168.10302715285644
# UAV: uav/420.jpg - TIF: tif/261_2206_2206.tif
# (216, 2)
# [[ 1.21637976e+00  6.26157001e-02  1.39588959e+02]
#  [-1.47535354e-02  1.31899011e+00  1.30069962e+02]
#  [-5.58846295e-05  1.10021938e-04  1.00000000e+00]]
# 旋转角度 (度): -1.7478930607744474
# 无人机图像中心点在tif的位置：[429.89846866 444.75427961]
# 无人机图像中心点在地图上的位置：2635.898468661444,2650.754279611045
# 无人机图像中心点的经纬度：10.664573356342276, -168.1030575863676
# UAV: uav/421.jpg - TIF: tif/261_2206_2206.tif
# (224, 2)
# [[ 1.18456292e+00 -2.66855936e-02  1.41876785e+02]
#  [-2.59422436e-02  1.24866962e+00  1.48016418e+02]
#  [-1.60395648e-04  2.89798318e-05  1.00000000e+00]]
# 旋转角度 (度): 0.017503800553701793
# 无人机图像中心点在tif的位置：[437.19117135 454.74316565]
# 无人机图像中心点在地图上的位置：2643.1911713522086,2660.74316565466
# 无人机图像中心点的经纬度：10.664562902265715, -168.10305757237515
# UAV: uav/422.jpg - TIF: tif/261_2206_2206.tif
# (223, 2)
# [[ 1.20800030e+00  6.26273779e-03  1.33544617e+02]
#  [-3.19751948e-02  1.24790537e+00  1.64820221e+02]
#  [-1.07297215e-04  7.09938331e-06  1.00000000e+00]]
# 旋转角度 (度): -0.8920111089390629
# 无人机图像中心点在tif的位置：[418.89496318 464.77107798]
# 无人机图像中心点在地图上的位置：2624.8949631831174,2670.7710779754066
# 无人机图像中心点的经纬度：10.664565152321812, -168.10307525636904
# UAV: uav/423.jpg - TIF: tif/261_2206_2206.tif
# (239, 2)
# [[1.62121892e+00 3.31099600e-01 8.36596909e+01]
#  [2.22670034e-01 1.87440646e+00 1.25720795e+02]
#  [4.08111402e-04 7.65833887e-04 1.00000000e+00]]
# 旋转角度 (度): -1.7766678360037798
# 无人机图像中心点在tif的位置：[428.36313734 483.0852002 ]
# 无人机图像中心点在地图上的位置：2634.363137344329,2689.0852002007327
# 无人机图像中心点的经纬度：10.664547926894583, -168.10307792686652
# UAV: uav/424.jpg - TIF: tif/261_2206_2206.tif
# (210, 2)
# [[ 1.08558381e+00 -1.26692187e-03  1.46452896e+02]
#  [-7.95530304e-02  1.18999374e+00  2.06314529e+02]
#  [-1.25075312e-04 -8.28831908e-05  1.00000000e+00]]
# 旋转角度 (度): -1.970354863068373
# 无人机图像中心点在tif的位置：[430.85732466 482.62288158]
# 无人机图像中心点在地图上的位置：2636.857324655673,2688.622881580835
# 无人机图像中心点的经纬度：10.66454700193104, -168.1030759711924
# UAV: uav/425.jpg - TIF: tif/280_2206_2356.tif
# (209, 2)
# [[ 1.31631780e+00 -6.88692629e-02  1.24253098e+02]
#  [ 3.42127718e-02  1.22006166e+00  6.12875481e+01]
#  [ 1.50711319e-04 -1.94765336e-04  1.00000000e+00]]
# 旋转角度 (度): 2.327300417271927
# 无人机图像中心点在tif的位置：[428.5838161  378.84193565]
# 无人机图像中心点在地图上的位置：2634.583816099464,2734.8419356540207
# 无人机图像中心点的经纬度：10.664516549363665, -168.10310078920094
# UAV: uav/426.jpg - TIF: tif/280_2206_2356.tif
# (171, 2)
# [[ 1.16280890e+00 -1.25200912e-01  1.34805862e+02]
#  [-2.94895787e-02  1.11253953e+00  8.52977448e+01]
#  [-1.11986876e-04 -1.57475180e-04  1.00000000e+00]]
# 旋转角度 (度): 2.408696807203042
# 无人机图像中心点在tif的位置：[309.40849653 358.15948463]
# 无人机图像中心点在地图上的位置：2515.4084965349275,2714.159484625624
# 无人机图像中心点的经纬度：10.664589973830633, -168.10317272017204
# UAV: uav/427.jpg - TIF: tif/280_2206_2356.tif
# (150, 2)
# [[ 1.20089447e+00 -1.36409849e-01  1.31171692e+02]
#  [-2.20816620e-02  1.13105464e+00  9.27448120e+01]
#  [-4.99033995e-05 -1.96151042e-04  1.00000000e+00]]
# 旋转角度 (度): 2.806785856469177
# 无人机图像中心点在tif的位置：[410.43752859 367.75255338]
# 无人机图像中心点在地图上的位置：2616.4375285947244,2723.7525533794706
# 无人机图像中心点的经纬度：10.664533155241156, -168.1031077480293
# UAV: uav/428.jpg - TIF: tif/280_2206_2356.tif
# (208, 2)
# [[ 1.18514907e+00  1.09485798e-01  1.24093399e+02]
#  [-5.58750443e-02  1.34653616e+00  9.53447418e+01]
#  [-1.13134920e-04  1.90626364e-04  1.00000000e+00]]
# 旋转角度 (度): -3.73705194924257
# 无人机图像中心点在tif的位置：[403.55216235 383.48992951]
# 无人机图像中心点在地图上的位置：2609.5521623546506,2739.489929512916
# 无人机图像中心点的经纬度：10.664525826674138, -168.10312042047568
# UAV: uav/429.jpg - TIF: tif/280_2206_2356.tif
# (149, 2)
# [[ 1.21662247e+00  6.63161725e-02  1.23102516e+02]
#  [-2.98624877e-02  1.28578532e+00  9.77563705e+01]
#  [-1.48529953e-05  3.10523064e-05  1.00000000e+00]]
# 旋转角度 (度): -2.201048240760984
# 无人机图像中心点在tif的位置：[444.88932583 378.62815738]
# 无人机图像中心点在地图上的位置：2650.889325828796,2734.628157380462
# 无人机图像中心点的经纬度：10.664508583292651, -168.10308941682717
# Time: 0.672s

# %%
import cv2
from my_pkg.tools import parse_keyframe_file, draw_keyframe_trajectory, plot_traj_tif, draw_keyframe_elevation_trajectory
points_traj = []
with open("/home/lty/outputs/RealUAV/city1/loc_elevpnp.txt", 'r') as loc_file:
    for line in loc_file:
        parts = line.strip().split()
        if len(parts) < 4:
            continue
        x_in_map = float(parts[3])   # 调整横坐标
        y_in_map = float(parts[4])  # 调整纵坐标
        print(f"{parts[0]}: {x_in_map}, {y_in_map}")
        points_traj.append((x_in_map, y_in_map))

    # 将点转换为整数坐标（像素坐标）
points_traj = [(int(x), int(y)) for x, y in points_traj]

# plot_traj_tif(
#     map_image_path="/home/lty/outputs/RealUAV/city1/gt_match(kf).png",
#     loc_file_path="/home/lty/outputs/RealUAV/city1/loc_elevation.txt",
#     output_image_path=output_dir/"gt_match_elevation().png",
#     scale_factor=1,
# )

# # 绘制关键帧的单独景象匹配结果
# map = cv2.imread("/home/lty/outputs/RealUAV/city1/gt_match(kf).png", cv2.IMREAD_COLOR)
# keyframe_mapping = parse_keyframe_file("/home/lty/outputs/RealUAV/city1/KeyFrameId.txt")
# map_with_traj = draw_keyframe_trajectory(map, points_traj, keyframe_mapping)
# cv2.imwrite(output_dir/"gt_match_elevation(kf).png", map_with_traj)
# # 绘制关键帧elevation的单独景象匹配结果
map = cv2.imread("/home/lty/outputs/RealUAV/city1/gt.png", cv2.IMREAD_COLOR)
keyframe_mapping = parse_keyframe_file("/home/lty/code/ORB_SLAM3_detailed_comments (realuav)/KeyFrameId.txt")
map_with_traj = draw_keyframe_elevation_trajectory(map, points_traj, keyframe_mapping)
cv2.imwrite(output_dir/"gt_elevpnp.png", map_with_traj)
# Out:
# uav/001.jpg: 2302.0157705, 2706.5474455
# uav/002.jpg: 2285.83211371, 2706.02296261
# uav/003.jpg: 2268.55442167, 2706.80696938
# uav/004.jpg: 2250.63765621, 2708.64591562
# uav/005.jpg: 2235.10267591, 2710.49439974
# uav/006.jpg: 2226.28671563, 2715.25634105
# uav/007.jpg: 2188.6869222, 2710.05131079
# uav/008.jpg: 2162.59611497, 2698.82892856
# uav/009.jpg: 2163.89662436, 2730.84857859
# uav/010.jpg: 2078.32570633, 2631.93308469
# uav/011.jpg: 2129.99231473, 2726.83190844
# uav/012.jpg: 2095.42923681, 2732.44024393
# uav/013.jpg: 2112.6726443, 2701.87685647
# uav/014.jpg: 2037.29218756, 2738.60145079
# uav/015.jpg: 2047.38662207, 2725.92404152
# uav/016.jpg: 2067.04143046, 2737.24262012
# uav/017.jpg: 2034.23591705, 2744.42927305
# uav/018.jpg: 1994.10901355, 2730.35224384
# uav/019.jpg: 1921.40364777, 2681.43886182
# uav/020.jpg: 1961.09131197, 2725.23938585
# uav/021.jpg: 1957.65202977, 2739.26587101
# uav/022.jpg: 1940.57424134, 2745.00456053
# uav/023.jpg: 1941.74466923, 2723.9500294
# uav/024.jpg: 1929.21334843, 2748.22650687
# uav/025.jpg: 1912.74723661, 2729.13013296
# uav/026.jpg: 1899.84199535, 2748.19039604
# uav/027.jpg: 1877.90682991, 2739.66575599
# uav/028.jpg: 1931.40669769, 2736.66143351
# uav/029.jpg: 1853.58371952, 2753.88587762
# uav/030.jpg: 1816.94147206, 2763.3830984
# uav/031.jpg: 1815.86440864, 2763.37579341
# uav/032.jpg: 1795.66053126, 2752.43222589
# uav/033.jpg: 1799.95963535, 2744.76505793
# uav/034.jpg: 1751.89856714, 2739.71174574
# uav/035.jpg: 1767.09304622, 2757.9416616
# uav/036.jpg: 1700.08860493, 2742.50033995
# uav/037.jpg: 1615.30701373, 2660.98367403
# uav/038.jpg: 1677.50799046, 2728.65636783
# uav/039.jpg: 1671.66335879, 2740.27914224
# uav/040.jpg: 1686.60930811, 2768.40455153
# uav/041.jpg: 1674.5818108, 2773.52189118
# uav/042.jpg: 1628.08050766, 2757.633139
# uav/043.jpg: 1621.75727672, 2786.91800405
# uav/044.jpg: 1579.34254394, 2741.32167486
# uav/045.jpg: 1569.8822333, 2765.61963343
# uav/046.jpg: 1513.82825322, 2582.2043749
# uav/047.jpg: 1570.67369556, 2749.50517989
# uav/048.jpg: 1554.44498661, 2775.96502883
# uav/049.jpg: 1521.42500429, 2772.36677688
# uav/050.jpg: 1474.37664829, 2741.84905372
# uav/051.jpg: 1512.87147931, 2798.53810167
# uav/052.jpg: 1457.88202202, 2753.87789547
# uav/053.jpg: 1442.83271408, 2777.8785775
# uav/054.jpg: 1457.69925122, 2772.42820696
# uav/055.jpg: 1242.66183107, 2727.71792001
# uav/056.jpg: 1401.58164107, 2750.16842075
# uav/057.jpg: 1380.78844196, 2785.04949751
# uav/058.jpg: 1368.17997249, 2750.08017212
# uav/059.jpg: 1345.74398768, 2798.36968124
# uav/060.jpg: 1336.14350516, 2777.42046526
# uav/061.jpg: 1314.02479165, 2794.78601956
# uav/062.jpg: 1300.14369123, 2798.91982288
# uav/063.jpg: 1291.81864146, 2772.45652323
# uav/064.jpg: 1171.0032208, 2625.51668795
# uav/065.jpg: 1265.52691194, 2781.08345704
# uav/066.jpg: 1258.39763653, 2770.67034472
# uav/067.jpg: 1221.91572366, 2751.7000256
# uav/068.jpg: 1221.52658769, 2739.04582647
# uav/069.jpg: 1211.73415144, 2754.61671586
# uav/070.jpg: 1177.04986209, 2766.70700696
# uav/071.jpg: 1159.65131087, 2771.65960503
# uav/072.jpg: 1158.95201597, 2741.94482843
# uav/073.jpg: 1056.93428875, 2564.16966812
# uav/074.jpg: 1136.34135962, 2728.43366839
# uav/075.jpg: 1113.15772456, 2716.79097791
# uav/076.jpg: 1114.33266571, 2740.25831626
# uav/077.jpg: 1104.70494562, 2685.79658715
# uav/078.jpg: 1084.98890531, 2674.10552324
# uav/079.jpg: 1048.69184782, 2678.64075157
# uav/080.jpg: 1046.16899986, 2662.25746326
# uav/081.jpg: 1040.9083599, 2650.5159061
# uav/082.jpg: 942.57150624, 2501.98584269
# uav/083.jpg: 1024.90231073, 2604.6193022
# uav/084.jpg: 1018.66565503, 2607.44414536
# uav/085.jpg: 1013.10792099, 2598.82249589
# uav/086.jpg: 989.80488577, 2548.65031798
# uav/087.jpg: 981.53795713, 2561.20101552
# uav/088.jpg: 975.16041737, 2540.89689237
# uav/089.jpg: 968.39897986, 2552.67153178
# uav/090.jpg: 962.14031035, 2506.9941678
# uav/091.jpg: 805.69549196, 2401.72224842
# uav/092.jpg: 965.47968062, 2486.47988541
# uav/093.jpg: 961.57608245, 2467.91569305
# uav/094.jpg: 965.08787181, 2445.5802159
# uav/095.jpg: 940.67341552, 2446.76452734
# uav/096.jpg: 941.8456466, 2424.95002056
# uav/097.jpg: 930.06546802, 2416.13797683
# uav/098.jpg: 935.85448322, 2411.3865296
# uav/099.jpg: 941.43254313, 2385.48630978
# uav/100.jpg: 896.92648699, 2447.12891718
# uav/101.jpg: 927.18399624, 2335.23560954
# uav/102.jpg: 930.50371337, 2332.10393846
# uav/103.jpg: 921.5869257, 2299.51207547
# uav/104.jpg: 935.97126844, 2262.84071221
# uav/105.jpg: 908.88697162, 2272.81516602
# uav/106.jpg: 886.8665507, 2250.16075444
# uav/107.jpg: 872.24749874, 2245.78061708
# uav/108.jpg: 903.23009649, 2226.41796931
# uav/109.jpg: 864.85580969, 2409.38757534
# uav/110.jpg: 891.66025813, 2198.1327237
# uav/111.jpg: 863.3437486, 2173.33927876
# uav/112.jpg: 877.48115944, 2170.84010599
# uav/113.jpg: 873.73969827, 2170.88538184
# uav/114.jpg: 877.85586117, 2141.00079184
# uav/115.jpg: 858.60444644, 2136.23249962
# uav/116.jpg: 875.1605792, 2101.76004604
# uav/117.jpg: 872.76320634, 2085.8038772
# uav/118.jpg: 890.47861355, 2201.1700155
# uav/119.jpg: 884.25208811, 2057.87094616
# uav/120.jpg: 891.56369424, 2013.21088266
# uav/121.jpg: 885.92689912, 2012.63817126
# uav/122.jpg: 854.82688629, 1996.30444283
# uav/123.jpg: 864.65878404, 2004.29347296
# uav/124.jpg: 888.2562746, 1980.01839915
# uav/125.jpg: 861.05962448, 1963.61853064
# uav/126.jpg: 869.22637144, 1934.57012761
# uav/127.jpg: 746.92048933, 1706.62996552
# uav/128.jpg: 875.58005152, 1925.66950881
# uav/129.jpg: 848.18213984, 1898.75345916
# uav/130.jpg: 855.5602714, 1895.20241296
# uav/131.jpg: 852.71835197, 1870.40883151
# uav/132.jpg: 879.94932795, 1840.79044484
# uav/133.jpg: 875.01035486, 1820.38829995
# uav/134.jpg: 868.66911637, 1799.64225872
# uav/135.jpg: 873.1410351, 1806.71926449
# uav/136.jpg: 815.01023536, 1674.47241386
# uav/137.jpg: 889.80280179, 1769.68300537
# uav/138.jpg: 863.70778736, 1754.77102823
# uav/139.jpg: 865.30528935, 1735.28502134
# uav/140.jpg: 855.3860184, 1707.59948196
# uav/141.jpg: 846.90290618, 1676.58901389
# uav/142.jpg: 869.24313548, 1692.42865771
# uav/143.jpg: 873.17985645, 1693.3231167
# uav/144.jpg: 866.79680755, 1632.40683477
# uav/145.jpg: 759.43804785, 1577.31374519
# uav/146.jpg: 880.47631593, 1612.45836653
# uav/147.jpg: 852.56032138, 1601.49035452
# uav/148.jpg: 846.14820686, 1592.76996193
# uav/149.jpg: 880.29123635, 1573.75124426
# uav/150.jpg: 857.22711557, 1560.94708151
# uav/151.jpg: 868.5729215, 1521.2890744
# uav/152.jpg: 840.53636245, 1513.70166085
# uav/153.jpg: 822.91223806, 1501.79175628
# uav/154.jpg: 725.46617751, 1421.5211941
# uav/155.jpg: 870.66961846, 1476.89347814
# uav/156.jpg: 854.81319004, 1434.4214703
# uav/157.jpg: 863.32989507, 1464.52736837
# uav/158.jpg: 844.35570463, 1421.89995705
# uav/159.jpg: 858.52632899, 1407.72246001
# uav/160.jpg: 838.72901443, 1348.17080685
# uav/161.jpg: 852.66945695, 1389.63363583
# uav/162.jpg: 863.34021251, 1370.82658119
# uav/163.jpg: 712.82257106, 1251.12856561
# uav/164.jpg: 830.87631011, 1310.29674119
# uav/165.jpg: 812.66370758, 1326.78341473
# uav/166.jpg: 808.64898998, 1289.26854957
# uav/167.jpg: 835.05885748, 1293.28172432
# uav/168.jpg: 810.01833102, 1261.82401529
# uav/169.jpg: 803.47501962, 1228.1522363
# uav/170.jpg: 804.99512738, 1222.62245951
# uav/171.jpg: 788.62288635, 1171.72155272
# uav/172.jpg: 705.92020111, 1102.15779198
# uav/173.jpg: 821.57722344, 1178.97675283
# uav/174.jpg: 793.62288061, 1159.7914887
# uav/175.jpg: 829.73978191, 1157.09762047
# uav/176.jpg: 807.2452398, 1111.91997543
# uav/177.jpg: 788.30371961, 1087.72678141
# uav/178.jpg: 780.86361674, 1077.08782984
# uav/179.jpg: 864.8457181, 1087.56140628
# uav/180.jpg: 869.50211144, 1100.95947149
# uav/181.jpg: 841.56945853, 902.52099137
# uav/182.jpg: 822.18629943, 1021.76114592
# uav/183.jpg: 851.83686977, 1033.9263065
# uav/184.jpg: 834.36964156, 989.3997454
# uav/185.jpg: 847.30945888, 960.32720265
# uav/186.jpg: 862.31492233, 974.72619334
# uav/187.jpg: 848.54866057, 971.86894388
# uav/188.jpg: 864.44324113, 942.54198363
# uav/189.jpg: 861.99286606, 907.78185573
# uav/190.jpg: 785.58183313, 796.58219197
# uav/191.jpg: 887.38454174, 933.0793393
# uav/192.jpg: 897.3786107, 869.37745535
# uav/193.jpg: 940.36382193, 907.71493155
# uav/194.jpg: 938.36375812, 894.94253697
# uav/195.jpg: 954.41777988, 901.8479382
# uav/196.jpg: 980.79062426, 878.07874971
# uav/197.jpg: 981.92016697, 850.0657058
# uav/198.jpg: 1004.57756906, 850.03850395
# uav/199.jpg: 885.92405612, 829.85254218
# uav/200.jpg: 1027.8166779, 871.48170375
# uav/201.jpg: 1060.14697841, 811.38690015
# uav/202.jpg: 1061.84132551, 840.59873069
# uav/203.jpg: 1080.12969931, 814.96673537
# uav/204.jpg: 1074.37021118, 814.05911514
# uav/205.jpg: 1111.86728625, 816.62567264
# uav/206.jpg: 1166.6515938, 802.08635042
# uav/207.jpg: 1155.7983565, 784.55924618
# uav/208.jpg: 1064.44271964, 756.82273998
# uav/209.jpg: 1161.59044839, 819.15893007
# uav/210.jpg: 1193.14606753, 765.6676639
# uav/211.jpg: 1229.52974938, 805.9167045
# uav/212.jpg: 1223.03037822, 797.86916624
# uav/213.jpg: 1212.32418676, 773.92874566
# uav/214.jpg: 1231.07724937, 787.88912507
# uav/215.jpg: 1270.89375201, 775.63500855
# uav/216.jpg: 1274.7020681, 754.64213743
# uav/217.jpg: 1345.77085062, 829.55637239
# uav/218.jpg: 1350.68945465, 771.58991308
# uav/219.jpg: 1354.65953953, 753.75760862
# uav/220.jpg: 1344.05811983, 765.43213109
# uav/221.jpg: 1389.90861028, 758.08543064
# uav/222.jpg: 1407.50539306, 729.2827867
# uav/223.jpg: 1409.24954335, 765.82624429
# uav/224.jpg: 1427.14609793, 761.67455871
# uav/225.jpg: 1442.08360155, 737.82473147
# uav/226.jpg: 1339.50466017, 672.10220599
# uav/227.jpg: 1467.81174445, 767.1897879
# uav/228.jpg: 1485.702976, 762.45991917
# uav/229.jpg: 1516.90762022, 718.22511785
# uav/230.jpg: 1516.50023973, 770.93204084
# uav/231.jpg: 1519.22292962, 755.15253418
# uav/232.jpg: 1525.37140852, 748.57840844
# uav/233.jpg: 1585.08511034, 761.67429988
# uav/234.jpg: 1589.03559496, 745.84259526
# uav/235.jpg: 1572.21475281, 735.43048863
# uav/236.jpg: 1623.26048543, 749.58349089
# uav/237.jpg: 1656.5866447, 778.69460059
# uav/238.jpg: 1641.22823297, 792.94620037
# uav/239.jpg: 1670.45626028, 769.52400791
# uav/240.jpg: 1694.8444814, 753.09575521
# uav/241.jpg: 1703.73813959, 792.92354425
# uav/242.jpg: 1708.3378815, 772.62153599
# uav/243.jpg: 1716.00116019, 797.69135387
# uav/244.jpg: 1681.32368041, 735.67519732
# uav/245.jpg: 1775.2780099, 792.09132026
# uav/246.jpg: 1803.9016436, 810.57971533
# uav/247.jpg: 1806.77149525, 835.21421072
# uav/248.jpg: 1808.00181642, 834.30553354
# uav/249.jpg: 1849.90536303, 802.33976295
# uav/250.jpg: 1859.61686081, 823.57277614
# uav/251.jpg: 1847.58633532, 840.87221979
# uav/252.jpg: 1876.55167511, 849.03447451
# uav/253.jpg: 1916.23256738, 860.29348403
# uav/254.jpg: 1898.56859791, 872.49494844
# uav/255.jpg: 1941.7979013, 862.09977641
# uav/256.jpg: 1929.42207847, 878.96728409
# uav/257.jpg: 1940.30121495, 888.58244441
# uav/258.jpg: 1951.33513138, 878.18678728
# uav/259.jpg: 1972.16738844, 905.08990632
# uav/260.jpg: 1963.68572617, 917.37517052
# uav/261.jpg: 1987.68682087, 921.18631467
# uav/262.jpg: 2103.54020272, 879.16923726
# uav/263.jpg: 2007.01106367, 925.48529329
# uav/264.jpg: 1997.11628026, 926.36119156
# uav/265.jpg: 2027.25123166, 943.05038257
# uav/266.jpg: 2035.28160621, 984.50829514
# uav/267.jpg: 2042.56519046, 997.58599951
# uav/268.jpg: 2061.88397863, 997.42220689
# uav/269.jpg: 2047.23329675, 1019.4236471
# uav/270.jpg: 2093.10024096, 1036.09469871
# uav/271.jpg: 1925.77146003, 1040.71842509
# uav/272.jpg: 2077.09867817, 1062.39472517
# uav/273.jpg: 2108.04471066, 1074.91246198
# uav/274.jpg: 2082.75559011, 1086.95197863
# uav/275.jpg: 2092.72310247, 1108.31274946
# uav/276.jpg: 2126.1932124, 1137.6866612
# uav/277.jpg: 2109.9016147, 1142.61351004
# uav/278.jpg: 2099.48618093, 1131.34627477
# uav/279.jpg: 2078.08764973, 1158.62221843
# uav/280.jpg: 1986.38610453, 1139.77522827
# uav/281.jpg: 2055.55374697, 1216.80606567
# uav/282.jpg: 2066.34843073, 1212.21043713
# uav/283.jpg: 2059.78871171, 1213.51851101
# uav/284.jpg: 2035.39725607, 1260.21239516
# uav/285.jpg: 2047.3245669, 1253.69221476
# uav/286.jpg: 2035.95970329, 1247.11184196
# uav/287.jpg: 2033.04670184, 1269.76184782
# uav/288.jpg: 2008.39661389, 1282.16353058
# uav/289.jpg: 1857.20326494, 1221.76349772
# uav/290.jpg: 2026.46519199, 1324.83856146
# uav/291.jpg: 1990.20975926, 1323.69141004
# uav/292.jpg: 1961.42012566, 1347.80686172
# uav/293.jpg: 1969.27398728, 1378.20402368
# uav/294.jpg: 1986.95844452, 1370.94798722
# uav/295.jpg: 1960.54445704, 1399.99119111
# uav/296.jpg: 1937.87327363, 1377.94042216
# uav/297.jpg: 1940.58029115, 1417.23717496
# uav/298.jpg: 1887.92150511, 1425.49271333
# uav/299.jpg: 1948.2097111, 1480.78384799
# uav/300.jpg: 1968.85462325, 1488.26024055
# uav/301.jpg: 1913.26499253, 1468.70017424
# uav/302.jpg: 1928.05560966, 1515.41551346
# uav/303.jpg: 1929.05624085, 1556.29060277
# uav/304.jpg: 1878.10632938, 1516.98063258
# uav/305.jpg: 1899.10899503, 1541.96196026
# uav/306.jpg: 1884.98976681, 1544.32295419
# uav/307.jpg: 1805.12063117, 1512.56333873
# uav/308.jpg: 1846.98159206, 1558.01623378
# uav/309.jpg: 1836.6460236, 1577.17221286
# uav/310.jpg: 1825.08921171, 1589.31829969
# uav/311.jpg: 1827.75496884, 1598.9576213
# uav/312.jpg: 1796.57933748, 1606.9278722
# uav/313.jpg: 1801.11426525, 1643.53807723
# uav/314.jpg: 1791.45596852, 1637.06202905
# uav/315.jpg: 1766.01482547, 1674.62780991
# uav/316.jpg: 1794.366469, 1521.05344885
# uav/317.jpg: 1747.49657598, 1701.2325995
# uav/318.jpg: 1777.85956494, 1701.4040047
# uav/319.jpg: 1793.82329953, 1743.04759199
# uav/320.jpg: 1768.37634231, 1744.41246286
# uav/321.jpg: 1742.6082804, 1739.16847523
# uav/322.jpg: 1786.87643684, 1769.60793817
# uav/323.jpg: 1778.29699375, 1786.86349796
# uav/324.jpg: 1759.08137213, 1785.25333422
# uav/325.jpg: 1676.35911298, 1823.63887828
# uav/326.jpg: 1774.78770579, 1843.02643052
# uav/327.jpg: 1798.53952519, 1858.14650884
# uav/328.jpg: 1790.69480358, 1866.79296813
# uav/329.jpg: 1777.57218638, 1879.95008615
# uav/330.jpg: 1823.03777211, 1908.89279151
# uav/331.jpg: 1821.80805189, 1919.27901671
# uav/332.jpg: 1814.07170416, 1906.55541826
# uav/333.jpg: 1880.086359, 1928.34637379
# uav/334.jpg: 1890.96889055, 1834.02982834
# uav/335.jpg: 1886.26054154, 1962.37077122
# uav/336.jpg: 1922.24043765, 1933.98887494
# uav/337.jpg: 1930.36893423, 1958.89574517
# uav/338.jpg: 1942.86282259, 1963.23133696
# uav/339.jpg: 1965.76444798, 1971.92840334
# uav/340.jpg: 1993.10150869, 1981.80159075
# uav/341.jpg: 1995.90271685, 1946.48422488
# uav/342.jpg: 2046.40339906, 1986.96312102
# uav/343.jpg: 2067.3554209, 1891.08893238
# uav/344.jpg: 2052.78457587, 1966.5380602
# uav/345.jpg: 2064.82151857, 1992.65196633
# uav/346.jpg: 2070.14282413, 1968.57670685
# uav/347.jpg: 2076.79606741, 2006.26891182
# uav/348.jpg: 2094.80874062, 1971.22909418
# uav/349.jpg: 2115.18719644, 1982.35842674
# uav/350.jpg: 2140.97451162, 1980.67559928
# uav/351.jpg: 2155.93066035, 1985.35465547
# uav/352.jpg: 2221.12943592, 1868.93606521
# uav/353.jpg: 2172.64831883, 1989.64299448
# uav/354.jpg: 2191.68395657, 1982.99667469
# uav/355.jpg: 2222.25453794, 1981.85664177
# uav/356.jpg: 2240.61361393, 1972.83858702
# uav/357.jpg: 2253.49602784, 1975.87664659
# uav/358.jpg: 2258.72595555, 1968.31015277
# uav/359.jpg: 2296.88050167, 1987.27671587
# uav/360.jpg: 2293.07017555, 1995.39582748
# uav/361.jpg: 2146.47425306, 1935.55519667
# uav/362.jpg: 2313.83546286, 1979.26322084
# uav/363.jpg: 2369.08859766, 1976.57398496
# uav/364.jpg: 2337.87490759, 1943.79199062
# uav/365.jpg: 2351.24721172, 1972.50307672
# uav/366.jpg: 2427.75920439, 1995.09015311
# uav/367.jpg: 2435.36727284, 1972.58700308
# uav/368.jpg: 2424.95341887, 1974.65026809
# uav/369.jpg: 2403.602072, 2000.88901824
# uav/370.jpg: 2481.29627722, 1893.82409182
# uav/371.jpg: 2467.18437221, 1958.53222304
# uav/372.jpg: 2456.1932777, 1975.06839228
# uav/373.jpg: 2490.58352646, 2007.40137834
# uav/374.jpg: 2510.75542232, 1989.23025085
# uav/375.jpg: 2526.73541161, 1993.74848891
# uav/376.jpg: 2535.2444286, 2007.83787844
# uav/377.jpg: 2562.16812999, 1996.72663009
# uav/378.jpg: 2555.91236243, 1997.72272888
# uav/379.jpg: 2460.71783595, 1888.42669651
# uav/380.jpg: 2588.35980998, 2007.97266601
# uav/381.jpg: 2617.89192657, 2050.2943885
# uav/382.jpg: 2638.87038912, 2036.236188
# uav/383.jpg: 2658.81321808, 2061.71736586
# uav/384.jpg: 2657.69987684, 2036.14651449
# uav/385.jpg: 2666.37840351, 2049.43837055
# uav/386.jpg: 2674.18844859, 2075.58313465
# uav/387.jpg: 2668.41266595, 2112.67554635
# uav/388.jpg: 2693.97419924, 2036.74810986
# uav/389.jpg: 2693.7140136, 2106.38234313
# uav/390.jpg: 2728.88412371, 2134.34616578
# uav/391.jpg: 2699.8237714, 2145.75248963
# uav/392.jpg: 2723.62622584, 2174.46317775
# uav/393.jpg: 2679.15207249, 2196.69211129
# uav/394.jpg: 2705.2953233, 2190.31682231
# uav/395.jpg: 2698.21390134, 2240.56870159
# uav/396.jpg: 2702.1489345, 2248.97704196
# uav/397.jpg: 2691.02506051, 2279.20584922
# uav/398.jpg: 2720.02731737, 2293.1179945
# uav/399.jpg: 2690.36455116, 2306.23413205
# uav/400.jpg: 2712.80210115, 2317.70237503
# uav/401.jpg: 2735.44116017, 2320.19335613
# uav/402.jpg: 2677.8817744, 2364.21169958
# uav/403.jpg: 2673.39743443, 2365.39105095
# uav/404.jpg: 2692.12973848, 2382.63308287
# uav/405.jpg: 2697.80095938, 2394.22781203
# uav/406.jpg: 2646.84635711, 2263.34284247
# uav/407.jpg: 2694.04263748, 2419.98833963
# uav/408.jpg: 2679.0240169, 2438.82433477
# uav/409.jpg: 2695.5187017, 2462.57929968
# uav/410.jpg: 2686.05685305, 2484.62554835
# uav/411.jpg: 2684.97296162, 2492.07024165
# uav/412.jpg: 2706.28009625, 2532.37604519
# uav/413.jpg: 2670.47187203, 2523.13223418
# uav/414.jpg: 2665.83343302, 2517.08936448
# uav/415.jpg: 2462.93872706, 2279.24308833
# uav/416.jpg: 2651.0374479, 2589.30163896
# uav/417.jpg: 2642.52935997, 2603.14692567
# uav/418.jpg: 2628.5372965, 2599.76485861
# uav/419.jpg: 2631.22639666, 2652.88832325
# uav/420.jpg: 2636.10181217, 2642.13281008
# uav/421.jpg: 2603.5031026, 2653.19208324
# uav/422.jpg: 2638.06951082, 2691.73972897
# uav/423.jpg: 2631.87918609, 2684.36346377
# uav/424.jpg: 2551.5323016, 2648.92311185
# uav/425.jpg: 2628.0753028, 2721.25821666
# uav/426.jpg: 2640.72302142, 2723.64633783
# uav/427.jpg: 2613.87736384, 2726.94158441
# uav/428.jpg: 2637.63542625, 2744.29562222
# uav/429.jpg: 2648.91605121, 2738.97366059
# True

# %% [markdown]
# slam traj

# %%
#fusion traj
import cv2
from my_pkg.tools import parse_keyframe_file, draw_slam_keyframe_traj, draw_fusion_keyframe_traj
slam_traj_path = "/home/lty/paper/results/city1/proposed.txt"
def geoXY_to_pixelXY(geo_x, geo_y, geotransform):
    x = int((geo_x - geotransform[0]) / geotransform[1])
    y = int((geo_y - geotransform[3]) / geotransform[5])
    return x, y

slam_traj = []
with open(slam_traj_path, 'r') as f:
    lines = f.readlines()
    for line in lines:
        parts = line.strip().split()
        if len(parts) < 2:
            continue
        Pixelx, Pixely = geoXY_to_pixelXY(float(parts[0]), float(parts[1]), geotransform)
        #print(f"{parts[0]}: {Pixelx}, {Pixely}")
        x_in_map = Pixelx  # 调整横坐标  seu need *0.2
        y_in_map = Pixely 
        slam_traj.append((x_in_map, y_in_map))
        
slam_traj = [(int(x), int(y)) for x, y in slam_traj]   
map = cv2.imread(output_dir/"gt_elevpnp.png", cv2.IMREAD_COLOR)
map_with_traj = draw_fusion_keyframe_traj(map, slam_traj)
cv2.imwrite(output_dir/"gt_elevpnp_proposed.png", map_with_traj)
# Out:
# True

# %%
#slam traj
import cv2
from my_pkg.tools import parse_keyframe_file, draw_slam_keyframe_traj
slam_traj_path = "/home/lty/paper/results/city1/orb-slam3.txt"
def geoXY_to_pixelXY(geo_x, geo_y, geotransform):
    x = int((geo_x - geotransform[0]) / geotransform[1])
    y = int((geo_y - geotransform[3]) / geotransform[5])
    return x, y

slam_traj = []
with open(slam_traj_path, 'r') as f:
    lines = f.readlines()
    for line in lines:
        parts = line.strip().split()
        if len(parts) < 2:
            continue
        Pixelx, Pixely = geoXY_to_pixelXY(float(parts[0]), float(parts[1]), geotransform)
        #print(f"{parts[0]}: {Pixelx}, {Pixely}")
        x_in_map = Pixelx  # 调整横坐标  seu need *0.2
        y_in_map = Pixely 
        slam_traj.append((x_in_map, y_in_map))
        
slam_traj = [(int(x), int(y)) for x, y in slam_traj]   
map = cv2.imread(output_dir/"gt_elevpnp_proposed.png", cv2.IMREAD_COLOR)
map_with_traj = draw_slam_keyframe_traj(map, slam_traj)
cv2.imwrite(output_dir/"compare.png", map_with_traj)
# Out:
# True

# %%
# 打开 HDF5 文件
with h5py.File(features_path, 'r') as f:
    # 获取所有数据集的名称
    print("文件中的数据集和分组结构：")
    def print_structure(name, obj):
        """递归打印 HDF5 文件的层次结构"""
        if isinstance(obj, h5py.Group):
            print(f"Group: {name}")
        elif isinstance(obj, h5py.Dataset):
            print(f"Dataset: {name} - Shape: {obj.shape} - Type: {obj.dtype}")
    f.visititems(print_structure)

    # 示例：读取一个特定图像的特征
    example_image = "seu_uav/DJI_0218.JPG"  # 替换为您的图像名称
    if example_image in f:
        group = f[example_image]
        print(f"\n特定图像 '{example_image}' 的内容:")
        for key in group.keys():
            data = group[key][:]
            print(f"{key}: {data.shape} - {data.dtype}")
    else:
        print(f"图像 '{example_image}' 不存在于 HDF5 文件中。")
# Out:
# 文件中的数据集和分组结构：
# Group: tif
# Group: tif/100_856_1006.tif
# Dataset: tif/100_856_1006.tif/descriptors - Shape: (256, 1919) - Type: float16
# Dataset: tif/100_856_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/100_856_1006.tif/keypoints - Shape: (1919, 2) - Type: float16
# Dataset: tif/100_856_1006.tif/scores - Shape: (1919,) - Type: float16
# Group: tif/101_1006_1006.tif
# Dataset: tif/101_1006_1006.tif/descriptors - Shape: (256, 1911) - Type: float16
# Dataset: tif/101_1006_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/101_1006_1006.tif/keypoints - Shape: (1911, 2) - Type: float16
# Dataset: tif/101_1006_1006.tif/scores - Shape: (1911,) - Type: float16
# Group: tif/102_1156_1006.tif
# Dataset: tif/102_1156_1006.tif/descriptors - Shape: (256, 1901) - Type: float16
# Dataset: tif/102_1156_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/102_1156_1006.tif/keypoints - Shape: (1901, 2) - Type: float16
# Dataset: tif/102_1156_1006.tif/scores - Shape: (1901,) - Type: float16
# Group: tif/103_1306_1006.tif
# Dataset: tif/103_1306_1006.tif/descriptors - Shape: (256, 1834) - Type: float16
# Dataset: tif/103_1306_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/103_1306_1006.tif/keypoints - Shape: (1834, 2) - Type: float16
# Dataset: tif/103_1306_1006.tif/scores - Shape: (1834,) - Type: float16
# Group: tif/104_1456_1006.tif
# Dataset: tif/104_1456_1006.tif/descriptors - Shape: (256, 1670) - Type: float16
# Dataset: tif/104_1456_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/104_1456_1006.tif/keypoints - Shape: (1670, 2) - Type: float16
# Dataset: tif/104_1456_1006.tif/scores - Shape: (1670,) - Type: float16
# Group: tif/105_1606_1006.tif
# Dataset: tif/105_1606_1006.tif/descriptors - Shape: (256, 1620) - Type: float16
# Dataset: tif/105_1606_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/105_1606_1006.tif/keypoints - Shape: (1620, 2) - Type: float16
# Dataset: tif/105_1606_1006.tif/scores - Shape: (1620,) - Type: float16
# Group: tif/106_1756_1006.tif
# Dataset: tif/106_1756_1006.tif/descriptors - Shape: (256, 1650) - Type: float16
# Dataset: tif/106_1756_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/106_1756_1006.tif/keypoints - Shape: (1650, 2) - Type: float16
# Dataset: tif/106_1756_1006.tif/scores - Shape: (1650,) - Type: float16
# Group: tif/107_1906_1006.tif
# Dataset: tif/107_1906_1006.tif/descriptors - Shape: (256, 1602) - Type: float16
# Dataset: tif/107_1906_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/107_1906_1006.tif/keypoints - Shape: (1602, 2) - Type: float16
# Dataset: tif/107_1906_1006.tif/scores - Shape: (1602,) - Type: float16
# Group: tif/108_2056_1006.tif
# Dataset: tif/108_2056_1006.tif/descriptors - Shape: (256, 1555) - Type: float16
# Dataset: tif/108_2056_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/108_2056_1006.tif/keypoints - Shape: (1555, 2) - Type: float16
# Dataset: tif/108_2056_1006.tif/scores - Shape: (1555,) - Type: float16
# Group: tif/109_2206_1006.tif
# Dataset: tif/109_2206_1006.tif/descriptors - Shape: (256, 1535) - Type: float16
# Dataset: tif/109_2206_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/109_2206_1006.tif/keypoints - Shape: (1535, 2) - Type: float16
# Dataset: tif/109_2206_1006.tif/scores - Shape: (1535,) - Type: float16
# Group: tif/10_1606_256.tif
# Dataset: tif/10_1606_256.tif/descriptors - Shape: (256, 1763) - Type: float16
# Dataset: tif/10_1606_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/10_1606_256.tif/keypoints - Shape: (1763, 2) - Type: float16
# Dataset: tif/10_1606_256.tif/scores - Shape: (1763,) - Type: float16
# Group: tif/110_2356_1006.tif
# Dataset: tif/110_2356_1006.tif/descriptors - Shape: (256, 1558) - Type: float16
# Dataset: tif/110_2356_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/110_2356_1006.tif/keypoints - Shape: (1558, 2) - Type: float16
# Dataset: tif/110_2356_1006.tif/scores - Shape: (1558,) - Type: float16
# Group: tif/111_2506_1006.tif
# Dataset: tif/111_2506_1006.tif/descriptors - Shape: (256, 1735) - Type: float16
# Dataset: tif/111_2506_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/111_2506_1006.tif/keypoints - Shape: (1735, 2) - Type: float16
# Dataset: tif/111_2506_1006.tif/scores - Shape: (1735,) - Type: float16
# Group: tif/112_2656_1006.tif
# Dataset: tif/112_2656_1006.tif/descriptors - Shape: (256, 1763) - Type: float16
# Dataset: tif/112_2656_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/112_2656_1006.tif/keypoints - Shape: (1763, 2) - Type: float16
# Dataset: tif/112_2656_1006.tif/scores - Shape: (1763,) - Type: float16
# Group: tif/113_2806_1006.tif
# Dataset: tif/113_2806_1006.tif/descriptors - Shape: (256, 1861) - Type: float16
# Dataset: tif/113_2806_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/113_2806_1006.tif/keypoints - Shape: (1861, 2) - Type: float16
# Dataset: tif/113_2806_1006.tif/scores - Shape: (1861,) - Type: float16
# Group: tif/114_2956_1006.tif
# Dataset: tif/114_2956_1006.tif/descriptors - Shape: (256, 1755) - Type: float16
# Dataset: tif/114_2956_1006.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/114_2956_1006.tif/keypoints - Shape: (1755, 2) - Type: float16
# Dataset: tif/114_2956_1006.tif/scores - Shape: (1755,) - Type: float16
# Group: tif/115_256_1156.tif
# Dataset: tif/115_256_1156.tif/descriptors - Shape: (256, 1602) - Type: float16
# Dataset: tif/115_256_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/115_256_1156.tif/keypoints - Shape: (1602, 2) - Type: float16
# Dataset: tif/115_256_1156.tif/scores - Shape: (1602,) - Type: float16
# Group: tif/116_406_1156.tif
# Dataset: tif/116_406_1156.tif/descriptors - Shape: (256, 1719) - Type: float16
# Dataset: tif/116_406_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/116_406_1156.tif/keypoints - Shape: (1719, 2) - Type: float16
# Dataset: tif/116_406_1156.tif/scores - Shape: (1719,) - Type: float16
# Group: tif/117_556_1156.tif
# Dataset: tif/117_556_1156.tif/descriptors - Shape: (256, 1785) - Type: float16
# Dataset: tif/117_556_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/117_556_1156.tif/keypoints - Shape: (1785, 2) - Type: float16
# Dataset: tif/117_556_1156.tif/scores - Shape: (1785,) - Type: float16
# Group: tif/118_706_1156.tif
# Dataset: tif/118_706_1156.tif/descriptors - Shape: (256, 1912) - Type: float16
# Dataset: tif/118_706_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/118_706_1156.tif/keypoints - Shape: (1912, 2) - Type: float16
# Dataset: tif/118_706_1156.tif/scores - Shape: (1912,) - Type: float16
# Group: tif/119_856_1156.tif
# Dataset: tif/119_856_1156.tif/descriptors - Shape: (256, 1847) - Type: float16
# Dataset: tif/119_856_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/119_856_1156.tif/keypoints - Shape: (1847, 2) - Type: float16
# Dataset: tif/119_856_1156.tif/scores - Shape: (1847,) - Type: float16
# Group: tif/11_1756_256.tif
# Dataset: tif/11_1756_256.tif/descriptors - Shape: (256, 1878) - Type: float16
# Dataset: tif/11_1756_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/11_1756_256.tif/keypoints - Shape: (1878, 2) - Type: float16
# Dataset: tif/11_1756_256.tif/scores - Shape: (1878,) - Type: float16
# Group: tif/120_1006_1156.tif
# Dataset: tif/120_1006_1156.tif/descriptors - Shape: (256, 1729) - Type: float16
# Dataset: tif/120_1006_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/120_1006_1156.tif/keypoints - Shape: (1729, 2) - Type: float16
# Dataset: tif/120_1006_1156.tif/scores - Shape: (1729,) - Type: float16
# Group: tif/121_1156_1156.tif
# Dataset: tif/121_1156_1156.tif/descriptors - Shape: (256, 1672) - Type: float16
# Dataset: tif/121_1156_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/121_1156_1156.tif/keypoints - Shape: (1672, 2) - Type: float16
# Dataset: tif/121_1156_1156.tif/scores - Shape: (1672,) - Type: float16
# Group: tif/122_1306_1156.tif
# Dataset: tif/122_1306_1156.tif/descriptors - Shape: (256, 1596) - Type: float16
# Dataset: tif/122_1306_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/122_1306_1156.tif/keypoints - Shape: (1596, 2) - Type: float16
# Dataset: tif/122_1306_1156.tif/scores - Shape: (1596,) - Type: float16
# Group: tif/123_1456_1156.tif
# Dataset: tif/123_1456_1156.tif/descriptors - Shape: (256, 1493) - Type: float16
# Dataset: tif/123_1456_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/123_1456_1156.tif/keypoints - Shape: (1493, 2) - Type: float16
# Dataset: tif/123_1456_1156.tif/scores - Shape: (1493,) - Type: float16
# Group: tif/124_1606_1156.tif
# Dataset: tif/124_1606_1156.tif/descriptors - Shape: (256, 1487) - Type: float16
# Dataset: tif/124_1606_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/124_1606_1156.tif/keypoints - Shape: (1487, 2) - Type: float16
# Dataset: tif/124_1606_1156.tif/scores - Shape: (1487,) - Type: float16
# Group: tif/125_1756_1156.tif
# Dataset: tif/125_1756_1156.tif/descriptors - Shape: (256, 1547) - Type: float16
# Dataset: tif/125_1756_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/125_1756_1156.tif/keypoints - Shape: (1547, 2) - Type: float16
# Dataset: tif/125_1756_1156.tif/scores - Shape: (1547,) - Type: float16
# Group: tif/126_1906_1156.tif
# Dataset: tif/126_1906_1156.tif/descriptors - Shape: (256, 1583) - Type: float16
# Dataset: tif/126_1906_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/126_1906_1156.tif/keypoints - Shape: (1583, 2) - Type: float16
# Dataset: tif/126_1906_1156.tif/scores - Shape: (1583,) - Type: float16
# Group: tif/127_2056_1156.tif
# Dataset: tif/127_2056_1156.tif/descriptors - Shape: (256, 1495) - Type: float16
# Dataset: tif/127_2056_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/127_2056_1156.tif/keypoints - Shape: (1495, 2) - Type: float16
# Dataset: tif/127_2056_1156.tif/scores - Shape: (1495,) - Type: float16
# Group: tif/128_2206_1156.tif
# Dataset: tif/128_2206_1156.tif/descriptors - Shape: (256, 1540) - Type: float16
# Dataset: tif/128_2206_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/128_2206_1156.tif/keypoints - Shape: (1540, 2) - Type: float16
# Dataset: tif/128_2206_1156.tif/scores - Shape: (1540,) - Type: float16
# Group: tif/129_2356_1156.tif
# Dataset: tif/129_2356_1156.tif/descriptors - Shape: (256, 1531) - Type: float16
# Dataset: tif/129_2356_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/129_2356_1156.tif/keypoints - Shape: (1531, 2) - Type: float16
# Dataset: tif/129_2356_1156.tif/scores - Shape: (1531,) - Type: float16
# Group: tif/12_1906_256.tif
# Dataset: tif/12_1906_256.tif/descriptors - Shape: (256, 1878) - Type: float16
# Dataset: tif/12_1906_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/12_1906_256.tif/keypoints - Shape: (1878, 2) - Type: float16
# Dataset: tif/12_1906_256.tif/scores - Shape: (1878,) - Type: float16
# Group: tif/130_2506_1156.tif
# Dataset: tif/130_2506_1156.tif/descriptors - Shape: (256, 1539) - Type: float16
# Dataset: tif/130_2506_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/130_2506_1156.tif/keypoints - Shape: (1539, 2) - Type: float16
# Dataset: tif/130_2506_1156.tif/scores - Shape: (1539,) - Type: float16
# Group: tif/131_2656_1156.tif
# Dataset: tif/131_2656_1156.tif/descriptors - Shape: (256, 1563) - Type: float16
# Dataset: tif/131_2656_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/131_2656_1156.tif/keypoints - Shape: (1563, 2) - Type: float16
# Dataset: tif/131_2656_1156.tif/scores - Shape: (1563,) - Type: float16
# Group: tif/132_2806_1156.tif
# Dataset: tif/132_2806_1156.tif/descriptors - Shape: (256, 1669) - Type: float16
# Dataset: tif/132_2806_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/132_2806_1156.tif/keypoints - Shape: (1669, 2) - Type: float16
# Dataset: tif/132_2806_1156.tif/scores - Shape: (1669,) - Type: float16
# Group: tif/133_2956_1156.tif
# Dataset: tif/133_2956_1156.tif/descriptors - Shape: (256, 1528) - Type: float16
# Dataset: tif/133_2956_1156.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/133_2956_1156.tif/keypoints - Shape: (1528, 2) - Type: float16
# Dataset: tif/133_2956_1156.tif/scores - Shape: (1528,) - Type: float16
# Group: tif/134_256_1306.tif
# Dataset: tif/134_256_1306.tif/descriptors - Shape: (256, 1523) - Type: float16
# Dataset: tif/134_256_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/134_256_1306.tif/keypoints - Shape: (1523, 2) - Type: float16
# Dataset: tif/134_256_1306.tif/scores - Shape: (1523,) - Type: float16
# Group: tif/135_406_1306.tif
# Dataset: tif/135_406_1306.tif/descriptors - Shape: (256, 1656) - Type: float16
# Dataset: tif/135_406_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/135_406_1306.tif/keypoints - Shape: (1656, 2) - Type: float16
# Dataset: tif/135_406_1306.tif/scores - Shape: (1656,) - Type: float16
# Group: tif/136_556_1306.tif
# Dataset: tif/136_556_1306.tif/descriptors - Shape: (256, 1752) - Type: float16
# Dataset: tif/136_556_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/136_556_1306.tif/keypoints - Shape: (1752, 2) - Type: float16
# Dataset: tif/136_556_1306.tif/scores - Shape: (1752,) - Type: float16
# Group: tif/137_706_1306.tif
# Dataset: tif/137_706_1306.tif/descriptors - Shape: (256, 1766) - Type: float16
# Dataset: tif/137_706_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/137_706_1306.tif/keypoints - Shape: (1766, 2) - Type: float16
# Dataset: tif/137_706_1306.tif/scores - Shape: (1766,) - Type: float16
# Group: tif/138_856_1306.tif
# Dataset: tif/138_856_1306.tif/descriptors - Shape: (256, 1718) - Type: float16
# Dataset: tif/138_856_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/138_856_1306.tif/keypoints - Shape: (1718, 2) - Type: float16
# Dataset: tif/138_856_1306.tif/scores - Shape: (1718,) - Type: float16
# Group: tif/139_1006_1306.tif
# Dataset: tif/139_1006_1306.tif/descriptors - Shape: (256, 1599) - Type: float16
# Dataset: tif/139_1006_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/139_1006_1306.tif/keypoints - Shape: (1599, 2) - Type: float16
# Dataset: tif/139_1006_1306.tif/scores - Shape: (1599,) - Type: float16
# Group: tif/13_2056_256.tif
# Dataset: tif/13_2056_256.tif/descriptors - Shape: (256, 1938) - Type: float16
# Dataset: tif/13_2056_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/13_2056_256.tif/keypoints - Shape: (1938, 2) - Type: float16
# Dataset: tif/13_2056_256.tif/scores - Shape: (1938,) - Type: float16
# Group: tif/140_1156_1306.tif
# Dataset: tif/140_1156_1306.tif/descriptors - Shape: (256, 1502) - Type: float16
# Dataset: tif/140_1156_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/140_1156_1306.tif/keypoints - Shape: (1502, 2) - Type: float16
# Dataset: tif/140_1156_1306.tif/scores - Shape: (1502,) - Type: float16
# Group: tif/141_1306_1306.tif
# Dataset: tif/141_1306_1306.tif/descriptors - Shape: (256, 1477) - Type: float16
# Dataset: tif/141_1306_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/141_1306_1306.tif/keypoints - Shape: (1477, 2) - Type: float16
# Dataset: tif/141_1306_1306.tif/scores - Shape: (1477,) - Type: float16
# Group: tif/142_1456_1306.tif
# Dataset: tif/142_1456_1306.tif/descriptors - Shape: (256, 1396) - Type: float16
# Dataset: tif/142_1456_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/142_1456_1306.tif/keypoints - Shape: (1396, 2) - Type: float16
# Dataset: tif/142_1456_1306.tif/scores - Shape: (1396,) - Type: float16
# Group: tif/143_1606_1306.tif
# Dataset: tif/143_1606_1306.tif/descriptors - Shape: (256, 1433) - Type: float16
# Dataset: tif/143_1606_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/143_1606_1306.tif/keypoints - Shape: (1433, 2) - Type: float16
# Dataset: tif/143_1606_1306.tif/scores - Shape: (1433,) - Type: float16
# Group: tif/144_1756_1306.tif
# Dataset: tif/144_1756_1306.tif/descriptors - Shape: (256, 1598) - Type: float16
# Dataset: tif/144_1756_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/144_1756_1306.tif/keypoints - Shape: (1598, 2) - Type: float16
# Dataset: tif/144_1756_1306.tif/scores - Shape: (1598,) - Type: float16
# Group: tif/145_1906_1306.tif
# Dataset: tif/145_1906_1306.tif/descriptors - Shape: (256, 1704) - Type: float16
# Dataset: tif/145_1906_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/145_1906_1306.tif/keypoints - Shape: (1704, 2) - Type: float16
# Dataset: tif/145_1906_1306.tif/scores - Shape: (1704,) - Type: float16
# Group: tif/146_2056_1306.tif
# Dataset: tif/146_2056_1306.tif/descriptors - Shape: (256, 1599) - Type: float16
# Dataset: tif/146_2056_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/146_2056_1306.tif/keypoints - Shape: (1599, 2) - Type: float16
# Dataset: tif/146_2056_1306.tif/scores - Shape: (1599,) - Type: float16
# Group: tif/147_2206_1306.tif
# Dataset: tif/147_2206_1306.tif/descriptors - Shape: (256, 1746) - Type: float16
# Dataset: tif/147_2206_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/147_2206_1306.tif/keypoints - Shape: (1746, 2) - Type: float16
# Dataset: tif/147_2206_1306.tif/scores - Shape: (1746,) - Type: float16
# Group: tif/148_2356_1306.tif
# Dataset: tif/148_2356_1306.tif/descriptors - Shape: (256, 1690) - Type: float16
# Dataset: tif/148_2356_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/148_2356_1306.tif/keypoints - Shape: (1690, 2) - Type: float16
# Dataset: tif/148_2356_1306.tif/scores - Shape: (1690,) - Type: float16
# Group: tif/149_2506_1306.tif
# Dataset: tif/149_2506_1306.tif/descriptors - Shape: (256, 1656) - Type: float16
# Dataset: tif/149_2506_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/149_2506_1306.tif/keypoints - Shape: (1656, 2) - Type: float16
# Dataset: tif/149_2506_1306.tif/scores - Shape: (1656,) - Type: float16
# Group: tif/14_2206_256.tif
# Dataset: tif/14_2206_256.tif/descriptors - Shape: (256, 2021) - Type: float16
# Dataset: tif/14_2206_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/14_2206_256.tif/keypoints - Shape: (2021, 2) - Type: float16
# Dataset: tif/14_2206_256.tif/scores - Shape: (2021,) - Type: float16
# Group: tif/150_2656_1306.tif
# Dataset: tif/150_2656_1306.tif/descriptors - Shape: (256, 1667) - Type: float16
# Dataset: tif/150_2656_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/150_2656_1306.tif/keypoints - Shape: (1667, 2) - Type: float16
# Dataset: tif/150_2656_1306.tif/scores - Shape: (1667,) - Type: float16
# Group: tif/151_2806_1306.tif
# Dataset: tif/151_2806_1306.tif/descriptors - Shape: (256, 1739) - Type: float16
# Dataset: tif/151_2806_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/151_2806_1306.tif/keypoints - Shape: (1739, 2) - Type: float16
# Dataset: tif/151_2806_1306.tif/scores - Shape: (1739,) - Type: float16
# Group: tif/152_2956_1306.tif
# Dataset: tif/152_2956_1306.tif/descriptors - Shape: (256, 1559) - Type: float16
# Dataset: tif/152_2956_1306.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/152_2956_1306.tif/keypoints - Shape: (1559, 2) - Type: float16
# Dataset: tif/152_2956_1306.tif/scores - Shape: (1559,) - Type: float16
# Group: tif/153_256_1456.tif
# Dataset: tif/153_256_1456.tif/descriptors - Shape: (256, 1480) - Type: float16
# Dataset: tif/153_256_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/153_256_1456.tif/keypoints - Shape: (1480, 2) - Type: float16
# Dataset: tif/153_256_1456.tif/scores - Shape: (1480,) - Type: float16
# Group: tif/154_406_1456.tif
# Dataset: tif/154_406_1456.tif/descriptors - Shape: (256, 1597) - Type: float16
# Dataset: tif/154_406_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/154_406_1456.tif/keypoints - Shape: (1597, 2) - Type: float16
# Dataset: tif/154_406_1456.tif/scores - Shape: (1597,) - Type: float16
# Group: tif/155_556_1456.tif
# Dataset: tif/155_556_1456.tif/descriptors - Shape: (256, 1713) - Type: float16
# Dataset: tif/155_556_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/155_556_1456.tif/keypoints - Shape: (1713, 2) - Type: float16
# Dataset: tif/155_556_1456.tif/scores - Shape: (1713,) - Type: float16
# Group: tif/156_706_1456.tif
# Dataset: tif/156_706_1456.tif/descriptors - Shape: (256, 1572) - Type: float16
# Dataset: tif/156_706_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/156_706_1456.tif/keypoints - Shape: (1572, 2) - Type: float16
# Dataset: tif/156_706_1456.tif/scores - Shape: (1572,) - Type: float16
# Group: tif/157_856_1456.tif
# Dataset: tif/157_856_1456.tif/descriptors - Shape: (256, 1474) - Type: float16
# Dataset: tif/157_856_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/157_856_1456.tif/keypoints - Shape: (1474, 2) - Type: float16
# Dataset: tif/157_856_1456.tif/scores - Shape: (1474,) - Type: float16
# Group: tif/158_1006_1456.tif
# Dataset: tif/158_1006_1456.tif/descriptors - Shape: (256, 1376) - Type: float16
# Dataset: tif/158_1006_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/158_1006_1456.tif/keypoints - Shape: (1376, 2) - Type: float16
# Dataset: tif/158_1006_1456.tif/scores - Shape: (1376,) - Type: float16
# Group: tif/159_1156_1456.tif
# Dataset: tif/159_1156_1456.tif/descriptors - Shape: (256, 1222) - Type: float16
# Dataset: tif/159_1156_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/159_1156_1456.tif/keypoints - Shape: (1222, 2) - Type: float16
# Dataset: tif/159_1156_1456.tif/scores - Shape: (1222,) - Type: float16
# Group: tif/15_2356_256.tif
# Dataset: tif/15_2356_256.tif/descriptors - Shape: (256, 1997) - Type: float16
# Dataset: tif/15_2356_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/15_2356_256.tif/keypoints - Shape: (1997, 2) - Type: float16
# Dataset: tif/15_2356_256.tif/scores - Shape: (1997,) - Type: float16
# Group: tif/160_1306_1456.tif
# Dataset: tif/160_1306_1456.tif/descriptors - Shape: (256, 1180) - Type: float16
# Dataset: tif/160_1306_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/160_1306_1456.tif/keypoints - Shape: (1180, 2) - Type: float16
# Dataset: tif/160_1306_1456.tif/scores - Shape: (1180,) - Type: float16
# Group: tif/161_1456_1456.tif
# Dataset: tif/161_1456_1456.tif/descriptors - Shape: (256, 1204) - Type: float16
# Dataset: tif/161_1456_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/161_1456_1456.tif/keypoints - Shape: (1204, 2) - Type: float16
# Dataset: tif/161_1456_1456.tif/scores - Shape: (1204,) - Type: float16
# Group: tif/162_1606_1456.tif
# Dataset: tif/162_1606_1456.tif/descriptors - Shape: (256, 1301) - Type: float16
# Dataset: tif/162_1606_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/162_1606_1456.tif/keypoints - Shape: (1301, 2) - Type: float16
# Dataset: tif/162_1606_1456.tif/scores - Shape: (1301,) - Type: float16
# Group: tif/163_1756_1456.tif
# Dataset: tif/163_1756_1456.tif/descriptors - Shape: (256, 1387) - Type: float16
# Dataset: tif/163_1756_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/163_1756_1456.tif/keypoints - Shape: (1387, 2) - Type: float16
# Dataset: tif/163_1756_1456.tif/scores - Shape: (1387,) - Type: float16
# Group: tif/164_1906_1456.tif
# Dataset: tif/164_1906_1456.tif/descriptors - Shape: (256, 1566) - Type: float16
# Dataset: tif/164_1906_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/164_1906_1456.tif/keypoints - Shape: (1566, 2) - Type: float16
# Dataset: tif/164_1906_1456.tif/scores - Shape: (1566,) - Type: float16
# Group: tif/165_2056_1456.tif
# Dataset: tif/165_2056_1456.tif/descriptors - Shape: (256, 1482) - Type: float16
# Dataset: tif/165_2056_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/165_2056_1456.tif/keypoints - Shape: (1482, 2) - Type: float16
# Dataset: tif/165_2056_1456.tif/scores - Shape: (1482,) - Type: float16
# Group: tif/166_2206_1456.tif
# Dataset: tif/166_2206_1456.tif/descriptors - Shape: (256, 1595) - Type: float16
# Dataset: tif/166_2206_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/166_2206_1456.tif/keypoints - Shape: (1595, 2) - Type: float16
# Dataset: tif/166_2206_1456.tif/scores - Shape: (1595,) - Type: float16
# Group: tif/167_2356_1456.tif
# Dataset: tif/167_2356_1456.tif/descriptors - Shape: (256, 1519) - Type: float16
# Dataset: tif/167_2356_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/167_2356_1456.tif/keypoints - Shape: (1519, 2) - Type: float16
# Dataset: tif/167_2356_1456.tif/scores - Shape: (1519,) - Type: float16
# Group: tif/168_2506_1456.tif
# Dataset: tif/168_2506_1456.tif/descriptors - Shape: (256, 1506) - Type: float16
# Dataset: tif/168_2506_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/168_2506_1456.tif/keypoints - Shape: (1506, 2) - Type: float16
# Dataset: tif/168_2506_1456.tif/scores - Shape: (1506,) - Type: float16
# Group: tif/169_2656_1456.tif
# Dataset: tif/169_2656_1456.tif/descriptors - Shape: (256, 1502) - Type: float16
# Dataset: tif/169_2656_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/169_2656_1456.tif/keypoints - Shape: (1502, 2) - Type: float16
# Dataset: tif/169_2656_1456.tif/scores - Shape: (1502,) - Type: float16
# Group: tif/16_2506_256.tif
# Dataset: tif/16_2506_256.tif/descriptors - Shape: (256, 2285) - Type: float16
# Dataset: tif/16_2506_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/16_2506_256.tif/keypoints - Shape: (2285, 2) - Type: float16
# Dataset: tif/16_2506_256.tif/scores - Shape: (2285,) - Type: float16
# Group: tif/170_2806_1456.tif
# Dataset: tif/170_2806_1456.tif/descriptors - Shape: (256, 1571) - Type: float16
# Dataset: tif/170_2806_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/170_2806_1456.tif/keypoints - Shape: (1571, 2) - Type: float16
# Dataset: tif/170_2806_1456.tif/scores - Shape: (1571,) - Type: float16
# Group: tif/171_2956_1456.tif
# Dataset: tif/171_2956_1456.tif/descriptors - Shape: (256, 1410) - Type: float16
# Dataset: tif/171_2956_1456.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/171_2956_1456.tif/keypoints - Shape: (1410, 2) - Type: float16
# Dataset: tif/171_2956_1456.tif/scores - Shape: (1410,) - Type: float16
# Group: tif/172_256_1606.tif
# Dataset: tif/172_256_1606.tif/descriptors - Shape: (256, 1420) - Type: float16
# Dataset: tif/172_256_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/172_256_1606.tif/keypoints - Shape: (1420, 2) - Type: float16
# Dataset: tif/172_256_1606.tif/scores - Shape: (1420,) - Type: float16
# Group: tif/173_406_1606.tif
# Dataset: tif/173_406_1606.tif/descriptors - Shape: (256, 1530) - Type: float16
# Dataset: tif/173_406_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/173_406_1606.tif/keypoints - Shape: (1530, 2) - Type: float16
# Dataset: tif/173_406_1606.tif/scores - Shape: (1530,) - Type: float16
# Group: tif/174_556_1606.tif
# Dataset: tif/174_556_1606.tif/descriptors - Shape: (256, 1699) - Type: float16
# Dataset: tif/174_556_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/174_556_1606.tif/keypoints - Shape: (1699, 2) - Type: float16
# Dataset: tif/174_556_1606.tif/scores - Shape: (1699,) - Type: float16
# Group: tif/175_706_1606.tif
# Dataset: tif/175_706_1606.tif/descriptors - Shape: (256, 1516) - Type: float16
# Dataset: tif/175_706_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/175_706_1606.tif/keypoints - Shape: (1516, 2) - Type: float16
# Dataset: tif/175_706_1606.tif/scores - Shape: (1516,) - Type: float16
# Group: tif/176_856_1606.tif
# Dataset: tif/176_856_1606.tif/descriptors - Shape: (256, 1434) - Type: float16
# Dataset: tif/176_856_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/176_856_1606.tif/keypoints - Shape: (1434, 2) - Type: float16
# Dataset: tif/176_856_1606.tif/scores - Shape: (1434,) - Type: float16
# Group: tif/177_1006_1606.tif
# Dataset: tif/177_1006_1606.tif/descriptors - Shape: (256, 1289) - Type: float16
# Dataset: tif/177_1006_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/177_1006_1606.tif/keypoints - Shape: (1289, 2) - Type: float16
# Dataset: tif/177_1006_1606.tif/scores - Shape: (1289,) - Type: float16
# Group: tif/178_1156_1606.tif
# Dataset: tif/178_1156_1606.tif/descriptors - Shape: (256, 1127) - Type: float16
# Dataset: tif/178_1156_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/178_1156_1606.tif/keypoints - Shape: (1127, 2) - Type: float16
# Dataset: tif/178_1156_1606.tif/scores - Shape: (1127,) - Type: float16
# Group: tif/179_1306_1606.tif
# Dataset: tif/179_1306_1606.tif/descriptors - Shape: (256, 1082) - Type: float16
# Dataset: tif/179_1306_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/179_1306_1606.tif/keypoints - Shape: (1082, 2) - Type: float16
# Dataset: tif/179_1306_1606.tif/scores - Shape: (1082,) - Type: float16
# Group: tif/17_2656_256.tif
# Dataset: tif/17_2656_256.tif/descriptors - Shape: (256, 2319) - Type: float16
# Dataset: tif/17_2656_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/17_2656_256.tif/keypoints - Shape: (2319, 2) - Type: float16
# Dataset: tif/17_2656_256.tif/scores - Shape: (2319,) - Type: float16
# Group: tif/180_1456_1606.tif
# Dataset: tif/180_1456_1606.tif/descriptors - Shape: (256, 1206) - Type: float16
# Dataset: tif/180_1456_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/180_1456_1606.tif/keypoints - Shape: (1206, 2) - Type: float16
# Dataset: tif/180_1456_1606.tif/scores - Shape: (1206,) - Type: float16
# Group: tif/181_1606_1606.tif
# Dataset: tif/181_1606_1606.tif/descriptors - Shape: (256, 1287) - Type: float16
# Dataset: tif/181_1606_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/181_1606_1606.tif/keypoints - Shape: (1287, 2) - Type: float16
# Dataset: tif/181_1606_1606.tif/scores - Shape: (1287,) - Type: float16
# Group: tif/182_1756_1606.tif
# Dataset: tif/182_1756_1606.tif/descriptors - Shape: (256, 1395) - Type: float16
# Dataset: tif/182_1756_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/182_1756_1606.tif/keypoints - Shape: (1395, 2) - Type: float16
# Dataset: tif/182_1756_1606.tif/scores - Shape: (1395,) - Type: float16
# Group: tif/183_1906_1606.tif
# Dataset: tif/183_1906_1606.tif/descriptors - Shape: (256, 1659) - Type: float16
# Dataset: tif/183_1906_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/183_1906_1606.tif/keypoints - Shape: (1659, 2) - Type: float16
# Dataset: tif/183_1906_1606.tif/scores - Shape: (1659,) - Type: float16
# Group: tif/184_2056_1606.tif
# Dataset: tif/184_2056_1606.tif/descriptors - Shape: (256, 1574) - Type: float16
# Dataset: tif/184_2056_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/184_2056_1606.tif/keypoints - Shape: (1574, 2) - Type: float16
# Dataset: tif/184_2056_1606.tif/scores - Shape: (1574,) - Type: float16
# Group: tif/185_2206_1606.tif
# Dataset: tif/185_2206_1606.tif/descriptors - Shape: (256, 1583) - Type: float16
# Dataset: tif/185_2206_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/185_2206_1606.tif/keypoints - Shape: (1583, 2) - Type: float16
# Dataset: tif/185_2206_1606.tif/scores - Shape: (1583,) - Type: float16
# Group: tif/186_2356_1606.tif
# Dataset: tif/186_2356_1606.tif/descriptors - Shape: (256, 1562) - Type: float16
# Dataset: tif/186_2356_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/186_2356_1606.tif/keypoints - Shape: (1562, 2) - Type: float16
# Dataset: tif/186_2356_1606.tif/scores - Shape: (1562,) - Type: float16
# Group: tif/187_2506_1606.tif
# Dataset: tif/187_2506_1606.tif/descriptors - Shape: (256, 1599) - Type: float16
# Dataset: tif/187_2506_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/187_2506_1606.tif/keypoints - Shape: (1599, 2) - Type: float16
# Dataset: tif/187_2506_1606.tif/scores - Shape: (1599,) - Type: float16
# Group: tif/188_2656_1606.tif
# Dataset: tif/188_2656_1606.tif/descriptors - Shape: (256, 1559) - Type: float16
# Dataset: tif/188_2656_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/188_2656_1606.tif/keypoints - Shape: (1559, 2) - Type: float16
# Dataset: tif/188_2656_1606.tif/scores - Shape: (1559,) - Type: float16
# Group: tif/189_2806_1606.tif
# Dataset: tif/189_2806_1606.tif/descriptors - Shape: (256, 1648) - Type: float16
# Dataset: tif/189_2806_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/189_2806_1606.tif/keypoints - Shape: (1648, 2) - Type: float16
# Dataset: tif/189_2806_1606.tif/scores - Shape: (1648,) - Type: float16
# Group: tif/18_2806_256.tif
# Dataset: tif/18_2806_256.tif/descriptors - Shape: (256, 2323) - Type: float16
# Dataset: tif/18_2806_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/18_2806_256.tif/keypoints - Shape: (2323, 2) - Type: float16
# Dataset: tif/18_2806_256.tif/scores - Shape: (2323,) - Type: float16
# Group: tif/190_2956_1606.tif
# Dataset: tif/190_2956_1606.tif/descriptors - Shape: (256, 1532) - Type: float16
# Dataset: tif/190_2956_1606.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/190_2956_1606.tif/keypoints - Shape: (1532, 2) - Type: float16
# Dataset: tif/190_2956_1606.tif/scores - Shape: (1532,) - Type: float16
# Group: tif/191_256_1756.tif
# Dataset: tif/191_256_1756.tif/descriptors - Shape: (256, 1671) - Type: float16
# Dataset: tif/191_256_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/191_256_1756.tif/keypoints - Shape: (1671, 2) - Type: float16
# Dataset: tif/191_256_1756.tif/scores - Shape: (1671,) - Type: float16
# Group: tif/192_406_1756.tif
# Dataset: tif/192_406_1756.tif/descriptors - Shape: (256, 1751) - Type: float16
# Dataset: tif/192_406_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/192_406_1756.tif/keypoints - Shape: (1751, 2) - Type: float16
# Dataset: tif/192_406_1756.tif/scores - Shape: (1751,) - Type: float16
# Group: tif/193_556_1756.tif
# Dataset: tif/193_556_1756.tif/descriptors - Shape: (256, 1881) - Type: float16
# Dataset: tif/193_556_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/193_556_1756.tif/keypoints - Shape: (1881, 2) - Type: float16
# Dataset: tif/193_556_1756.tif/scores - Shape: (1881,) - Type: float16
# Group: tif/194_706_1756.tif
# Dataset: tif/194_706_1756.tif/descriptors - Shape: (256, 1645) - Type: float16
# Dataset: tif/194_706_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/194_706_1756.tif/keypoints - Shape: (1645, 2) - Type: float16
# Dataset: tif/194_706_1756.tif/scores - Shape: (1645,) - Type: float16
# Group: tif/195_856_1756.tif
# Dataset: tif/195_856_1756.tif/descriptors - Shape: (256, 1485) - Type: float16
# Dataset: tif/195_856_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/195_856_1756.tif/keypoints - Shape: (1485, 2) - Type: float16
# Dataset: tif/195_856_1756.tif/scores - Shape: (1485,) - Type: float16
# Group: tif/196_1006_1756.tif
# Dataset: tif/196_1006_1756.tif/descriptors - Shape: (256, 1382) - Type: float16
# Dataset: tif/196_1006_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/196_1006_1756.tif/keypoints - Shape: (1382, 2) - Type: float16
# Dataset: tif/196_1006_1756.tif/scores - Shape: (1382,) - Type: float16
# Group: tif/197_1156_1756.tif
# Dataset: tif/197_1156_1756.tif/descriptors - Shape: (256, 1208) - Type: float16
# Dataset: tif/197_1156_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/197_1156_1756.tif/keypoints - Shape: (1208, 2) - Type: float16
# Dataset: tif/197_1156_1756.tif/scores - Shape: (1208,) - Type: float16
# Group: tif/198_1306_1756.tif
# Dataset: tif/198_1306_1756.tif/descriptors - Shape: (256, 1259) - Type: float16
# Dataset: tif/198_1306_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/198_1306_1756.tif/keypoints - Shape: (1259, 2) - Type: float16
# Dataset: tif/198_1306_1756.tif/scores - Shape: (1259,) - Type: float16
# Group: tif/199_1456_1756.tif
# Dataset: tif/199_1456_1756.tif/descriptors - Shape: (256, 1451) - Type: float16
# Dataset: tif/199_1456_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/199_1456_1756.tif/keypoints - Shape: (1451, 2) - Type: float16
# Dataset: tif/199_1456_1756.tif/scores - Shape: (1451,) - Type: float16
# Group: tif/19_2956_256.tif
# Dataset: tif/19_2956_256.tif/descriptors - Shape: (256, 2158) - Type: float16
# Dataset: tif/19_2956_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/19_2956_256.tif/keypoints - Shape: (2158, 2) - Type: float16
# Dataset: tif/19_2956_256.tif/scores - Shape: (2158,) - Type: float16
# Group: tif/1_256_256.tif
# Dataset: tif/1_256_256.tif/descriptors - Shape: (256, 1723) - Type: float16
# Dataset: tif/1_256_256.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/1_256_256.tif/keypoints - Shape: (1723, 2) - Type: float16
# Dataset: tif/1_256_256.tif/scores - Shape: (1723,) - Type: float16
# Group: tif/200_1606_1756.tif
# Dataset: tif/200_1606_1756.tif/descriptors - Shape: (256, 1528) - Type: float16
# Dataset: tif/200_1606_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/200_1606_1756.tif/keypoints - Shape: (1528, 2) - Type: float16
# Dataset: tif/200_1606_1756.tif/scores - Shape: (1528,) - Type: float16
# Group: tif/201_1756_1756.tif
# Dataset: tif/201_1756_1756.tif/descriptors - Shape: (256, 1595) - Type: float16
# Dataset: tif/201_1756_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/201_1756_1756.tif/keypoints - Shape: (1595, 2) - Type: float16
# Dataset: tif/201_1756_1756.tif/scores - Shape: (1595,) - Type: float16
# Group: tif/202_1906_1756.tif
# Dataset: tif/202_1906_1756.tif/descriptors - Shape: (256, 1894) - Type: float16
# Dataset: tif/202_1906_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/202_1906_1756.tif/keypoints - Shape: (1894, 2) - Type: float16
# Dataset: tif/202_1906_1756.tif/scores - Shape: (1894,) - Type: float16
# Group: tif/203_2056_1756.tif
# Dataset: tif/203_2056_1756.tif/descriptors - Shape: (256, 1798) - Type: float16
# Dataset: tif/203_2056_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/203_2056_1756.tif/keypoints - Shape: (1798, 2) - Type: float16
# Dataset: tif/203_2056_1756.tif/scores - Shape: (1798,) - Type: float16
# Group: tif/204_2206_1756.tif
# Dataset: tif/204_2206_1756.tif/descriptors - Shape: (256, 1664) - Type: float16
# Dataset: tif/204_2206_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/204_2206_1756.tif/keypoints - Shape: (1664, 2) - Type: float16
# Dataset: tif/204_2206_1756.tif/scores - Shape: (1664,) - Type: float16
# Group: tif/205_2356_1756.tif
# Dataset: tif/205_2356_1756.tif/descriptors - Shape: (256, 1631) - Type: float16
# Dataset: tif/205_2356_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/205_2356_1756.tif/keypoints - Shape: (1631, 2) - Type: float16
# Dataset: tif/205_2356_1756.tif/scores - Shape: (1631,) - Type: float16
# Group: tif/206_2506_1756.tif
# Dataset: tif/206_2506_1756.tif/descriptors - Shape: (256, 1725) - Type: float16
# Dataset: tif/206_2506_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/206_2506_1756.tif/keypoints - Shape: (1725, 2) - Type: float16
# Dataset: tif/206_2506_1756.tif/scores - Shape: (1725,) - Type: float16
# Group: tif/207_2656_1756.tif
# Dataset: tif/207_2656_1756.tif/descriptors - Shape: (256, 1601) - Type: float16
# Dataset: tif/207_2656_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/207_2656_1756.tif/keypoints - Shape: (1601, 2) - Type: float16
# Dataset: tif/207_2656_1756.tif/scores - Shape: (1601,) - Type: float16
# Group: tif/208_2806_1756.tif
# Dataset: tif/208_2806_1756.tif/descriptors - Shape: (256, 1717) - Type: float16
# Dataset: tif/208_2806_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/208_2806_1756.tif/keypoints - Shape: (1717, 2) - Type: float16
# Dataset: tif/208_2806_1756.tif/scores - Shape: (1717,) - Type: float16
# Group: tif/209_2956_1756.tif
# Dataset: tif/209_2956_1756.tif/descriptors - Shape: (256, 1626) - Type: float16
# Dataset: tif/209_2956_1756.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/209_2956_1756.tif/keypoints - Shape: (1626, 2) - Type: float16
# Dataset: tif/209_2956_1756.tif/scores - Shape: (1626,) - Type: float16
# Group: tif/20_256_406.tif
# Dataset: tif/20_256_406.tif/descriptors - Shape: (256, 1778) - Type: float16
# Dataset: tif/20_256_406.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/20_256_406.tif/keypoints - Shape: (1778, 2) - Type: float16
# Dataset: tif/20_256_406.tif/scores - Shape: (1778,) - Type: float16
# Group: tif/210_256_1906.tif
# Dataset: tif/210_256_1906.tif/descriptors - Shape: (256, 1659) - Type: float16
# Dataset: tif/210_256_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/210_256_1906.tif/keypoints - Shape: (1659, 2) - Type: float16
# Dataset: tif/210_256_1906.tif/scores - Shape: (1659,) - Type: float16
# Group: tif/211_406_1906.tif
# Dataset: tif/211_406_1906.tif/descriptors - Shape: (256, 1632) - Type: float16
# Dataset: tif/211_406_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/211_406_1906.tif/keypoints - Shape: (1632, 2) - Type: float16
# Dataset: tif/211_406_1906.tif/scores - Shape: (1632,) - Type: float16
# Group: tif/212_556_1906.tif
# Dataset: tif/212_556_1906.tif/descriptors - Shape: (256, 1694) - Type: float16
# Dataset: tif/212_556_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/212_556_1906.tif/keypoints - Shape: (1694, 2) - Type: float16
# Dataset: tif/212_556_1906.tif/scores - Shape: (1694,) - Type: float16
# Group: tif/213_706_1906.tif
# Dataset: tif/213_706_1906.tif/descriptors - Shape: (256, 1430) - Type: float16
# Dataset: tif/213_706_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/213_706_1906.tif/keypoints - Shape: (1430, 2) - Type: float16
# Dataset: tif/213_706_1906.tif/scores - Shape: (1430,) - Type: float16
# Group: tif/214_856_1906.tif
# Dataset: tif/214_856_1906.tif/descriptors - Shape: (256, 1200) - Type: float16
# Dataset: tif/214_856_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/214_856_1906.tif/keypoints - Shape: (1200, 2) - Type: float16
# Dataset: tif/214_856_1906.tif/scores - Shape: (1200,) - Type: float16
# Group: tif/215_1006_1906.tif
# Dataset: tif/215_1006_1906.tif/descriptors - Shape: (256, 1135) - Type: float16
# Dataset: tif/215_1006_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/215_1006_1906.tif/keypoints - Shape: (1135, 2) - Type: float16
# Dataset: tif/215_1006_1906.tif/scores - Shape: (1135,) - Type: float16
# Group: tif/216_1156_1906.tif
# Dataset: tif/216_1156_1906.tif/descriptors - Shape: (256, 1045) - Type: float16
# Dataset: tif/216_1156_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/216_1156_1906.tif/keypoints - Shape: (1045, 2) - Type: float16
# Dataset: tif/216_1156_1906.tif/scores - Shape: (1045,) - Type: float16
# Group: tif/217_1306_1906.tif
# Dataset: tif/217_1306_1906.tif/descriptors - Shape: (256, 1120) - Type: float16
# Dataset: tif/217_1306_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/217_1306_1906.tif/keypoints - Shape: (1120, 2) - Type: float16
# Dataset: tif/217_1306_1906.tif/scores - Shape: (1120,) - Type: float16
# Group: tif/218_1456_1906.tif
# Dataset: tif/218_1456_1906.tif/descriptors - Shape: (256, 1292) - Type: float16
# Dataset: tif/218_1456_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/218_1456_1906.tif/keypoints - Shape: (1292, 2) - Type: float16
# Dataset: tif/218_1456_1906.tif/scores - Shape: (1292,) - Type: float16
# Group: tif/219_1606_1906.tif
# Dataset: tif/219_1606_1906.tif/descriptors - Shape: (256, 1362) - Type: float16
# Dataset: tif/219_1606_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/219_1606_1906.tif/keypoints - Shape: (1362, 2) - Type: float16
# Dataset: tif/219_1606_1906.tif/scores - Shape: (1362,) - Type: float16
# Group: tif/21_406_406.tif
# Dataset: tif/21_406_406.tif/descriptors - Shape: (256, 1976) - Type: float16
# Dataset: tif/21_406_406.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/21_406_406.tif/keypoints - Shape: (1976, 2) - Type: float16
# Dataset: tif/21_406_406.tif/scores - Shape: (1976,) - Type: float16
# Group: tif/220_1756_1906.tif
# Dataset: tif/220_1756_1906.tif/descriptors - Shape: (256, 1436) - Type: float16
# Dataset: tif/220_1756_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/220_1756_1906.tif/keypoints - Shape: (1436, 2) - Type: float16
# Dataset: tif/220_1756_1906.tif/scores - Shape: (1436,) - Type: float16
# Group: tif/221_1906_1906.tif
# Dataset: tif/221_1906_1906.tif/descriptors - Shape: (256, 1669) - Type: float16
# Dataset: tif/221_1906_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/221_1906_1906.tif/keypoints - Shape: (1669, 2) - Type: float16
# Dataset: tif/221_1906_1906.tif/scores - Shape: (1669,) - Type: float16
# Group: tif/222_2056_1906.tif
# Dataset: tif/222_2056_1906.tif/descriptors - Shape: (256, 1554) - Type: float16
# Dataset: tif/222_2056_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/222_2056_1906.tif/keypoints - Shape: (1554, 2) - Type: float16
# Dataset: tif/222_2056_1906.tif/scores - Shape: (1554,) - Type: float16
# Group: tif/223_2206_1906.tif
# Dataset: tif/223_2206_1906.tif/descriptors - Shape: (256, 1427) - Type: float16
# Dataset: tif/223_2206_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/223_2206_1906.tif/keypoints - Shape: (1427, 2) - Type: float16
# Dataset: tif/223_2206_1906.tif/scores - Shape: (1427,) - Type: float16
# Group: tif/224_2356_1906.tif
# Dataset: tif/224_2356_1906.tif/descriptors - Shape: (256, 1494) - Type: float16
# Dataset: tif/224_2356_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/224_2356_1906.tif/keypoints - Shape: (1494, 2) - Type: float16
# Dataset: tif/224_2356_1906.tif/scores - Shape: (1494,) - Type: float16
# Group: tif/225_2506_1906.tif
# Dataset: tif/225_2506_1906.tif/descriptors - Shape: (256, 1551) - Type: float16
# Dataset: tif/225_2506_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/225_2506_1906.tif/keypoints - Shape: (1551, 2) - Type: float16
# Dataset: tif/225_2506_1906.tif/scores - Shape: (1551,) - Type: float16
# Group: tif/226_2656_1906.tif
# Dataset: tif/226_2656_1906.tif/descriptors - Shape: (256, 1505) - Type: float16
# Dataset: tif/226_2656_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/226_2656_1906.tif/keypoints - Shape: (1505, 2) - Type: float16
# Dataset: tif/226_2656_1906.tif/scores - Shape: (1505,) - Type: float16
# Group: tif/227_2806_1906.tif
# Dataset: tif/227_2806_1906.tif/descriptors - Shape: (256, 1604) - Type: float16
# Dataset: tif/227_2806_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/227_2806_1906.tif/keypoints - Shape: (1604, 2) - Type: float16
# Dataset: tif/227_2806_1906.tif/scores - Shape: (1604,) - Type: float16
# Group: tif/228_2956_1906.tif
# Dataset: tif/228_2956_1906.tif/descriptors - Shape: (256, 1566) - Type: float16
# Dataset: tif/228_2956_1906.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/228_2956_1906.tif/keypoints - Shape: (1566, 2) - Type: float16
# Dataset: tif/228_2956_1906.tif/scores - Shape: (1566,) - Type: float16
# Group: tif/229_256_2056.tif
# Dataset: tif/229_256_2056.tif/descriptors - Shape: (256, 1553) - Type: float16
# Dataset: tif/229_256_2056.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/229_256_2056.tif/keypoints - Shape: (1553, 2) - Type: float16
# Dataset: tif/229_256_2056.tif/scores - Shape: (1553,) - Type: float16
# Group: tif/22_556_406.tif
# Dataset: tif/22_556_406.tif/descriptors - Shape: (256, 2077) - Type: float16
# Dataset: tif/22_556_406.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/22_556_406.tif/keypoints - Shape: (2077, 2) - Type: float16
# Dataset: tif/22_556_406.tif/scores - Shape: (2077,) - Type: float16
# Group: tif/230_406_2056.tif
# Dataset: tif/230_406_2056.tif/descriptors - Shape: (256, 1486) - Type: float16
# Dataset: tif/230_406_2056.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/230_406_2056.tif/keypoints - Shape: (1486, 2) - Type: float16
# Dataset: tif/230_406_2056.tif/scores - Shape: (1486,) - Type: float16
# Group: tif/231_556_2056.tif
# Dataset: tif/231_556_2056.tif/descriptors - Shape: (256, 1527) - Type: float16
# Dataset: tif/231_556_2056.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/231_556_2056.tif/keypoints - Shape: (1527, 2) - Type: float16
# Dataset: tif/231_556_2056.tif/scores - Shape: (1527,) - Type: float16
# Group: tif/232_706_2056.tif
# Dataset: tif/232_706_2056.tif/descriptors - Shape: (256, 1303) - Type: float16
# Dataset: tif/232_706_2056.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/232_706_2056.tif/keypoints - Shape: (1303, 2) - Type: float16
# Dataset: tif/232_706_2056.tif/scores - Shape: (1303,) - Type: float16
# Group: tif/233_856_2056.tif
# Dataset: tif/233_856_2056.tif/descriptors - Shape: (256, 1129) - Type: float16
# Dataset: tif/233_856_2056.tif/image_size - Shape: (2,) - Type: int64
# Dataset: tif/233_856_2056.tif/keypoints - Shape: (1129, 2) - Type: float16
# Dataset: tif/233_856_2056.tif/scores - Shape: (1129,) - Type: float16
# Group: tif/234_1006_2056.tif
# ...
# Dataset: uav/372.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/372.jpg/keypoints - Shape: (3220, 2) - Type: float16
# Dataset: uav/372.jpg/scores - Shape: (3220,) - Type: float16
# Group: uav/373.jpg
# Dataset: uav/373.jpg/descriptors - Shape: (256, 3060) - Type: float16
# Dataset: uav/373.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/373.jpg/keypoints - Shape: (3060, 2) - Type: float16
# Dataset: uav/373.jpg/scores - Shape: (3060,) - Type: float16
# Group: uav/374.jpg
# Dataset: uav/374.jpg/descriptors - Shape: (256, 3114) - Type: float16
# Dataset: uav/374.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/374.jpg/keypoints - Shape: (3114, 2) - Type: float16
# Dataset: uav/374.jpg/scores - Shape: (3114,) - Type: float16
# Group: uav/375.jpg
# Dataset: uav/375.jpg/descriptors - Shape: (256, 2999) - Type: float16
# Dataset: uav/375.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/375.jpg/keypoints - Shape: (2999, 2) - Type: float16
# Dataset: uav/375.jpg/scores - Shape: (2999,) - Type: float16
# Group: uav/376.jpg
# Dataset: uav/376.jpg/descriptors - Shape: (256, 2981) - Type: float16
# Dataset: uav/376.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/376.jpg/keypoints - Shape: (2981, 2) - Type: float16
# Dataset: uav/376.jpg/scores - Shape: (2981,) - Type: float16
# Group: uav/377.jpg
# Dataset: uav/377.jpg/descriptors - Shape: (256, 2997) - Type: float16
# Dataset: uav/377.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/377.jpg/keypoints - Shape: (2997, 2) - Type: float16
# Dataset: uav/377.jpg/scores - Shape: (2997,) - Type: float16
# Group: uav/378.jpg
# Dataset: uav/378.jpg/descriptors - Shape: (256, 3037) - Type: float16
# Dataset: uav/378.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/378.jpg/keypoints - Shape: (3037, 2) - Type: float16
# Dataset: uav/378.jpg/scores - Shape: (3037,) - Type: float16
# Group: uav/379.jpg
# Dataset: uav/379.jpg/descriptors - Shape: (256, 3007) - Type: float16
# Dataset: uav/379.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/379.jpg/keypoints - Shape: (3007, 2) - Type: float16
# Dataset: uav/379.jpg/scores - Shape: (3007,) - Type: float16
# Group: uav/380.jpg
# Dataset: uav/380.jpg/descriptors - Shape: (256, 3159) - Type: float16
# Dataset: uav/380.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/380.jpg/keypoints - Shape: (3159, 2) - Type: float16
# Dataset: uav/380.jpg/scores - Shape: (3159,) - Type: float16
# Group: uav/381.jpg
# Dataset: uav/381.jpg/descriptors - Shape: (256, 3208) - Type: float16
# Dataset: uav/381.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/381.jpg/keypoints - Shape: (3208, 2) - Type: float16
# Dataset: uav/381.jpg/scores - Shape: (3208,) - Type: float16
# Group: uav/382.jpg
# Dataset: uav/382.jpg/descriptors - Shape: (256, 3057) - Type: float16
# Dataset: uav/382.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/382.jpg/keypoints - Shape: (3057, 2) - Type: float16
# Dataset: uav/382.jpg/scores - Shape: (3057,) - Type: float16
# Group: uav/383.jpg
# Dataset: uav/383.jpg/descriptors - Shape: (256, 3130) - Type: float16
# Dataset: uav/383.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/383.jpg/keypoints - Shape: (3130, 2) - Type: float16
# Dataset: uav/383.jpg/scores - Shape: (3130,) - Type: float16
# Group: uav/384.jpg
# Dataset: uav/384.jpg/descriptors - Shape: (256, 3195) - Type: float16
# Dataset: uav/384.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/384.jpg/keypoints - Shape: (3195, 2) - Type: float16
# Dataset: uav/384.jpg/scores - Shape: (3195,) - Type: float16
# Group: uav/385.jpg
# Dataset: uav/385.jpg/descriptors - Shape: (256, 3092) - Type: float16
# Dataset: uav/385.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/385.jpg/keypoints - Shape: (3092, 2) - Type: float16
# Dataset: uav/385.jpg/scores - Shape: (3092,) - Type: float16
# Group: uav/386.jpg
# Dataset: uav/386.jpg/descriptors - Shape: (256, 3203) - Type: float16
# Dataset: uav/386.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/386.jpg/keypoints - Shape: (3203, 2) - Type: float16
# Dataset: uav/386.jpg/scores - Shape: (3203,) - Type: float16
# Group: uav/387.jpg
# Dataset: uav/387.jpg/descriptors - Shape: (256, 3209) - Type: float16
# Dataset: uav/387.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/387.jpg/keypoints - Shape: (3209, 2) - Type: float16
# Dataset: uav/387.jpg/scores - Shape: (3209,) - Type: float16
# Group: uav/388.jpg
# Dataset: uav/388.jpg/descriptors - Shape: (256, 3303) - Type: float16
# Dataset: uav/388.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/388.jpg/keypoints - Shape: (3303, 2) - Type: float16
# Dataset: uav/388.jpg/scores - Shape: (3303,) - Type: float16
# Group: uav/389.jpg
# Dataset: uav/389.jpg/descriptors - Shape: (256, 3303) - Type: float16
# Dataset: uav/389.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/389.jpg/keypoints - Shape: (3303, 2) - Type: float16
# Dataset: uav/389.jpg/scores - Shape: (3303,) - Type: float16
# Group: uav/390.jpg
# Dataset: uav/390.jpg/descriptors - Shape: (256, 3399) - Type: float16
# Dataset: uav/390.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/390.jpg/keypoints - Shape: (3399, 2) - Type: float16
# Dataset: uav/390.jpg/scores - Shape: (3399,) - Type: float16
# Group: uav/391.jpg
# Dataset: uav/391.jpg/descriptors - Shape: (256, 3295) - Type: float16
# Dataset: uav/391.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/391.jpg/keypoints - Shape: (3295, 2) - Type: float16
# Dataset: uav/391.jpg/scores - Shape: (3295,) - Type: float16
# Group: uav/392.jpg
# Dataset: uav/392.jpg/descriptors - Shape: (256, 3152) - Type: float16
# Dataset: uav/392.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/392.jpg/keypoints - Shape: (3152, 2) - Type: float16
# Dataset: uav/392.jpg/scores - Shape: (3152,) - Type: float16
# Group: uav/393.jpg
# Dataset: uav/393.jpg/descriptors - Shape: (256, 3181) - Type: float16
# Dataset: uav/393.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/393.jpg/keypoints - Shape: (3181, 2) - Type: float16
# Dataset: uav/393.jpg/scores - Shape: (3181,) - Type: float16
# Group: uav/394.jpg
# Dataset: uav/394.jpg/descriptors - Shape: (256, 3217) - Type: float16
# Dataset: uav/394.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/394.jpg/keypoints - Shape: (3217, 2) - Type: float16
# Dataset: uav/394.jpg/scores - Shape: (3217,) - Type: float16
# Group: uav/395.jpg
# Dataset: uav/395.jpg/descriptors - Shape: (256, 3158) - Type: float16
# Dataset: uav/395.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/395.jpg/keypoints - Shape: (3158, 2) - Type: float16
# Dataset: uav/395.jpg/scores - Shape: (3158,) - Type: float16
# Group: uav/396.jpg
# Dataset: uav/396.jpg/descriptors - Shape: (256, 3101) - Type: float16
# Dataset: uav/396.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/396.jpg/keypoints - Shape: (3101, 2) - Type: float16
# Dataset: uav/396.jpg/scores - Shape: (3101,) - Type: float16
# Group: uav/397.jpg
# Dataset: uav/397.jpg/descriptors - Shape: (256, 3027) - Type: float16
# Dataset: uav/397.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/397.jpg/keypoints - Shape: (3027, 2) - Type: float16
# Dataset: uav/397.jpg/scores - Shape: (3027,) - Type: float16
# Group: uav/398.jpg
# Dataset: uav/398.jpg/descriptors - Shape: (256, 2974) - Type: float16
# Dataset: uav/398.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/398.jpg/keypoints - Shape: (2974, 2) - Type: float16
# Dataset: uav/398.jpg/scores - Shape: (2974,) - Type: float16
# Group: uav/399.jpg
# Dataset: uav/399.jpg/descriptors - Shape: (256, 2674) - Type: float16
# Dataset: uav/399.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/399.jpg/keypoints - Shape: (2674, 2) - Type: float16
# Dataset: uav/399.jpg/scores - Shape: (2674,) - Type: float16
# Group: uav/400.jpg
# Dataset: uav/400.jpg/descriptors - Shape: (256, 2774) - Type: float16
# Dataset: uav/400.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/400.jpg/keypoints - Shape: (2774, 2) - Type: float16
# Dataset: uav/400.jpg/scores - Shape: (2774,) - Type: float16
# Group: uav/401.jpg
# Dataset: uav/401.jpg/descriptors - Shape: (256, 2673) - Type: float16
# Dataset: uav/401.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/401.jpg/keypoints - Shape: (2673, 2) - Type: float16
# Dataset: uav/401.jpg/scores - Shape: (2673,) - Type: float16
# Group: uav/402.jpg
# Dataset: uav/402.jpg/descriptors - Shape: (256, 2544) - Type: float16
# Dataset: uav/402.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/402.jpg/keypoints - Shape: (2544, 2) - Type: float16
# Dataset: uav/402.jpg/scores - Shape: (2544,) - Type: float16
# Group: uav/403.jpg
# Dataset: uav/403.jpg/descriptors - Shape: (256, 2591) - Type: float16
# Dataset: uav/403.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/403.jpg/keypoints - Shape: (2591, 2) - Type: float16
# Dataset: uav/403.jpg/scores - Shape: (2591,) - Type: float16
# Group: uav/404.jpg
# Dataset: uav/404.jpg/descriptors - Shape: (256, 2509) - Type: float16
# Dataset: uav/404.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/404.jpg/keypoints - Shape: (2509, 2) - Type: float16
# Dataset: uav/404.jpg/scores - Shape: (2509,) - Type: float16
# Group: uav/405.jpg
# Dataset: uav/405.jpg/descriptors - Shape: (256, 2533) - Type: float16
# Dataset: uav/405.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/405.jpg/keypoints - Shape: (2533, 2) - Type: float16
# Dataset: uav/405.jpg/scores - Shape: (2533,) - Type: float16
# Group: uav/406.jpg
# Dataset: uav/406.jpg/descriptors - Shape: (256, 2552) - Type: float16
# Dataset: uav/406.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/406.jpg/keypoints - Shape: (2552, 2) - Type: float16
# Dataset: uav/406.jpg/scores - Shape: (2552,) - Type: float16
# Group: uav/407.jpg
# Dataset: uav/407.jpg/descriptors - Shape: (256, 2615) - Type: float16
# Dataset: uav/407.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/407.jpg/keypoints - Shape: (2615, 2) - Type: float16
# Dataset: uav/407.jpg/scores - Shape: (2615,) - Type: float16
# Group: uav/408.jpg
# Dataset: uav/408.jpg/descriptors - Shape: (256, 2657) - Type: float16
# Dataset: uav/408.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/408.jpg/keypoints - Shape: (2657, 2) - Type: float16
# Dataset: uav/408.jpg/scores - Shape: (2657,) - Type: float16
# Group: uav/409.jpg
# Dataset: uav/409.jpg/descriptors - Shape: (256, 2722) - Type: float16
# Dataset: uav/409.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/409.jpg/keypoints - Shape: (2722, 2) - Type: float16
# Dataset: uav/409.jpg/scores - Shape: (2722,) - Type: float16
# Group: uav/410.jpg
# Dataset: uav/410.jpg/descriptors - Shape: (256, 2734) - Type: float16
# Dataset: uav/410.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/410.jpg/keypoints - Shape: (2734, 2) - Type: float16
# Dataset: uav/410.jpg/scores - Shape: (2734,) - Type: float16
# Group: uav/411.jpg
# Dataset: uav/411.jpg/descriptors - Shape: (256, 2826) - Type: float16
# Dataset: uav/411.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/411.jpg/keypoints - Shape: (2826, 2) - Type: float16
# Dataset: uav/411.jpg/scores - Shape: (2826,) - Type: float16
# Group: uav/412.jpg
# Dataset: uav/412.jpg/descriptors - Shape: (256, 2964) - Type: float16
# Dataset: uav/412.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/412.jpg/keypoints - Shape: (2964, 2) - Type: float16
# Dataset: uav/412.jpg/scores - Shape: (2964,) - Type: float16
# Group: uav/413.jpg
# Dataset: uav/413.jpg/descriptors - Shape: (256, 2892) - Type: float16
# Dataset: uav/413.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/413.jpg/keypoints - Shape: (2892, 2) - Type: float16
# Dataset: uav/413.jpg/scores - Shape: (2892,) - Type: float16
# Group: uav/414.jpg
# Dataset: uav/414.jpg/descriptors - Shape: (256, 2977) - Type: float16
# Dataset: uav/414.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/414.jpg/keypoints - Shape: (2977, 2) - Type: float16
# Dataset: uav/414.jpg/scores - Shape: (2977,) - Type: float16
# Group: uav/415.jpg
# Dataset: uav/415.jpg/descriptors - Shape: (256, 2998) - Type: float16
# Dataset: uav/415.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/415.jpg/keypoints - Shape: (2998, 2) - Type: float16
# Dataset: uav/415.jpg/scores - Shape: (2998,) - Type: float16
# Group: uav/416.jpg
# Dataset: uav/416.jpg/descriptors - Shape: (256, 2929) - Type: float16
# Dataset: uav/416.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/416.jpg/keypoints - Shape: (2929, 2) - Type: float16
# Dataset: uav/416.jpg/scores - Shape: (2929,) - Type: float16
# Group: uav/417.jpg
# Dataset: uav/417.jpg/descriptors - Shape: (256, 2916) - Type: float16
# Dataset: uav/417.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/417.jpg/keypoints - Shape: (2916, 2) - Type: float16
# Dataset: uav/417.jpg/scores - Shape: (2916,) - Type: float16
# Group: uav/418.jpg
# Dataset: uav/418.jpg/descriptors - Shape: (256, 2873) - Type: float16
# Dataset: uav/418.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/418.jpg/keypoints - Shape: (2873, 2) - Type: float16
# Dataset: uav/418.jpg/scores - Shape: (2873,) - Type: float16
# Group: uav/419.jpg
# Dataset: uav/419.jpg/descriptors - Shape: (256, 2872) - Type: float16
# Dataset: uav/419.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/419.jpg/keypoints - Shape: (2872, 2) - Type: float16
# Dataset: uav/419.jpg/scores - Shape: (2872,) - Type: float16
# Group: uav/420.jpg
# Dataset: uav/420.jpg/descriptors - Shape: (256, 2927) - Type: float16
# Dataset: uav/420.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/420.jpg/keypoints - Shape: (2927, 2) - Type: float16
# Dataset: uav/420.jpg/scores - Shape: (2927,) - Type: float16
# Group: uav/421.jpg
# Dataset: uav/421.jpg/descriptors - Shape: (256, 2870) - Type: float16
# Dataset: uav/421.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/421.jpg/keypoints - Shape: (2870, 2) - Type: float16
# Dataset: uav/421.jpg/scores - Shape: (2870,) - Type: float16
# Group: uav/422.jpg
# Dataset: uav/422.jpg/descriptors - Shape: (256, 2888) - Type: float16
# Dataset: uav/422.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/422.jpg/keypoints - Shape: (2888, 2) - Type: float16
# Dataset: uav/422.jpg/scores - Shape: (2888,) - Type: float16
# Group: uav/423.jpg
# Dataset: uav/423.jpg/descriptors - Shape: (256, 2925) - Type: float16
# Dataset: uav/423.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/423.jpg/keypoints - Shape: (2925, 2) - Type: float16
# Dataset: uav/423.jpg/scores - Shape: (2925,) - Type: float16
# Group: uav/424.jpg
# Dataset: uav/424.jpg/descriptors - Shape: (256, 3003) - Type: float16
# Dataset: uav/424.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/424.jpg/keypoints - Shape: (3003, 2) - Type: float16
# Dataset: uav/424.jpg/scores - Shape: (3003,) - Type: float16
# Group: uav/425.jpg
# Dataset: uav/425.jpg/descriptors - Shape: (256, 2971) - Type: float16
# Dataset: uav/425.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/425.jpg/keypoints - Shape: (2971, 2) - Type: float16
# Dataset: uav/425.jpg/scores - Shape: (2971,) - Type: float16
# Group: uav/426.jpg
# Dataset: uav/426.jpg/descriptors - Shape: (256, 2855) - Type: float16
# Dataset: uav/426.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/426.jpg/keypoints - Shape: (2855, 2) - Type: float16
# Dataset: uav/426.jpg/scores - Shape: (2855,) - Type: float16
# Group: uav/427.jpg
# Dataset: uav/427.jpg/descriptors - Shape: (256, 2746) - Type: float16
# Dataset: uav/427.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/427.jpg/keypoints - Shape: (2746, 2) - Type: float16
# Dataset: uav/427.jpg/scores - Shape: (2746,) - Type: float16
# Group: uav/428.jpg
# Dataset: uav/428.jpg/descriptors - Shape: (256, 2707) - Type: float16
# Dataset: uav/428.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/428.jpg/keypoints - Shape: (2707, 2) - Type: float16
# Dataset: uav/428.jpg/scores - Shape: (2707,) - Type: float16
# Group: uav/429.jpg
# Dataset: uav/429.jpg/descriptors - Shape: (256, 2761) - Type: float16
# Dataset: uav/429.jpg/image_size - Shape: (2,) - Type: int64
# Dataset: uav/429.jpg/keypoints - Shape: (2761, 2) - Type: float16
# Dataset: uav/429.jpg/scores - Shape: (2761,) - Type: float16
# 图像 'seu_uav/DJI_0218.JPG' 不存在于 HDF5 文件中。
